# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras
import re
import nltk
from nltk.corpus import stopwords
import string
import json
from time import time
import pickle
from keras.applications.vgg16 import VGG16
from keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from keras.preprocessing import image
from keras.models import Model, load_model
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Input, Dense, Dropout, Embedding, LSTM
from keras.layers.merge import add

# %% [markdown]
# # Read Caption File

# %%
# Reading the Description file

#with open("./flicker8k-dataset/Flickr8k_text/Flickr8k.token.txt") as filepath:
with open("flickr_dataset/Flickr8k_text/Flickr8k.token.txt") as filepath:
    captions = filepath.read()
    filepath.close()

# %%
captions = captions.split("\n")[:-1]

# %%
len(captions)
# Out:
# 40460

# %%
# creating a "descriptions" dictionary  where key is 'img_name' and value is list of captions corresponding to that image_file.

descriptions = {}

for ele in captions:
    i_to_c = ele.split("\t")
    img_name = i_to_c[0].split(".")[0]
    cap = i_to_c[1]
    
    if descriptions.get(img_name) == None:
        descriptions[img_name] = []

    descriptions[img_name].append(cap)

# %%
descriptions['1000268201_693b08cb0e']
# Out:
# ['A child in a pink dress is climbing up a set of stairs in an entry way .',
#  'A girl going into a wooden building .',
#  'A little girl climbing into a wooden playhouse .',
#  'A little girl climbing the stairs to her playhouse .',
#  'A little girl in a pink dress going into a wooden cabin .']

# %% [markdown]
# # Data Cleaning

# %%
""" 1. lower each word
    2. remove puntuations
    3. remove words less than length 1 """ 

def clean_text(sample):
    sample = sample.lower()
    
    sample = re.sub("[^a-z]+"," ",sample)
    
    sample = sample.split()
    
    sample = [s for s in sample if len(s)>1]
    
    sample = " ".join(sample)
    
    return sample

# %%
clean_text("My noghsujf si am m cricket101 &8 mphi*&86%%&??,BY6fajdn 213 q rqu243 boy  32 ewr wO>>J DHD 34  asfb HHGY Gvg HgB   231 123")
# Out:
# 'my noghsujf si am cricket mphi by fajdn rqu boy ewr wo dhd asfb hhgy gvg hgb'

# %%
#  modify all the captions i.e - cleaned captions

for key, desc_list in descriptions.items():
    for i in range(len(desc_list)):
        desc_list[i] = clean_text(desc_list[i])

# %%
#  clean descriptions

descriptions['1000268201_693b08cb0e']
# Out:
# ['child in pink dress is climbing up set of stairs in an entry way',
#  'girl going into wooden building',
#  'little girl climbing into wooden playhouse',
#  'little girl climbing the stairs to her playhouse',
#  'little girl in pink dress going into wooden cabin']

# %%
# writing clean description to .txt file

f = open("descriptions.txt","w")
f.write( str(descriptions) )
f.close()

# %%
#  reading description file

#f = open("storage/descriptions.txt", 'r')
f = open("descriptions.txt", 'r')
descriptions = f.read()
f.close()

json_acceptable_string = descriptions.replace("'", "\"")
descriptions = json.loads(json_acceptable_string)

# %%
# finding the unique vocabulary 

vocabulary = set()

for key in descriptions.keys():
    [vocabulary.update(i.split()) for i in descriptions[key]]

print('Vocabulary Size: %d' % len(vocabulary))
# Out:
# Vocabulary Size: 8424

# %%
#  ALl words in description dictionary
all_vocab =  []

for key in descriptions.keys():
    [all_vocab.append(i) for des in descriptions[key] for i in des.split()]

print('Vocabulary Size: %d' % len(all_vocab))
print(all_vocab[:15])
# Out:
# Vocabulary Size: 373837
# ['child', 'in', 'pink', 'dress', 'is', 'climbing', 'up', 'set', 'of', 'stairs', 'in', 'an', 'entry', 'way', 'girl']

# %%
#  count the frequency of each word, sort them and discard the words having frequency lesser than threshold value

import collections


counter= collections.Counter(all_vocab)

dic_ = dict(counter)

threshelod_value = 10

sorted_dic = sorted(dic_.items(), reverse=True, key = lambda x: x[1])
sorted_dic = [x for x in sorted_dic if x[1]>threshelod_value]
all_vocab = [x[0] for x in sorted_dic]

# %%
len(all_vocab)
# Out:
# 1845

# %% [markdown]
# # Loading training testing data

# %%
# TrainImagesFile
#f = open("flicker8k-dataset/Flickr8k_text/Flickr_8k.trainImages.txt")
f = open("flickr_dataset/Flickr8k_text/Flickr_8k.trainImages.txt")
train = f.read()
f.close()

# %%
train  = [e.split(".")[0] for e in train.split("\n")[:-1]]

# %%
train
# Out:
# ['2513260012_03d33305cf',
#  '2903617548_d3e38d7f88',
#  '3338291921_fe7ae0c8f8',
#  '488416045_1c6d903fe0',
#  '2644326817_8f45080b87',
#  '218342358_1755a9cce1',
#  '2501968935_02f2cd8079',
#  '2699342860_5288e203ea',
#  '2638369467_8fc251595b',
#  '2926786902_815a99a154',
#  '2851304910_b5721199bc',
#  '3423802527_94bd2b23b0',
#  '3356369156_074750c6cc',
#  '2294598473_40637b5c04',
#  '1191338263_a4fa073154',
#  '2380765956_6313d8cae3',
#  '3197891333_b1b0fd1702',
#  '3119887967_271a097464',
#  '2276499757_b44dc6f8ce',
#  '2506892928_7e79bec613',
#  '2187222896_c206d63396',
#  '2826769554_85c90864c9',
#  '3097196395_ec06075389',
#  '3603116579_4a28a932e2',
#  '3339263085_6db9fd0981',
#  '2532262109_87429a2cae',
#  '2076906555_c20dc082db',
#  '2502007071_82a8c639cf',
#  '3113769557_9edbb8275c',
#  '3325974730_3ee192e4ff',
#  '1655781989_b15ab4cbff',
#  '1662261486_db967930de',
#  '2410562803_56ec09f41c',
#  '2469498117_b4543e1460',
#  '69710415_5c2bfb1058',
#  '3414734842_beb543f400',
#  '3006217970_90b42e6b27',
#  '2192411521_9c7e488c5e',
#  '3535879138_9281dc83d5',
#  '2685788323_ceab14534a',
#  '3465606652_f380a38050',
#  '2599131872_65789d86d5',
#  '2244613488_4d1f9edb33',
#  '2738077433_10e6264b6f',
#  '3537201804_ce07aff237',
#  '1597557856_30640e0b43',
#  '3357194782_c261bb6cbf',
#  '3682038869_585075b5ff',
#  '236474697_0c73dd5d8b',
#  '2641288004_30ce961211',
#  '267164457_2e8b4d30aa',
#  '2453891449_fedb277908',
#  '281419391_522557ce27',
#  '354999632_915ea81e53',
#  '3109136206_f7d201b368',
#  '2281054343_95d6d3b882',
#  '3296584432_bef3c965a3',
#  '3526431764_056d2c61dc',
#  '3549997413_01388dece0',
#  '143688895_e837c3bc76',
#  '2495394666_2ef6c37519',
#  '3384742888_85230c34d5',
#  '1160034462_16b38174fe',
#  '334768700_51c439b9ee',
#  '2687539673_d54a8dc613',
#  '3067500667_0fce8f28d4',
#  '2657484970_610e18144f',
#  '407008823_bdd7fc6ed5',
#  '3675825945_96b2916959',
#  '1557838421_a33f2a4911',
#  '544301311_5e7d69a517',
#  '3624076529_9793655a21',
#  '537479916_c033897fac',
#  '2737729252_b3fd9c05b1',
#  '267162122_c3437414ec',
#  '2592711202_55f8c64495',
#  ...]

# %%
# TestImagesFile
#f = open("flicker8k-dataset/Flickr8k_text/Flickr_8k.testImages.txt")

f = open("flickr_dataset/Flickr8k_text/Flickr_8k.testImages.txt")
test = f.read()
f.close()

# %%
test  = [e.split(".")[0] for e in test.split("\n")[:-1]]

# %%
# create train_descriptions dictionary, which will be similar to earlier one, but having only train samples
# add startseq + endseq 

train_descriptions = {}

for t in train:
    train_descriptions[t] = []
    for cap in descriptions[t]:
        cap_to_append = "startseq " + cap + " endseq"
        train_descriptions[t].append(cap_to_append)

# %%
train_descriptions
# Out:
# {'2513260012_03d33305cf': ['startseq black dog is running after white dog in the snow endseq',
#   'startseq black dog chasing brown dog through snow endseq',
#   'startseq two dogs chase each other across the snowy ground endseq',
#   'startseq two dogs play together in the snow endseq',
#   'startseq two dogs running through low lying body of water endseq'],
#  '2903617548_d3e38d7f88': ['startseq little baby plays croquet endseq',
#   'startseq little girl plays croquet next to truck endseq',
#   'startseq the child is playing croquette by the truck endseq',
#   'startseq the kid is in front of car with put and ball endseq',
#   'startseq the little boy is playing with croquet hammer and ball beside the car endseq'],
#  '3338291921_fe7ae0c8f8': ['startseq brown dog in the snow has something hot pink in its mouth endseq',
#   'startseq brown dog in the snow holding pink hat endseq',
#   'startseq brown dog is holding pink shirt in the snow endseq',
#   'startseq dog is carrying something pink in its mouth while walking through the snow endseq',
#   'startseq dog with something pink in its mouth is looking forward endseq'],
#  '488416045_1c6d903fe0': ['startseq brown dog is running along beach endseq',
#   'startseq brown dog wearing black collar running across the beach endseq',
#   'startseq dog walks on the sand near the water endseq',
#   'startseq brown dog running on the beach endseq',
#   'startseq the large brown dog is running on the beach by the ocean endseq'],
#  '2644326817_8f45080b87': ['startseq black and white dog with red frisbee standing on sandy beach endseq',
#   'startseq dog drops red disc on beach endseq',
#   'startseq dog with red frisbee flying in the air endseq',
#   'startseq dog catching red frisbee endseq',
#   'startseq the black dog is dropping red disc on beach endseq'],
#  '218342358_1755a9cce1': ['startseq cyclist wearing red helmet is riding on the pavement endseq',
#   'startseq girl is riding bike on the street while wearing red helmet endseq',
#   'startseq person on bike wearing red helmet riding down street endseq',
#   'startseq woman wears red helmet and blue shirt as she goes for bike ride in the shade endseq',
#   'startseq person in blue shirt and red helmet riding bike down the road endseq'],
#  '2501968935_02f2cd8079': ['startseq man dressed in purple shirt and red bandanna smiles at the people watching him endseq',
#   'startseq man on the street wearing leather chaps and chainmail codpiece endseq',
#   'startseq man wearing purple shirt and black leather chaps poses for the camera endseq',
#   'startseq man dressed in leather chaps and purple shirt stands in front of onlookers endseq',
#   'startseq there is man in purple shirt leather chaps and red bandanna standing near other men endseq'],
#  '2699342860_5288e203ea': ['startseq boy wearing red shirt is running through woodland endseq',
#   'startseq child runs near some trees endseq',
#   'startseq young boy is dancing around endseq',
#   'startseq young boy with red short sleeved shirt and jeans runs by some trees endseq',
#   'startseq the little boy in the red shirt stops to smile for the camera endseq'],
#  '2638369467_8fc251595b': ['startseq girl in white dress endseq',
#   'startseq little girl in white is looking back at the camera while carrying water grenade endseq',
#   'startseq smiling young girl in braids is playing ball endseq',
#   'startseq young girl wearing white looks at the camera as she plays endseq',
#   'startseq the girl is holding green ball endseq'],
#  '2926786902_815a99a154': ['startseq skier in yellow jacket is airborne above the mountains endseq',
#   'startseq skier jumps high in the air with view of the mountains endseq',
#   'startseq skiing man in fluorescent jacket jumps very high and it looks as though he is flying endseq',
#   'startseq somone is high in the air doing ski jump endseq',
#   'startseq the skier in the green jacket and white pants appears to almost fly into the sky endseq'],
#  '2851304910_b5721199bc': ['startseq photographer looks over the hills endseq',
#   'startseq woman in red jacket is videotaping natural landscape endseq',
#   'startseq woman with camera looks out over rolling hills endseq',
#   'startseq woman with camera on tripod is looking at the view endseq',
#   'startseq lady in red shirt has her camera set up in the field to record something endseq'],
#  '3423802527_94bd2b23b0': ['startseq bunch of girls in cheerleader outfits endseq',
#   'startseq large group of cheerleaders walking in parade endseq',
#   'startseq cheerleaders perform endseq',
#   'startseq many cheerleaders wearing black walk down the street endseq',
#   'startseq parade of cheerleaders wearing black pink and white uniforms endseq'],
#  '3356369156_074750c6cc': ['startseq blue boat with yellow canopy is floating on calm waters endseq',
#   'startseq boat in the water endseq',
#   'startseq boat with roof on green water endseq',
#   'startseq the boat is in the middle of the water endseq',
#   'startseq the solitude boat floats on the lake endseq'],
#  '2294598473_40637b5c04': ['startseq dog catches frisbee in midair endseq',
#   'startseq dog catching frisbee endseq',
#   'startseq terrier mix catches frisbee in the air endseq',
#   'startseq white and black dog catching frisbee endseq',
#   'startseq white dog is leaping in the air with green object in its mouth endseq'],
#  '1191338263_a4fa073154': ['startseq little old lady sitting next to an advertisement endseq',
#   'startseq an asian woman waiting at an underground train stop endseq',
#   'startseq an old woman sits in transit station next to backlit advertisement endseq',
#   'startseq woman sits in subway station endseq',
#   'startseq woman with an umbrella is sitting at station with an aquos commercial on the wall endseq'],
#  '2380765956_6313d8cae3': ['startseq blond girl wearing green jacket walks on trail along side metal fence endseq',
#   'startseq girl in green coat walks down rural road playing flute endseq',
#   'startseq young girl in parka playing flute while walking by fenced in field endseq',
#   'startseq girl in green and blue jacket walking past an enclosed field endseq',
#   'startseq girl playing flute as she walks by fence in rural area endseq'],
#  '3197891333_b1b0fd1702': ['startseq family of nine people including four children pose in front of brick fireplace with white mantle endseq',
#   'startseq family poses in front of the fireplace and christmas tree endseq',
#   'startseq family posing by the mantle and christmas tree endseq',
#   'startseq happy family poses by the fireplace endseq',
#   'startseq two couples and four kids pose for family picture endseq'],
#  '3119887967_271a097464': ['startseq man in sweater pointing at the camera endseq',
#   'startseq one man is posing with arms outstretched and finger pointed while another stares from behind him endseq',
#   'startseq the man in the black hat stands behind the man who is pointing his finger endseq',
#   'startseq two men look toward the camera while the one in front points his index finger endseq',
#   'startseq two men one wearing black hat while the one in front points standing in hallway endseq'],
#  '2276499757_b44dc6f8ce': ['startseq dog looks warily at the brown dog investigating his area endseq',
#   'startseq large brown dog is looking at medium sized black dog endseq',
#   'startseq small black dog looks at larger brown dog in grassy field endseq',
#   'startseq the big brown dog looks at the small black dog in tall grass endseq',
#   'startseq there is big dog looking at little dog endseq'],
#  '2506892928_7e79bec613': ['startseq three children in field with white flowers endseq',
#   'startseq three children one with stuffed kitten in field of flowers endseq',
#   'startseq three children play in the garden endseq',
#   'startseq three children pose among wildflowers endseq',
#   'startseq three kids palying with toy cat in garden endseq'],
#  '2187222896_c206d63396': ['startseq boy in red shirt in front of long blue wall raises his eyebrow at the camera endseq',
#   'startseq boy in red shirt with stripes standing near blue brick wall with handicap signs endseq',
#   'startseq an african american boy stands in front of blue building in the handicapped space endseq',
#   'startseq the boy in the orange shirt looks backwards endseq',
#   'startseq the boy in the red shirt is next to blue wall endseq'],
#  '2826769554_85c90864c9': ['startseq brown dog is carrying wet stick on the shore of the ocean endseq',
#   'startseq dog bounds across the sandy beach with stick in his mouth and water splashing off his paws endseq',
#   'startseq wet blond dog carries stick on the shore endseq',
#   'startseq the dog is running along the beach next to the ocean with stick in its mouth endseq',
#   'startseq the wet brown dog has stick in his mouth and is running in the sand next to the water endseq'],
#  '3097196395_ec06075389': ['startseq two dogs are racing on ractrack endseq',
#   'startseq two dogs race across the track endseq',
#   'startseq two greyhounds race endseq',
#   'startseq two greyhounds with muzzles race along the inside curb of railed dirt track endseq',
#   'startseq two racing dogs run around track endseq'],
#  '3603116579_4a28a932e2': ['startseq baseball pitcher with shelton on his shirt throws the ball endseq',
#   'startseq baseball player in black and orange shirt and with glove on pitches the ball endseq',
#   'startseq male dressed in sports outfit tries to catch baseball endseq',
#   'startseq man playing baseball endseq',
#   'startseq the baseball player is running after the ball endseq'],
#  '3339263085_6db9fd0981': ['startseq brown dog wades through water and walks toward rock endseq',
#   'startseq dog has waded through shallow water to reach rock outcropping endseq',
#   'startseq light brown dog is splashing in the water with its paw endseq',
#   'startseq small brown dog is about ready to exit the water after swim endseq',
#   'startseq yellow dog in shallow water endseq'],
#  '2532262109_87429a2cae': ['startseq group of girls in school uniforms are standing together and waiting to cross the street while one girl takes picture endseq',
#   'startseq group of people are standing together outside as one takes photograph endseq',
#   'startseq group of school girls are standing together while one is taking pictures endseq',
#   'startseq group of young women stand together endseq',
#   'startseq girls in school uniforms endseq'],
#  '2076906555_c20dc082db': ['startseq boy wearing jean jacket with his hand on his chest smiling at the camera endseq',
#   'startseq boy with bruised nose and writing on his hands is standing in video rental store endseq',
#   'startseq boy with writing on his hand is standing in store endseq',
#   'startseq young man in jean jacket smiles for the camera inside store endseq',
#   'startseq young man with denim jacket and writing on his hand smiles in front of bookcase full of videos endseq'],
#  '2502007071_82a8c639cf': ['startseq group of people in front of house endseq',
#   'startseq man in stripes woman in sunglasses and child in blue hat in front of brick building endseq',
#   'startseq woman in sunglasses and blue flowered shirt stands while boy and man sit nearby endseq',
#   'startseq woman wearing sunglasses and flowered shirt looks to the left endseq',
#   'startseq three adults and one child are waiting outside of building perhaps school endseq'],
#  '3113769557_9edbb8275c': ['startseq woman stands in front of display case and another woman looks at digital camera endseq',
#   'startseq woman stands tall in front of glass display while another woman takes picture of something endseq',
#   'startseq woman stands with her arms out at her sides while another takes picture endseq',
#   'startseq woman stands with her arms out in store while another woman holds camera endseq',
#   'startseq one woman is taking picture and another woman is standing sideways with her arm out endseq'],
#  '3325974730_3ee192e4ff': ['startseq snowboarder jumps high into the air off of snowy ramp endseq',
#   'startseq snowboarder jumps off ramp endseq',
#   'startseq man on snowboard performing trick high in the air endseq',
#   'startseq person in purple coat making jump on snowboard endseq',
#   'startseq snowboarder jumps off high ramp over icy landscape endseq'],
#  '1655781989_b15ab4cbff': ['startseq group of mountain climbers endseq',
#   'startseq group of people walking in line through the snow toward mountain endseq',
#   'startseq line of people are making their way through snow covered mountains endseq',
#   'startseq people are walking through snow covered field with mountain the background endseq',
#   'startseq people facing mountains in the snow endseq'],
#  '1662261486_db967930de': ['startseq black and white dog is jumping through black and white hoop endseq',
#   'startseq black and white dog jumps through black and white hoop endseq',
#   'startseq brown and white dog jumping through black and white hoop endseq',
#   'startseq dog jumping through black and white hoop endseq',
#   'startseq dog jumping through ring endseq'],
#  '2410562803_56ec09f41c': ['startseq girl using laptop another girl and boy looking at his cellphone endseq',
#   'startseq group of people sit against building and use electronics endseq',
#   'startseq three people sit near street endseq',
#   'startseq three people sitting in front of store on bench endseq',
#   'startseq three young people sit outside and engage with electronic devices endseq'],
#  '2469498117_b4543e1460': ['startseq dog races while wearing number endseq',
#   'startseq greyhound wearing muzzle and the number six on yellow jacket is running on dog track endseq',
#   'startseq muzzle greyhound dog running on track endseq',
#   'startseq tan greyhound wearing gold shirt with number on it runs down track endseq',
#   'startseq muxzzled greyhound leaping in race with yellow jacket endseq'],
#  '69710415_5c2bfb1058': ['startseq group of people stand at the edge of cliff over the ocean endseq',
#   'startseq group of three boy scouts rest on bluff overlooking the ocean endseq',
#   'startseq three men stand on cliff overlooking lake endseq',
#   'startseq three scouts are on top of cliff overlooking the ocean endseq',
#   'startseq two men are sitting on rock near the ocean with another man standing nearby endseq'],
#  '3414734842_beb543f400': ['startseq couple holding hands and another woman are walking down wooded trail endseq',
#   'startseq couple holding hands and woman standing beside them pose on tree lined dirt road endseq',
#   'startseq three friends on stroll in the forest endseq',
#   'startseq three people stand on path through the woods endseq',
#   'startseq two women and man posing on rural path endseq'],
#  '3006217970_90b42e6b27': ['startseq car sponsored by riwal is smoking its tires on wet road endseq',
#   'startseq race car drives along track in the rain endseq',
#   'startseq racing car is driving around wet track with its headlights on endseq',
#   'startseq small race car with advertising is driving on rainy track endseq',
#   'startseq sponsored race car is driving with lights on wet raceway endseq'],
#  '2192411521_9c7e488c5e': ['startseq bearded man wearing bandanna is pointing his finger whilst riding bicycle endseq',
#   'startseq man bicycles down the street and points his finger endseq',
#   'startseq man holds an object with his hand while riding his bike down the street endseq',
#   'startseq man with long hair riding bicycle gives the peace sign endseq',
#   'startseq man in blue shirt and black cap riding bike down street flashing peace sign endseq'],
#  '3535879138_9281dc83d5': ['startseq crowd of people waving red flags are passing under bridge endseq',
#   'startseq group of people walk down the street carrying red flags endseq',
#   'startseq large group of people walking down street some carrying flags or banners endseq',
#   'startseq many people walking together on pavement near brick building with other people looking on endseq',
#   'startseq many people walk in the street endseq'],
#  '2685788323_ceab14534a': ['startseq man in sunglasses gets ready to pull chair out to sit down for his meal endseq',
#   'startseq man wearing sunglasses stands by table at cafe endseq',
#   'startseq man about to pull out chair and sit down at restaurant endseq',
#   'startseq man at eatery getting ready to sit down endseq',
#   'startseq the large man grabs seat at restaurant endseq'],
#  '3465606652_f380a38050': ['startseq boy holding racket is standing in the grass endseq',
#   'startseq boy in purple shirt and blue jeans is standing in the grass holding round toy with handle endseq',
#   'startseq boy playes with stringless racket in his backyard endseq',
#   'startseq boy walks through the lawn endseq',
#   'startseq child in purple clothing is playing with toy inside yard with other toys and fence endseq'],
#  '2599131872_65789d86d5': ['startseq two blond girls are playing together endseq',
#   'startseq two girls enjoy themselves whilst wind blows through their hair endseq',
#   'startseq two girls with long hair jumping on trampoline endseq',
#   'startseq two little blonde girls twirl their hair endseq',
#   'startseq two little girls are playing on trampoline endseq'],
#  '2244613488_4d1f9edb33': ['startseq four bicyclists ride along dirt road between two wire fences endseq',
#   'startseq four cyclists on country trail are passing by an electricity pylon endseq',
#   'startseq the four bicyclists are riding through the desert endseq',
#   'startseq three bikers bike across the dry land endseq',
#   'startseq three cyclists ride near mountain endseq'],
#  '2738077433_10e6264b6f': ['startseq dog climbing steep dirt hill endseq',
#   'startseq dog climbs hill endseq',
#   'startseq great dane climbing steep hill endseq',
#   'startseq light brown dog is running up endseq',
#   'startseq light dog climbing wall of dirt endseq'],
#  '3537201804_ce07aff237': ['startseq child spins on merry go round endseq',
#   'startseq childern are playing on merry go round as adults on bench watch them endseq',
#   'startseq children play on merry go round as adults look on from bench endseq',
#   'startseq fathers watch as their children enjoy the spinning merry go round endseq',
#   'startseq two kids sit in the middle of playground toy that spins around them endseq'],
#  '1597557856_30640e0b43': ['startseq brown dog is jumping up at woman who is wearing brown skirt endseq',
#   'startseq golden retriever is excitedly greeting woman as little dog walks towards the camera endseq',
#   'startseq tan dog jumping up at woman in skirt and black and tan dog walking away endseq',
#   'startseq yellow dog jumps to greet woman endseq',
#   'startseq one dog is jumping at the lady while the other walks away endseq'],
#  '3357194782_c261bb6cbf': ['startseq man in the dooorway of bus looking onward endseq',
#   'startseq man standing at the door of vehicle with another sitting glancing out the window endseq',
#   'startseq people ride bus or trolley endseq',
#   'startseq some people riding an old bus endseq',
#   'startseq three passengers on train car endseq'],
#  '3682038869_585075b5ff': ['startseq little girl is peaking out from behind tree endseq',
#   'startseq little girl peering out from behind tree endseq',
#   'startseq young girl hiding behind tree in forest endseq',
#   'startseq young girl peeking out from behind tree in wooded area endseq',
#   'startseq young girl wearing striped dress peeks out from behind tree endseq'],
#  '236474697_0c73dd5d8b': ['startseq group of people hold drinks and point at the camera endseq',
#   'startseq group of people are holding up drinks and pointing to the camera endseq',
#   'startseq group of young people holding bottles and pointing at the camera endseq',
#   'startseq several young people posing for this photo holding beers endseq',
#   'startseq young adults stand pointing at the person taking the picture endseq'],
#  '2641288004_30ce961211': ['startseq border collie jumps over bed with tennis ball in its mouth endseq',
#   'startseq dog jumping with ball in its mouth endseq',
#   'startseq dog jumps on bed and catches green toy endseq',
#   'startseq border collie jumps in the air and catches tennis ball endseq',
#   'startseq the black and white dog jumps with tennis ball in its mouth endseq'],
#  '267164457_2e8b4d30aa': ['startseq climber walks along snowy peak endseq',
#   'startseq man climbs over snow covered rocks by shore endseq',
#   'startseq man is standing on snowcapped mountain endseq',
#   'startseq person hikes down snowy mountain endseq',
#   'startseq there man on top of an snow covered mountain with lake behind him endseq'],
#  '2453891449_fedb277908': ['startseq white dog chasing black dog across the grass endseq',
#   'startseq white dog is following black dog through the grassy area endseq',
#   'startseq there are two dogs black and white and the black one is jumping endseq',
#   'startseq two dogs running in grassy fenced in area surrounded by trees endseq',
#   'startseq two dogs running through yard with forest in the distance endseq'],
#  '281419391_522557ce27': ['startseq black race car spins its tires while smoke comes out endseq',
#   'startseq black race car starts up in front of crowd of people endseq',
#   'startseq broken down car during race endseq',
#   'startseq race car smoking very badly on the racetrack endseq',
#   'startseq red bull branded race car leaves smoke behind it in front of crowd endseq'],
#  '354999632_915ea81e53': ['startseq person behind some bags inside an igloo endseq',
#   'startseq snowy cave full of luggage endseq',
#   'startseq inside the igloo the young man gets ready for his overnight stay endseq',
#   'startseq some backpacks piled up in an ice cave with person dressed in black in the background endseq',
#   'startseq there is something visible through the hole in the wall endseq'],
#  '3109136206_f7d201b368': ['startseq brown dog drinks from body of water endseq',
#   'startseq brown dog is starting to walk into water endseq',
#   'startseq brown dog steps into murky water endseq',
#   'startseq dog getting into some water endseq',
#   'startseq dog putting his legs into pond endseq'],
#  '2281054343_95d6d3b882': ['startseq man wearing black hat is walking through busy city street endseq',
#   'startseq silhouette of man in hat on busy city street endseq',
#   'startseq person with black hat and black coat near buildings with signs endseq',
#   'startseq three people in crowded city area endseq',
#   'startseq thre is shot of man with his back turned in city endseq'],
#  '3296584432_bef3c965a3': ['startseq brown dog chases something man behind him threw on the beach endseq',
#   'startseq man and dog on the beach endseq',
#   'startseq man is interacting with dog that is running in the opposite direction endseq',
#   'startseq man playing fetch with his dog on beach endseq',
#   'startseq man walking behind running dog on the beach endseq'],
#  '3526431764_056d2c61dc': ['startseq woman taking photo standing next to tall man and in front of another man who is also taking photo endseq',
#   'startseq three people are outdoors taking pictures endseq',
#   'startseq three people holding cameras are standing on dirt trail with grass on the side of it endseq',
#   'startseq three people taking pictures with their cameras endseq',
#   'startseq two people are taking pictures while third is holding camera endseq'],
#  '3549997413_01388dece0': ['startseq man is skiing down mountain with another large mountain behind him and river between the mountains endseq',
#   'startseq man is skiing down snowy hill with large mountain in the background endseq',
#   'startseq man skiing down snow covered mountain endseq',
#   'startseq person skis down snowy mountain endseq',
#   'startseq skier goes down hill with mountain as backdrop endseq'],
#  '143688895_e837c3bc76': ['startseq boy climbing rock face endseq',
#   'startseq climber is standing on the rock face next to the pink rope endseq',
#   'startseq man climbing cliff with rope endseq',
#   'startseq man climbs steep rocks endseq',
#   'startseq man rock climbing in the forest surrounded by light endseq'],
#  '2495394666_2ef6c37519': ['startseq brown dog is standing in lake endseq',
#   'startseq brown dog is swimming in creek endseq',
#   'startseq dog swimming in pond endseq',
#   'startseq dog swimming in body of water endseq',
#   'startseq the brown dog is swimming in the water endseq'],
#  '3384742888_85230c34d5': ['startseq dog plays with toy in the grass endseq',
#   'startseq rotweiler playfully rolls over int he grass with toy endseq',
#   'startseq black and tan dog playing with toy and rolling on the grass endseq',
#   'startseq dog chewing up ball while rolling in grass endseq',
#   'startseq the dog is resting after game of fetch endseq'],
#  '1160034462_16b38174fe': ['startseq elderly man in straw hat is sitting on bench endseq',
#   'startseq elderly man sits alone on park bench endseq',
#   'startseq an old man in straw hat sits on park bench endseq',
#   'startseq the old man in the brown hat is sitting on the bench endseq',
#   'startseq white haired man in gray sweater and straw hat sitting on bench under tree endseq'],
#  '334768700_51c439b9ee': ['startseq dark haired man in red shirt with beard playing the guitar in park endseq',
#   'startseq man in red shirt plays guitar in park endseq',
#   'startseq man is sitting and playing guitar on the grass endseq',
#   'startseq man sitting in the grass playing his guitar wearing red shirt endseq',
#   'startseq man wearing red plays his guitar on the grass endseq'],
#  '412101267_7257e6d8c0': ['startseq two black dogs are jumping and playing with yellow tennis ball in the snow endseq',
#   'startseq two dog play in the snow endseq',
#   'startseq two dogs one with tennis ball in his mouth play together in the snow endseq',
#   'startseq two dogs playing with ball in the snow endseq',
#   'startseq two dogs play with tennis ball in the snow endseq'],
#  '2623939135_0cd02ffa5d': ['startseq an attractive woman holds halo above her head endseq',
#   'startseq woman in dress raises her arm over her head endseq',
#   'startseq woman is looking at the ceiling while taking off her hat endseq',
#   'startseq woman looking up towards wide ring she is holding over her head drink in her other hand endseq',
#   'startseq woman looking upward with her hand above her head endseq'],
#  '3043266735_904dda6ded': ['startseq an elderly person with white hat is reading paperback book endseq',
#   'startseq an elder woman in hat and scarf is looking through book she has in her hands endseq',
#   'startseq an older woman wearing hat reads book endseq',
#   'startseq an old lady consulting paperback book endseq',
#   'startseq woman in white hat reading book endseq'],
#  '3034585889_388d6ffcc0': ['startseq looker on catches motocross bike on its side after spill while another races by endseq',
#   'startseq man on dirt bike zipping away while another one slips to the ground and third man in yellow jacket looks on endseq',
#   'startseq man on motorcycle making tight turn endseq',
#   'startseq person is riding their motorbike and person in bright yellow jacket is watching someone fall off their bike endseq',
#   'startseq bike rider is looking at accident of other sports bike rider endseq'],
#  '2069279767_fb32bfb2de': ['startseq the men are climbing endseq',
#   'startseq two men are lying in red cots on the side of mountain endseq',
#   'startseq two men are sleeping on makeshift beds on the side of cliff endseq',
#   'startseq two men in cots hanging from cliff endseq',
#   'startseq two mountain climbers are smiling on the mountainside endseq'],
#  '2593406865_ab98490c1f': ['startseq skateboarder jumps off his skateboard in midair in hopes of landing back on it endseq',
#   'startseq teenage boy is performing trick with his skateboard endseq',
#   'startseq young man is flipping skateboard during trick endseq',
#   'startseq young skateboarder doing tricks in the air endseq',
#   'startseq the man is performing trick on skateboard near onlookers endseq'],
#  '432167214_c17fcc1a2d': ['startseq dark colored man is holding protest banner in busy city street with people staring from behind endseq',
#   'startseq man in blue and yellow jacket holding religious sign stands in street with people behind him on the sidewalk endseq',
#   'startseq man is holding religious poster endseq',
#   'startseq man wearing hat holding sign with writing on it endseq',
#   'startseq man standing on the street holding sign endseq'],
#  '305749904_54a612fd1a': ['startseq man is wearing blue shirt with the word mambo on it endseq',
#   'startseq man is wearing shirt that reads mambo with an image of baby and teddy bear endseq',
#   'startseq man wears shirt showing baby humping stuffed bear endseq',
#   'startseq person wearing blue mambo shirt has his back to the camera endseq',
#   'startseq the man is wearing blue shirt endseq'],
#  '2780087302_6a77658cbf': ['startseq man in black shirt sits on stool while trying to sell stuffed animals endseq',
#   'startseq man is outside selling various toys endseq',
#   'startseq vendor sells children toys as visitors walk by endseq',
#   'startseq vendor sells inflatable toys and stuffed animals on the sidewalk endseq',
#   'startseq man sits on stool beside toys endseq'],
#  '3051998298_38da5746fa': ['startseq guy in navy blue and yellow shorts jumping into pool endseq',
#   'startseq man catches football in midair while jumping into pool endseq',
#   'startseq man in swim trunks is jumping into pool while in strange pose endseq',
#   'startseq antics in covered pool endseq',
#   'startseq people are diving into swimming pool endseq'],
#  '1574401950_6bedc0d29b': ['startseq boy jumps from the top of blue plastic slide endseq',
#   'startseq child jumps over the slide portion of playground equipment shaded by trees endseq',
#   'startseq little boy in striped shirt jumps from blue slide endseq',
#   'startseq little boy is jumping off the top of slide endseq',
#   'startseq young boy jumps on slide in backyard endseq'],
#  '539493431_744eb1abaa': ['startseq man is playing with fire baton in the day light endseq',
#   'startseq man juggling fire endseq',
#   'startseq man stands near playground endseq',
#   'startseq man throws flames outside endseq',
#   'startseq the guy is holding black stick in front of playground endseq'],
#  '3524436870_7670df68e8': ['startseq brown dog playing with bubbles endseq',
#   'startseq brown dog walking across lawn as bubbles float by endseq',
#   'startseq dark brown dog is looking at bubbles while walking on green grass endseq',
#   'startseq dog catching bubbles on the grass endseq',
#   'startseq the brown dog is chasing and popping bubbles endseq'],
#  '2081446176_f97dc76951': ['startseq guy with scarf and woven toboggan endseq',
#   'startseq man in black and white cap and scarf endseq',
#   'startseq man wearing scarf and knitted hat is smiling endseq',
#   'startseq person wearing hat and scarf looks to the right endseq',
#   'startseq the man has poof on top of his woolen hat endseq'],
#  '2265367960_7928c5642f': ['startseq boy sitting down smiling for the picture endseq',
#   'startseq child holding some shoes endseq',
#   'startseq child in blue and wearing hat smiles endseq',
#   'startseq young boy smiling and holding sandals endseq',
#   'startseq the boy is wearing hat and holding sandals endseq'],
#  '460350019_af60511a3b': ['startseq black dog and woman in red shirt playing tug of war endseq',
#   'startseq dog is pulling on one end of rope and girl is pulling on the other endseq',
#   'startseq woman plays tug of war with her black dog in brown landscape surrounded by trees endseq',
#   'startseq woman plays with her rottweiler dog outside endseq',
#   'startseq woman and dog playing outside endseq'],
#  '2976946039_fb9147908d': ['startseq group of people surf on very large wave endseq',
#   'startseq group of surfers catching wave endseq',
#   'startseq people surfing and attempting to surf in the ocean on big wave endseq',
#   'startseq several people are surfing on wave in the sea endseq',
#   'startseq surfers on huge ocean wave at sunset endseq'],
#  '2308108566_2cba6bca53': ['startseq man rides bike on dirt path endseq',
#   'startseq person biking through the woods endseq',
#   'startseq person dirtbikes along muddy trail endseq',
#   'startseq dirt bike rider riding down the slope endseq',
#   'startseq person rides dirt bike down dirt hill endseq'],
#  '3367758711_a8c09607ac': ['startseq there are two women crossing the street in front of two buses endseq',
#   'startseq two women in headwraps are hurrying past buses endseq',
#   'startseq two women walk in front of bus to cross the road endseq',
#   'startseq two women walk on the street in front of two buses endseq',
#   'startseq two women with their heads covered crossing the road in front of buses endseq'],
#  '3666056567_661e25f54c': ['startseq group of people walk down city street at night endseq',
#   'startseq group of people walking down the street with one on the phone in green hat endseq',
#   'startseq four people are walking along city sidewalk while the one in the green hat talks on cellphone endseq',
#   'startseq four people are walking on sidewalk endseq',
#   'startseq four people walk down sidewalk at night endseq'],
#  '3099264059_21653e2536': ['startseq skateboarder is jumping almost as high as building endseq',
#   'startseq snowboarder jumping off tall brick building endseq',
#   'startseq snowboarder jumps over pile of snow endseq',
#   'startseq snowboarder jumps off rail over snowpile endseq',
#   'startseq the snowboarder is doing stunt high in the air at night endseq'],
#  '2988439935_7cea05bc48': ['startseq man in red soccer uniform getting ready to kick the ball endseq',
#   'startseq man in red uniform plays in soccer game endseq',
#   'startseq man in red uniform runs towards soccer ball on field endseq',
#   'startseq player in red uniform gets ready to kick the ball during soccer match as the crowd watches endseq',
#   'startseq soccer player in red uniform runs after soccer ball endseq'],
#  '241345864_138471c9ea': ['startseq boy cheerleader has girl cheerleader on his knee endseq',
#   'startseq female cheerleader sits on the knee of male cheerleader endseq',
#   'startseq cheerleaders taking break endseq',
#   'startseq the cheerleader in red and white is sitting on the knee of man also wearing red and white endseq',
#   'startseq two cheerleaders are sitting at football game endseq'],
#  '3019199755_a984bc21b1': ['startseq driver is at the wheel of race car endseq',
#   'startseq man inside red race car gives thumbs up sign endseq',
#   'startseq man is in red race car while another man is at the back of it endseq',
#   'startseq man is smiling whilst sitting inside red racing car endseq',
#   'startseq race car driver smiles and gives the thumbs up before race endseq'],
#  '3201594926_cd2009eb13': ['startseq girl wearing white polka dots and black boots walks and woman in blue outfit hurridly walks behind her endseq',
#   'startseq hip young woman down the street with woman in kimono walks behind her endseq',
#   'startseq woman in boots with big purse walks down the street followed by woman in blue endseq',
#   'startseq woman walks with her big purse endseq',
#   'startseq women walk down the street endseq'],
#  '2540751930_d71c7f5622': ['startseq man and woman walk away from the camera as redheaded man walks in the other direction endseq',
#   'startseq pedestrians walk on sidewalk next to grassy wooded field endseq',
#   'startseq people are walking around park area endseq',
#   'startseq people meandering around in grassy area with trees endseq',
#   'startseq young adults dressed casually walk around in field endseq'],
#  '1475046848_831245fc64': ['startseq blonde woman in blue shorts walks on the beach carrying her shoes endseq',
#   'startseq woman in blue shorts is carrying her shoes whilst walking on the beach next to the ocean endseq',
#   'startseq blond woman with blue shorts walks along beach carrying shoes in one hand endseq',
#   'startseq woman carrying her shoes on beach endseq',
#   'startseq woman in blue shorts walking barefoot on the beach endseq'],
#  '2877637572_641cd29901': ['startseq cute puppy fetches yellow ring chew toy in the yard endseq',
#   'startseq puppy is running across the grass with yellow toy in its mouth endseq',
#   'startseq tan dog is running through the grass with yellow toy in its mouth endseq',
#   'startseq tan dog with red collar runs with yellow toy in its mouth endseq',
#   'startseq fluffy golden puppy holding yellow rings in mouth while running through grass endseq'],
#  '1308472581_9961782889': ['startseq boy in blue shirt splashing in water under dock endseq',
#   'startseq laughing girl holding bucket splashes in the ocean endseq',
#   'startseq young girl plays under pier with blue bucket endseq',
#   'startseq girls with blue bucket is playing and splashing in the ocean water endseq',
#   'startseq the girl with the blue bucket splashes beneath the pier endseq'],
#  '2282260240_55387258de': ['startseq little girl dances in room with balloons on the floor endseq',
#   'startseq young girl dancing in her socks on wooden floor strewn with pink balloons endseq',
#   'startseq child with pink strings on head dancing surrounded by confetti balloons endseq',
#   'startseq little girl in brown shirt and bluejean skirt dances on wood floor endseq',
#   'startseq the blond girl is dancing inside house endseq'],
#  '2363419943_717e6b119d': ['startseq lady and her little girl are holding hands and walking up the sidewalk endseq',
#   'startseq mother and child run hand in hand through chinatown in an american city endseq',
#   'startseq woman and child both wearing red outfits walking up street endseq',
#   'startseq child in red holding the hand of person in red coat walking on sidewalk under awnings endseq',
#   'startseq woman and little girl wearing red in asian area endseq'],
#  '392976422_c8d0514bc3': ['startseq boy in blue shirt is walking along tan and blue wall endseq',
#   'startseq boy in stripes walking along ledge endseq',
#   'startseq boy scales the wall endseq',
#   'startseq child in striped shirt is walking along wall endseq',
#   'startseq boy in striped shirt walking along ledge endseq'],
#  '103205630_682ca7285b': ['startseq tent is being set up on the ice endseq',
#   'startseq two men are about to enter an ice fishing tent on snow covered lake endseq',
#   'startseq two men setting up blue ice fishing hut on an iced over lake endseq',
#   'startseq two men standing on an ice looking into something covered with blue tarp endseq',
#   'startseq two people standing outside blue tent structure on snowy surface endseq'],
#  '1347519824_e402241e4f': ['startseq few girls with green foam statue of liberty hats on train endseq',
#   'startseq some young adults are wearing green foam statute of liberty crowns endseq',
#   'startseq some young people take photos of each other while in new york endseq',
#   'startseq three woman with statue of liberty hats and taking picture endseq',
#   'startseq two woman wearing statue of liberty hats get their picture taken in subway endseq'],
#  '584484388_0eeb36d03d': ['startseq two brown dogs are playing with red ball endseq',
#   'startseq two brown dogs fight over red ball while playing in the grass endseq',
#   'startseq two brown dogs run over the grass carrying red toy endseq',
#   'startseq two daschunds play with red ball endseq',
#   'startseq two little wiener dogs are running on the grass carrying red ball between them endseq'],
#  '2460823604_7f6f786b1c': ['startseq boy baseball player in green and yellow jersey leaps for the ball endseq',
#   'startseq boy chasing baseball endseq',
#   'startseq little boy playing baseball goes for the ball on the ground endseq',
#   'startseq young boy dives to catch the ball during baseball game endseq',
#   'startseq the boy in the green and yellow shirt has glove on and is going towards the ball endseq'],
#  '121800200_bef08fae5f': ['startseq group of climbers begin up sheer rock face endseq',
#   'startseq group of rock climbers climb rock wall in forest endseq',
#   'startseq many people are climbing the mountain surrounded by pretty green trees endseq',
#   'startseq people at distance trying to climb cliff endseq',
#   'startseq the flat side of large rocky mountain endseq'],
#  '2422302286_385725e3cf': ['startseq child sits in plastic toy car endseq',
#   'startseq little kid in toy car endseq',
#   'startseq small girl riding in play car endseq',
#   'startseq there is child in red and yellow toy car endseq',
#   'startseq the small child is sitting in red and yellow toy car endseq'],
#  '3183883750_b6acc40397': ['startseq two girls hold up card reading know what this is endseq',
#   'startseq two kids smiling and holding card endseq',
#   'startseq two people pose for picure holding card that says know what this is endseq',
#   'startseq two people smile at the camera while holding sign endseq',
#   'startseq two teenage girls hold card referring to periods as they smile endseq'],
#  '3091912922_0d6ebc8f6a': ['startseq dog runs holding yellow dog toy in fall bench in the background endseq',
#   'startseq dog runs with yellow toy in its mouth endseq',
#   'startseq tan dog running through the grass with toy in his mouth endseq',
#   'startseq the brown dog is running through the grass with yellow toy in its mouth endseq',
#   'startseq the tan colored dog has yellow toy in its mouth endseq'],
#  '2787868417_810985234d': ['startseq blond girl in pink bathing suit running through the sprinklers endseq',
#   'startseq girl in pink runs through sprinkler endseq',
#   'startseq girl runs through sprinklers on lawn endseq',
#   'startseq little girl in pink in running through sprinkler endseq',
#   'startseq little girl wearing pink dress is running across the grass endseq'],
#  '3670075789_92ea9a183a': ['startseq child is sliding into small pool endseq',
#   'startseq girl in child swimming pool endseq',
#   'startseq little girl is sliding down short slide into an inflatable paddling pool endseq',
#   'startseq girl splashing in kiddie pool endseq',
#   'startseq the dark haired girl is sliding into white kiddie pool endseq'],
#  '3329169877_175cb16845': ['startseq lone snowboarder wearing white jacket jumping into the air on the snowy mountains endseq',
#   'startseq snowboarder flies through the air in front of leafless trees endseq',
#   'startseq snowboarder gets some air endseq',
#   'startseq snowboarder in green pants and white jacket is jumping high in the air endseq',
#   'startseq someone in green pants is on white snowboard in the air endseq'],
#  '751074141_feafc7b16c': ['startseq boy being pulled on shovel endseq',
#   'startseq happy child play in the scoop of shovel by chair in grassy backyard endseq',
#   'startseq little boy in red flowered shorts is sitting on shovel endseq',
#   'startseq little boy smiling and riding in shovel endseq',
#   'startseq small boy in red shorts with blue flowers sitting on shovel in the grass near tan chair endseq'],
#  '3445428367_25bafffe75': ['startseq person is standing on brick ledge taking picture of something in the distance endseq',
#   'startseq woman takes photograph endseq',
#   'startseq woman with long hair pointing her camera skyward as she stands on brick wall endseq',
#   'startseq the woman is holding camera and standing on brick wall endseq',
#   'startseq woman standing on brick wall and taking picture endseq'],
#  '3542418447_7c337360d6': ['startseq black dog and brown dog with yellow foam soccer ball toy on grassy field endseq',
#   'startseq brown dog and black dog playing with yellow soccer ball endseq',
#   'startseq two dogs on lawn play with plastic toy in distorted photograph endseq',
#   'startseq two dogs one brown one black with yellow toy black dog has mouth open and brown dog has the toy endseq',
#   'startseq two dogs run to catch yellow soccer ball endseq'],
#  '2730819220_b58af1119a': ['startseq little girl ends up at the bottom of the slide endseq',
#   'startseq little girl is just reaching the bottom of playground slide endseq',
#   'startseq little girl lands at the bottom of slide endseq',
#   'startseq young girl reaches the bottom of slide endseq',
#   'startseq young girl sliding down tan plastic slide endseq'],
#  '3543378438_47e2712486': ['startseq man dressed in green jacket is playing piano while woman sings endseq',
#   'startseq man is sitting in front of harpsichord and woman is preparing to sing endseq',
#   'startseq person playing the piano with singer nearby endseq',
#   'startseq pianist and singer are ready to perform endseq',
#   'startseq the man in the green jacket is playing the piano next to woman who is by music stand endseq'],
#  '2335619125_2e2034f2c3': ['startseq big black dog bares its teeth while running through the snow endseq',
#   'startseq black dog is running through the snow endseq',
#   'startseq black dog is running through the snow endseq',
#   'startseq black dog with his mouth open and tongue out runs across an expanse of snow endseq',
#   'startseq black dog runs through snow endseq'],
#  '3520199925_ca18d0f41e': ['startseq curly haired woman plays the violin endseq',
#   'startseq red haired woman is holding violin and boe endseq',
#   'startseq woman is playing violin while surrounded by transparent walls and pictures endseq',
#   'startseq woman playing the violin with posters in the background endseq',
#   'startseq the woman is holding violin endseq'],
#  '3374722123_6fe6fef449': ['startseq an elderly woman is wearing pink striped shirt endseq',
#   'startseq an older woman in pink striped shirt endseq',
#   'startseq an older woman with striped shirt rubbing her chin endseq',
#   'startseq woman in pink striped shirt with her hand up endseq',
#   'startseq older lady is appears to be getting ready to cover her mouth endseq'],
#  '3280672302_2967177653': ['startseq boy carries teenager on his back endseq',
#   'startseq boy struggles to carry girl on his back endseq',
#   'startseq person wearing black shirt is getting piggy back ride from person wearing black shirt walkng on paved path in the woods endseq',
#   'startseq teenage boy gives another teenage boy piggy back ride in forest endseq',
#   'startseq the boy is carrying the other boy endseq'],
#  '3073579130_7c95d16a7f': ['startseq man wears red bandanna endseq',
#   'startseq man with head covering endseq',
#   'startseq an man wearing an arab scarf with another man in the background endseq',
#   'startseq white man in turban endseq',
#   'startseq man with facial hair wearing red and white palestinian style headscarf endseq'],
#  '99679241_adc853a5c0': ['startseq grey bird stands majestically on beach while waves roll in endseq',
#   'startseq large bird stands in the water on the beach endseq',
#   'startseq tall bird is standing on the sand beside the ocean endseq',
#   'startseq water bird standing at the ocean edge endseq',
#   'startseq white crane stands tall as it looks out upon the ocean endseq'],
#  '3759492488_592cd78ed1': ['startseq boy hanging onto pole endseq',
#   'startseq kid in green shirt playing in the park endseq',
#   'startseq little kid swings on pole at playground endseq',
#   'startseq the boy in the green shirt swings with one arm on the silver pole endseq',
#   'startseq the boy is swinging on pole at the beach endseq'],
#  '2875528143_94d9480fdd': ['startseq girl wearing pink bounces on bed endseq',
#   'startseq little girl in pink leotard is jumping and landing in straddle split on blue bed endseq',
#   'startseq young girl jumping with her mouth open endseq',
#   'startseq little girl in pink hello kitty shirt is jumping endseq',
#   'startseq the girl in pink does midair leg splits endseq'],
#  '1052358063_eae6744153': ['startseq boy takes jump on his skateboard while another boy with skateboard watches endseq',
#   'startseq child is performing skateboard trick while another child with skateboard leans on wall endseq',
#   'startseq little boy skateboarder is doing trick on his board while another young skateboarder watches endseq',
#   'startseq young boy skateboarder jumping on platform on skateboard endseq',
#   'startseq two skateboarders endseq'],
#  '111766423_4522d36e56': ['startseq black and white bird eating seeds out of someone hand endseq',
#   'startseq black and white bird standing on hand endseq',
#   'startseq small bird sits in person hand and eats seeds endseq',
#   'startseq black and white bird standing on hand of someone holding sunflower seeds endseq',
# ...
#  '2546667441_bbe87a6285': ['startseq black dog is walking along the grass sniffing at the ground endseq',
#   'startseq black dog running in the grass endseq',
#   'startseq dog sniffs the grass endseq',
#   'startseq black dog on grass sniffing the ground endseq',
#   'startseq black dog with tan markings wearing blue collar standing on green grass endseq'],
#  '1301140633_046e4e8010': ['startseq boy in blue shirt with dirt on his face endseq',
#   'startseq boy with dirty face smiles endseq',
#   'startseq child with dirty face looks at the camera and smiles endseq',
#   'startseq blond child with dirty face holding yellow bottle with red cap plants in background endseq',
#   'startseq the boy has blonde hair and dirty face endseq'],
#  '458735196_176e7df6b3': ['startseq brown dog indoors with large pink toy endseq',
#   'startseq dog with wrinkled face bites on pink toy endseq',
#   'startseq wrinkled dog playing with pink chew toy endseq',
#   'startseq the dog is carrying pink ball in its mouth endseq',
#   'startseq this is strange sight dog delivering cookie endseq'],
#  '3304712466_18cbdb85fe': ['startseq bicycle racers being cheered on by some people endseq',
#   'startseq bicycle road racers passing group of cheering spectators endseq',
#   'startseq crowds cheer on cyclists as they complete race to the finish endseq',
#   'startseq people on bicycles riding through group of onlookers endseq',
#   'startseq racers on bikes riding past crowd endseq'],
#  '2721656220_5f4cda8bc1': ['startseq lady holds beverage endseq',
#   'startseq an attractive brunette woman smiles and holds beverage in front of her endseq',
#   'startseq woman holding drink and smiling endseq',
#   'startseq woman holds drink and smiles endseq',
#   'startseq this woman is wearing white shirt and holding cup endseq'],
#  '1253275679_e955fb7304': ['startseq boy has his head down and is wearing shirt that says adhd endseq',
#   'startseq young boy wearing clever black and white shirt with his head bowed down endseq',
#   'startseq the boy is wearing black shirt with an ad parody of the ac logo endseq',
#   'startseq young boy wearing an ac shirt looking down endseq',
#   'startseq young boy with black adhd shirt nodding off endseq'],
#  '3668984985_b60ceb2ae9': ['startseq family sits on bench in front of pool endseq',
#   'startseq few couples sitting on beanches next to pool endseq',
#   'startseq girl wearing boots stands next to swimming pool and four people seated on bench endseq',
#   'startseq group of people talking next to pool with trees in the background endseq',
#   'startseq people sit on bench by the pool endseq'],
#  '3241726740_6d256d61ec': ['startseq man smoking cigarette talking to lady who is sitting on steps endseq',
#   'startseq lady in black standing and smoking with another girl sitting on the steps endseq',
#   'startseq the person in black smoked while the woman in brown sat on the steps endseq',
#   'startseq the woman in the black coat is smoking and the woman in the gray coat sits on stone steps endseq',
#   'startseq two women smoking on the steps of white building endseq'],
#  '310213587_778fe8fb5b': ['startseq group of people sitting on benches at city park endseq',
#   'startseq man drinking beverage and holding plastic bag far away from the other people endseq',
#   'startseq man drinking soda is standing in front of bench near group of people sitting endseq',
#   'startseq man in black clothes and blue hat is taking drink and holding shopping bag endseq',
#   'startseq man is standing next to bench drinking soda while other people sit on bench nearby endseq'],
#  '2974501005_346f74e5d8': ['startseq boy does skateboard jump at skateboard park endseq',
#   'startseq kid doing trick on his skateboard endseq',
#   'startseq young boy is performing tricks with skateboard at skate park endseq',
#   'startseq young man rides yellow and black skateboard at the top of ramp endseq',
#   'startseq kid doing skateboard trick with his legs split and board between them endseq'],
#  '3716277216_c04002be81': ['startseq three african american women are dressed in bright orange and brown dresses and head scarves endseq',
#   'startseq three african women in traditional orange costume are gathered in front of yellow curtain endseq',
#   'startseq three women are dressed in african clothes and two of them are putting on make up endseq',
#   'startseq three women wearing traditional apparel make the final touches on their clothing endseq',
#   'startseq women are putting their robes and headdresses on endseq'],
#  '3320209694_db579cb607': ['startseq man in purple had climbs rocky wall with his hands endseq',
#   'startseq man with purple hat is climbing rock endseq',
#   'startseq man with purple hat and bandaged hand climbs wall of rock endseq',
#   'startseq young man in purple snow cap is rock climbing endseq',
#   'startseq this young man is rock climbing endseq'],
#  '3368865171_597d51cdd5': ['startseq child rides unicycle while crowd watches endseq',
#   'startseq little girl rides on bicycle during parade endseq',
#   'startseq small girl riding unicycle endseq',
#   'startseq girl in plaid shirt riding unicycle endseq',
#   'startseq person in checked shirt riding unicycle while crowd watches endseq'],
#  '124881487_36e668145d': ['startseq man on bicycle riding down rocky hill endseq',
#   'startseq man rides his dirt bike down rocky trail endseq',
#   'startseq person rides bike down rocky hill endseq',
#   'startseq blurry picture of mountain biker descending rocky trail endseq',
#   'startseq the mountain biker in blue rides down rocky path endseq'],
#  '2701603045_6cbdc4ce7c': ['startseq boy is wading through water endseq',
#   'startseq boy up to his knees in water endseq',
#   'startseq boy wearing white shorts walks through the water endseq',
#   'startseq young boy with white swim trunks walks out of the water endseq',
#   'startseq the boy is wading through the blue ocean endseq'],
#  '2278766574_f71f1704a8': ['startseq youn woman on man back walking down cement path with another couple behind them holding hands endseq',
#   'startseq people walk on path outside endseq',
#   'startseq several people are walking down trail endseq',
#   'startseq the man is giving woman piggyback ride through park endseq',
#   'startseq two couples walking on path adorned with trees bushes and grass endseq'],
#  '347543966_b2053ae78c': ['startseq group of men stand outside glass and steel building endseq',
#   'startseq three men are looking at wall very intently in city endseq',
#   'startseq three men stand in glass area endseq',
#   'startseq three people in glass structure endseq',
#   'startseq three people stand in an outdoor glass structure endseq'],
#  '1143882946_1898d2eeb9': ['startseq lady wearing helmet holding bike endseq',
#   'startseq woman in blue vest and sky blue helmet stands with her bicycle in traffic endseq',
#   'startseq woman in helmet rides her bike behind car endseq',
#   'startseq woman with helmet and backpack walks next to her bike endseq',
#   'startseq women with bike and helmet wait for traffic endseq'],
#  '2029280005_a19609c81a': ['startseq man in black shirt is rollerblading past bench in the city endseq',
#   'startseq man is inline skating in front of wooden bench endseq',
#   'startseq man is wearing rollerblades standing on paved area near park bench endseq',
#   'startseq man on rollerblades travelling down the sidewalk endseq',
#   'startseq man wearing black shirt and brown pants skates on concrete surface near park bench endseq'],
#  '3231751379_10ebf7150c': ['startseq goalie is crouching in defensive position in front of the goal endseq',
#   'startseq hockey player in blue and red guarding the goal endseq',
#   'startseq an ice hockey goalkeeper in red and blue strip is on his knees in front of the goal endseq',
#   'startseq an ice hockey player is bending down on the ice endseq',
#   'startseq the hockey player knelt on the ice endseq'],
#  '3069216757_c419b3898e': ['startseq girl in pink striped shirt is in front of an armoire endseq',
#   'startseq girl in pink striped shirt poses for the camera endseq',
#   'startseq girl wearing pink striped shirt throws her arms into the air endseq',
#   'startseq young girl wearing pink and orange stripped shirt extends her arms forward and appears to be happy endseq',
#   'startseq the girl wearing the pink striped shirt is standing in the doorway with her arm outstretched endseq'],
#  '3234719720_5bb2fc5ffa': ['startseq dark haired bearded man in white dress shirt and black sweater and woman in black and white dress in small space endseq',
#   'startseq man and women both in black and white are in an elevator endseq',
#   'startseq man with large beard and woman wearing white necklace smile endseq',
#   'startseq nicely dressed woman and bearded man in small room endseq',
#   'startseq smiling man leaning to his right stands behind smiling woman leaning to her left endseq'],
#  '491964988_414b556228': ['startseq little girl runs down path in japanese garden endseq',
#   'startseq little girl skips down path near an idyllic country pond endseq',
#   'startseq young girl hops on the path to avoid the puddles located near lake endseq',
#   'startseq young girl is jumping on gravel road near pond endseq',
#   'startseq the girl runs near pond endseq'],
#  '2474047296_fd9179d438': ['startseq man in white shirt and dress pants sits just underneath stone archway endseq',
#   'startseq man wearing white shirt and black pants sitting on staircase endseq',
#   'startseq an old man sits in an ancient brick archway endseq',
#   'startseq an old man with white shirt and black pants sits on chair in the opening of stone tunnel endseq',
#   'startseq elderly man sitting in doorway endseq'],
#  '3546891929_f31a99cd0d': ['startseq man in bicycle helmet is talking on cellphone with other people behind him endseq',
#   'startseq man in helmet holding cellphone endseq',
#   'startseq man in plaid shirt with red and black bike helmet on his cellphone endseq',
#   'startseq man wearing red bicycle helmet talking on cellphone with other people in the background endseq',
#   'startseq man with bicycle helmet on is using cellphone in the midst of crowd endseq'],
#  '2355763034_9fb61a8165': ['startseq flautist plays the flute in marching band endseq',
#   'startseq girl in band is playing the flute endseq',
#   'startseq girl in red and black uniform is playing the flute as part of marching band endseq',
#   'startseq woman in red uniform is playing the flute endseq',
#   'startseq girl in uniform playing flute with marching band endseq'],
#  '3065560742_f6e266ccd9': ['startseq boy playing hockey lies on the ice injured endseq',
#   'startseq the two hockey players are down on the ice endseq',
#   'startseq two hockey players fall on the ice endseq',
#   'startseq two hockey players fall to the ground in game endseq',
#   'startseq two hockey players slide into each other on the ice endseq'],
#  '265528702_8653eab9fa': ['startseq man in sunglasses and neatly trimmed beard overlooks woody valley endseq',
#   'startseq man posing with large grassy mountains off in the distance endseq',
#   'startseq man wearing sunglasses stands before forested landscape endseq',
#   'startseq man with beard and sunglasses is standing in front of tree covered hills endseq',
#   'startseq bearded man with sunglasses in the mountains endseq'],
#  '2687539673_d54a8dc613': ['startseq girl and young boy are jumping on trampoline in suburban yard endseq',
#   'startseq girl is jumping on trampoline with her arms in the air while boy in blue shirt is bouncing on his stomach endseq',
#   'startseq teenager girl jumps high on trampoline and toddler falls on his stomach endseq',
#   'startseq toddler and teenage girl jumping on trampoline endseq',
#   'startseq two children jump on trampoline endseq'],
#  '3067500667_0fce8f28d4': ['startseq cricket batsman has been bowled out middle stump endseq',
#   'startseq cricket player swings his bat but misses endseq',
#   'startseq man is standing in front of some red sticks trying to hit ball endseq',
#   'startseq man is swinging paddle at unique ball game endseq',
#   'startseq player hits the ball at cricket game endseq'],
#  '2657484970_610e18144f': ['startseq people are boating near mountain endseq',
#   'startseq two people in canoe are rowing past large tree covered mountain endseq',
#   'startseq two people in canoe float past rocky wooded cliff endseq',
#   'startseq two people in canoe on river beside forested mountain endseq',
#   'startseq two people in kayak are paddling past green foliage on river endseq'],
#  '407008823_bdd7fc6ed5': ['startseq climber is making his way up snowy mountainside endseq',
#   'startseq lone person jumping through the air from one snowy mountain to another endseq',
#   'startseq man doing tricks in the snow endseq',
#   'startseq man dressed in snow gear takes leap into snow covered ravine endseq',
#   'startseq people jump over mountain crevasse on rope endseq'],
#  '3675825945_96b2916959': ['startseq man in skateboarding in an empty swimming pool endseq',
#   'startseq man rides skateboard up the side of an empty pool endseq',
#   'startseq skateboarder dressed in white is dropping into blue bowl endseq',
#   'startseq skateboarder hanging off the edge of bowl at skate park endseq',
#   'startseq skateboarder in an empty pool endseq'],
#  '1557838421_a33f2a4911': ['startseq grey and white dog is biting the ear of white and brown dog endseq',
#   'startseq the brown and white dog nips at the yellow dog endseq',
#   'startseq there are two dogs playing with each other endseq',
#   'startseq two dogs wrestle with each other with their teeth bared endseq',
#   'startseq two large dogs attempt to bite each other playfully endseq'],
#  '544301311_5e7d69a517': ['startseq the women sit outside on the steps reading and drinking endseq',
#   'startseq two girls sit by doorway on the steps endseq',
#   'startseq two women in period dress sitting in doorway endseq',
#   'startseq two women in traditional european dress sit on stoop one drinking the other reading endseq',
#   'startseq two women with white head garb and long dresses sitting in front of door on steps reading and drinking beverage endseq'],
#  '3624076529_9793655a21': ['startseq brown dog swimming through lake with stick in his mouth endseq',
#   'startseq brown dog swimming with stick endseq',
#   'startseq dog holding stick swims in the water endseq',
#   'startseq dog swimming with stick in its mouth endseq',
#   'startseq golden dog swims with stick in its mouth endseq'],
#  '537479916_c033897fac': ['startseq black dog finishes running down blue and orange ramp endseq',
#   'startseq black dog has just run down blue and red ramp on an obstacle course endseq',
#   'startseq dog and person doing an agility course endseq',
#   'startseq dog runs dog ramp endseq',
#   'startseq dog runs down ramp past its trainer endseq'],
#  '2737729252_b3fd9c05b1': ['startseq girl is taking picture of another girl in park endseq',
#   'startseq girl is taking picture of another girl in park endseq',
#   'startseq woman takes picture of another in purple in park endseq',
#   'startseq one girl taking picture of her friend endseq',
#   'startseq two little girls playing in the parking lot endseq'],
#  '267162122_c3437414ec': ['startseq black puppy jumping on the back of white puppy endseq',
#   'startseq black dog and white dog wrestle endseq',
#   'startseq black dog and white dog wrestling next to food dish endseq',
#   'startseq black puppy stands over white puppy endseq',
#   'startseq small black dog is standing over small white dog laying on his side endseq'],
#  '2592711202_55f8c64495': ['startseq girl dressed in blue enjoys blue treat while putting her white shoe back on endseq',
#   'startseq girl in blue dress sitting on the ground eating cotton candy endseq',
#   'startseq girl in blue dress takes off her shoes and eats blue cotton candy endseq',
#   'startseq child in blue dress holding sandal in one hand and eating blue cotton candy with other hand endseq',
#   'startseq the girl in blue dress is eating some blue cotton candy with one shoe off and one shoe on endseq'],
#  ...}

# %% [markdown]
# # Data Preprocessing - Images

# %%
"""
In this section, we will load our images and do some processing so that we can feed it in our network.
"""
# Out:
# '\nIn this section, we will load our images and do some processing so that we can feed it in our network.\n'

# %%
model = ResNet50(weights="imagenet", input_shape=(224,224,3))

# %%
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 1000)         2049000     avg_pool[0][0]
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
# Create a new model, by removing the last layer (output layer of 1000 classes) from the resnet50
model_new = Model(model.input, model.layers[-2].output)

# %%
images = "flickr_dataset/Flicker8k_Dataset/"

# %%
len(images)
# Out:
# 33

# %%
def preprocess_image(img):
    img = image.load_img(img, target_size=(224,224))
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)
    return img

# %%
def encode_image(img):
    img = preprocess_image(img)
    feature_vector = model_new.predict(img)
    feature_vector = feature_vector.reshape(feature_vector.shape[1],)
    return feature_vector

# %%
start = time()

encoding_train = {}

for ix, img in enumerate(train):
    
   # img = "./flicker8k-dataset/Flickr8k_Dataset/{}.jpg".format(train[ix])
    img = "flickr_dataset/Flicker8k_Dataset/{}.jpg".format(train[ix])
    encoding_train[img[len(images):]] = encode_image(img)
    
    if ix%100==0:
        print("Encoding image- "+ str(ix))
    
print("Time taken in seconds =", time()-start)
# Out:
# Encoding image- 0
# Encoding image- 100
# Encoding image- 200
# Encoding image- 300
# Encoding image- 400
# Encoding image- 500
# Encoding image- 600
# Encoding image- 700
# Encoding image- 800
# Encoding image- 900
# Encoding image- 1000
# Encoding image- 1100
# Encoding image- 1200
# Encoding image- 1300
# Encoding image- 1400
# Encoding image- 1500
# Encoding image- 1600
# Encoding image- 1700
# Encoding image- 1800
# Encoding image- 1900
# Encoding image- 2000
# Encoding image- 2100
# Encoding image- 2200
# Encoding image- 2300
# Encoding image- 2400
# Encoding image- 2500
# Encoding image- 2600
# Encoding image- 2700
# Encoding image- 2800
# Encoding image- 2900
# Encoding image- 3000
# Encoding image- 3100
# Encoding image- 3200
# Encoding image- 3300
# Encoding image- 3400
# Encoding image- 3500
# Encoding image- 3600
# Encoding image- 3700
# Encoding image- 3800
# Encoding image- 3900
# Encoding image- 4000
# Encoding image- 4100
# Encoding image- 4200
# Encoding image- 4300
# Encoding image- 4400
# Encoding image- 4500
# Encoding image- 4600
# Encoding image- 4700
# Encoding image- 4800
# Encoding image- 4900
# Encoding image- 5000
# Encoding image- 5100
# Encoding image- 5200
# Encoding image- 5300
# Encoding image- 5400
# Encoding image- 5500
# Encoding image- 5600
# Encoding image- 5700
# Encoding image- 5800
# Encoding image- 5900
# Time taken in seconds = 1169.0109071731567

# %%
# Save the bottleneck train features to disk

with open("./storage/encoded_train_images.pkl", "wb") as encoded_pickle:
    pickle.dump(encoding_train, encoded_pickle)

# %%
start = time()

encoding_test = {}

for ix, img in enumerate(test):

    img = "flickr_dataset/Flicker8k_Dataset/{}.jpg".format(test[ix])
    encoding_test[img[len(images):]] = encode_image(img)
    
    if ix%100==0:
        print("Encoding image- "+ str(ix))
    
print("Time taken in seconds =", time()-start)
# Out:
# Encoding image- 0
# Encoding image- 100
# Encoding image- 200
# Encoding image- 300
# Encoding image- 400
# Encoding image- 500
# Encoding image- 600
# Encoding image- 700
# Encoding image- 800
# Encoding image- 900
# Time taken in seconds = 187.945631980896

# %%
# Save the bottleneck train features to disk

with open("./storage/encoded_test_images.pkl", "wb") as encoded_pickle:
    pickle.dump(encoding_test, encoded_pickle)

# %%
# Load the train images features from disk

with open("./storage/encoded_train_images.pkl", "rb") as encoded_pickle:
    encoding_train = pickle.load(encoded_pickle)

# %%
# Load the test images features from disk

with open("./storage/encoded_test_images.pkl", "rb") as encoded_pickle:
    encoding_test = pickle.load(encoded_pickle)

# %%
encoding_train
# Out:
# {'2513260012_03d33305cf.jpg': array([0.3470795 , 0.51159084, 0.08728848, ..., 1.1897296 , 0.04043847,
#         0.1527106 ], dtype=float32),
#  '2903617548_d3e38d7f88.jpg': array([0.        , 0.00303404, 0.09360084, ..., 0.4310791 , 0.37979594,
#         0.9166435 ], dtype=float32),
#  '3338291921_fe7ae0c8f8.jpg': array([0.7674472 , 0.5342269 , 0.38325197, ..., 0.02098639, 0.18429385,
#         0.04270015], dtype=float32),
#  '488416045_1c6d903fe0.jpg': array([6.2481058e-01, 3.2965460e-01, 1.7821058e-04, ..., 1.2753810e+00,
#         4.6392566e-01, 4.9036074e-01], dtype=float32),
#  '2644326817_8f45080b87.jpg': array([0.1155531 , 0.6596539 , 0.05323281, ..., 0.14397353, 1.0179375 ,
#         0.00556583], dtype=float32),
#  '218342358_1755a9cce1.jpg': array([1.7061832 , 0.4051473 , 0.35206553, ..., 0.29408896, 0.04833031,
#         0.04654434], dtype=float32),
#  '2501968935_02f2cd8079.jpg': array([0.10608297, 1.4420797 , 0.04447002, ..., 0.20587179, 0.6978754 ,
#         1.590432  ], dtype=float32),
#  '2699342860_5288e203ea.jpg': array([0.46122536, 0.3323877 , 0.10834733, ..., 0.71413195, 0.        ,
#         0.06853592], dtype=float32),
#  '2638369467_8fc251595b.jpg': array([1.4792114 , 0.00732505, 0.1990863 , ..., 0.911336  , 0.07021052,
#         0.9363788 ], dtype=float32),
#  '2926786902_815a99a154.jpg': array([1.1178092 , 0.6061055 , 2.0033443 , ..., 1.3630112 , 0.49351892,
#         0.13383187], dtype=float32),
#  '2851304910_b5721199bc.jpg': array([0.13311353, 0.8839836 , 0.26648125, ..., 0.06137232, 0.30909884,
#         0.        ], dtype=float32),
#  '3423802527_94bd2b23b0.jpg': array([0.23148237, 0.41955256, 0.07108793, ..., 0.51854736, 0.292536  ,
#         0.8536098 ], dtype=float32),
#  '3356369156_074750c6cc.jpg': array([0.3818782 , 0.14747812, 0.95705813, ..., 1.2396249 , 0.6067537 ,
#         0.09615622], dtype=float32),
#  '2294598473_40637b5c04.jpg': array([0.9133097 , 0.17343298, 0.11540992, ..., 1.9545766 , 0.94113034,
#         0.01581051], dtype=float32),
#  '1191338263_a4fa073154.jpg': array([1.0365963 , 0.12317808, 0.2958485 , ..., 3.3519733 , 1.7793591 ,
#         0.41484973], dtype=float32),
#  '2380765956_6313d8cae3.jpg': array([0.4852698 , 0.53069174, 0.02347291, ..., 2.2674115 , 0.39438626,
#         0.12719129], dtype=float32),
#         0.05886733], dtype=float32),
#  '3067500667_0fce8f28d4.jpg': array([0.75720525, 3.1249123 , 0.01961731, ..., 1.5944678 , 0.45336682,
#         0.64769727], dtype=float32),
#  '2657484970_610e18144f.jpg': array([0.51081073, 0.04414028, 0.00772437, ..., 0.78429836, 0.11223575,
#         0.        ], dtype=float32),
#  '407008823_bdd7fc6ed5.jpg': array([0.45115823, 2.6158314 , 0.        , ..., 0.07525696, 0.66879606,
#         0.        ], dtype=float32),
#  '3675825945_96b2916959.jpg': array([0.40501565, 0.3748037 , 0.15193506, ..., 1.0126328 , 0.1438267 ,
#         1.5070627 ], dtype=float32),
#  '1557838421_a33f2a4911.jpg': array([0.7515679 , 0.549046  , 0.510202  , ..., 0.16861133, 0.37967035,
#         0.12857203], dtype=float32),
#  '544301311_5e7d69a517.jpg': array([0.852905  , 0.15831676, 0.71747124, ..., 0.414882  , 0.6047261 ,
#         0.19936511], dtype=float32),
#  '3624076529_9793655a21.jpg': array([1.6719826 , 0.45983368, 0.02224702, ..., 1.5215069 , 0.10599517,
#         0.48607403], dtype=float32),
#  '537479916_c033897fac.jpg': array([0.29341614, 0.68819934, 0.03396511, ..., 0.86882   , 0.21497968,
#         0.09678081], dtype=float32),
#  '2737729252_b3fd9c05b1.jpg': array([5.1189816e-01, 3.4504399e-01, 3.6004125e-04, ..., 1.8665691e-01,
#         1.1546625e+00, 1.3712884e-01], dtype=float32),
#  '267162122_c3437414ec.jpg': array([0.08635254, 0.23993513, 0.54427713, ..., 0.16394928, 0.15965247,
#         0.2726738 ], dtype=float32),
#  '2592711202_55f8c64495.jpg': array([0.35245472, 0.18302605, 0.28294978, ..., 0.04511109, 0.62672466,
#         0.071109  ], dtype=float32),
#  ...}

# %%
train_descriptions
# Out:
# {'2513260012_03d33305cf': ['startseq black dog is running after white dog in the snow endseq',
#   'startseq black dog chasing brown dog through snow endseq',
#   'startseq two dogs chase each other across the snowy ground endseq',
#   'startseq two dogs play together in the snow endseq',
#   'startseq two dogs running through low lying body of water endseq'],
#  '2903617548_d3e38d7f88': ['startseq little baby plays croquet endseq',
#   'startseq little girl plays croquet next to truck endseq',
#   'startseq the child is playing croquette by the truck endseq',
#   'startseq the kid is in front of car with put and ball endseq',
#   'startseq the little boy is playing with croquet hammer and ball beside the car endseq'],
#  '3338291921_fe7ae0c8f8': ['startseq brown dog in the snow has something hot pink in its mouth endseq',
#   'startseq brown dog in the snow holding pink hat endseq',
#   'startseq brown dog is holding pink shirt in the snow endseq',
#   'startseq dog is carrying something pink in its mouth while walking through the snow endseq',
#   'startseq dog with something pink in its mouth is looking forward endseq'],
#  '488416045_1c6d903fe0': ['startseq brown dog is running along beach endseq',
#   'startseq brown dog wearing black collar running across the beach endseq',
#   'startseq dog walks on the sand near the water endseq',
#   'startseq brown dog running on the beach endseq',
#   'startseq the large brown dog is running on the beach by the ocean endseq'],
#  '2644326817_8f45080b87': ['startseq black and white dog with red frisbee standing on sandy beach endseq',
#   'startseq dog drops red disc on beach endseq',
#   'startseq dog with red frisbee flying in the air endseq',
#   'startseq dog catching red frisbee endseq',
#   'startseq the black dog is dropping red disc on beach endseq'],
#  '218342358_1755a9cce1': ['startseq cyclist wearing red helmet is riding on the pavement endseq',
#   'startseq girl is riding bike on the street while wearing red helmet endseq',
#   'startseq person on bike wearing red helmet riding down street endseq',
#   'startseq woman wears red helmet and blue shirt as she goes for bike ride in the shade endseq',
#   'startseq person in blue shirt and red helmet riding bike down the road endseq'],
#  '2501968935_02f2cd8079': ['startseq man dressed in purple shirt and red bandanna smiles at the people watching him endseq',
#   'startseq man on the street wearing leather chaps and chainmail codpiece endseq',
#   'startseq man wearing purple shirt and black leather chaps poses for the camera endseq',
#   'startseq man dressed in leather chaps and purple shirt stands in front of onlookers endseq',
#   'startseq there is man in purple shirt leather chaps and red bandanna standing near other men endseq'],
#  '2699342860_5288e203ea': ['startseq boy wearing red shirt is running through woodland endseq',
#   'startseq child runs near some trees endseq',
#   'startseq young boy is dancing around endseq',
#   'startseq young boy with red short sleeved shirt and jeans runs by some trees endseq',
#   'startseq the little boy in the red shirt stops to smile for the camera endseq'],
#  '2638369467_8fc251595b': ['startseq girl in white dress endseq',
#   'startseq little girl in white is looking back at the camera while carrying water grenade endseq',
#   'startseq smiling young girl in braids is playing ball endseq',
#   'startseq young girl wearing white looks at the camera as she plays endseq',
#   'startseq the girl is holding green ball endseq'],
#  '2926786902_815a99a154': ['startseq skier in yellow jacket is airborne above the mountains endseq',
#   'startseq skier jumps high in the air with view of the mountains endseq',
#   'startseq skiing man in fluorescent jacket jumps very high and it looks as though he is flying endseq',
#   'startseq somone is high in the air doing ski jump endseq',
#   'startseq the skier in the green jacket and white pants appears to almost fly into the sky endseq'],
#  '2851304910_b5721199bc': ['startseq photographer looks over the hills endseq',
#   'startseq woman in red jacket is videotaping natural landscape endseq',
#   'startseq woman with camera looks out over rolling hills endseq',
#   'startseq woman with camera on tripod is looking at the view endseq',
#   'startseq lady in red shirt has her camera set up in the field to record something endseq'],
#  '3423802527_94bd2b23b0': ['startseq bunch of girls in cheerleader outfits endseq',
#   'startseq large group of cheerleaders walking in parade endseq',
#   'startseq cheerleaders perform endseq',
#   'startseq many cheerleaders wearing black walk down the street endseq',
#   'startseq parade of cheerleaders wearing black pink and white uniforms endseq'],
#  '3356369156_074750c6cc': ['startseq blue boat with yellow canopy is floating on calm waters endseq',
#   'startseq boat in the water endseq',
#   'startseq boat with roof on green water endseq',
#   'startseq the boat is in the middle of the water endseq',
#   'startseq the solitude boat floats on the lake endseq'],
#  '2294598473_40637b5c04': ['startseq dog catches frisbee in midair endseq',
#   'startseq dog catching frisbee endseq',
#   'startseq terrier mix catches frisbee in the air endseq',
#   'startseq white and black dog catching frisbee endseq',
#   'startseq white dog is leaping in the air with green object in its mouth endseq'],
#  '1191338263_a4fa073154': ['startseq little old lady sitting next to an advertisement endseq',
#   'startseq an asian woman waiting at an underground train stop endseq',
#   'startseq an old woman sits in transit station next to backlit advertisement endseq',
#   'startseq woman sits in subway station endseq',
#   'startseq woman with an umbrella is sitting at station with an aquos commercial on the wall endseq'],
#  '2380765956_6313d8cae3': ['startseq blond girl wearing green jacket walks on trail along side metal fence endseq',
#   'startseq girl in green coat walks down rural road playing flute endseq',
#   'startseq young girl in parka playing flute while walking by fenced in field endseq',
#   'startseq girl in green and blue jacket walking past an enclosed field endseq',
#   'startseq girl playing flute as she walks by fence in rural area endseq'],
#  '3197891333_b1b0fd1702': ['startseq family of nine people including four children pose in front of brick fireplace with white mantle endseq',
#   'startseq family poses in front of the fireplace and christmas tree endseq',
#   'startseq family posing by the mantle and christmas tree endseq',
#   'startseq happy family poses by the fireplace endseq',
#   'startseq two couples and four kids pose for family picture endseq'],
#  '3119887967_271a097464': ['startseq man in sweater pointing at the camera endseq',
#   'startseq one man is posing with arms outstretched and finger pointed while another stares from behind him endseq',
#   'startseq the man in the black hat stands behind the man who is pointing his finger endseq',
#   'startseq two men look toward the camera while the one in front points his index finger endseq',
#   'startseq two men one wearing black hat while the one in front points standing in hallway endseq'],
#  '2276499757_b44dc6f8ce': ['startseq dog looks warily at the brown dog investigating his area endseq',
#   'startseq large brown dog is looking at medium sized black dog endseq',
#   'startseq small black dog looks at larger brown dog in grassy field endseq',
#   'startseq the big brown dog looks at the small black dog in tall grass endseq',
#   'startseq there is big dog looking at little dog endseq'],
#  '2506892928_7e79bec613': ['startseq three children in field with white flowers endseq',
#   'startseq three children one with stuffed kitten in field of flowers endseq',
#   'startseq three children play in the garden endseq',
#   'startseq three children pose among wildflowers endseq',
#   'startseq three kids palying with toy cat in garden endseq'],
#  '2187222896_c206d63396': ['startseq boy in red shirt in front of long blue wall raises his eyebrow at the camera endseq',
#   'startseq boy in red shirt with stripes standing near blue brick wall with handicap signs endseq',
#   'startseq an african american boy stands in front of blue building in the handicapped space endseq',
#   'startseq the boy in the orange shirt looks backwards endseq',
#   'startseq the boy in the red shirt is next to blue wall endseq'],
#  '2826769554_85c90864c9': ['startseq brown dog is carrying wet stick on the shore of the ocean endseq',
#   'startseq dog bounds across the sandy beach with stick in his mouth and water splashing off his paws endseq',
#   'startseq wet blond dog carries stick on the shore endseq',
#   'startseq the dog is running along the beach next to the ocean with stick in its mouth endseq',
#   'startseq the wet brown dog has stick in his mouth and is running in the sand next to the water endseq'],
#  '3097196395_ec06075389': ['startseq two dogs are racing on ractrack endseq',
#   'startseq two dogs race across the track endseq',
#   'startseq two greyhounds race endseq',
#   'startseq two greyhounds with muzzles race along the inside curb of railed dirt track endseq',
#   'startseq two racing dogs run around track endseq'],
#  '3603116579_4a28a932e2': ['startseq baseball pitcher with shelton on his shirt throws the ball endseq',
#   'startseq baseball player in black and orange shirt and with glove on pitches the ball endseq',
#   'startseq male dressed in sports outfit tries to catch baseball endseq',
#   'startseq man playing baseball endseq',
#   'startseq the baseball player is running after the ball endseq'],
#  '3339263085_6db9fd0981': ['startseq brown dog wades through water and walks toward rock endseq',
#   'startseq dog has waded through shallow water to reach rock outcropping endseq',
#   'startseq light brown dog is splashing in the water with its paw endseq',
#   'startseq small brown dog is about ready to exit the water after swim endseq',
#   'startseq yellow dog in shallow water endseq'],
#  '2532262109_87429a2cae': ['startseq group of girls in school uniforms are standing together and waiting to cross the street while one girl takes picture endseq',
#   'startseq group of people are standing together outside as one takes photograph endseq',
#   'startseq group of school girls are standing together while one is taking pictures endseq',
#   'startseq group of young women stand together endseq',
#   'startseq girls in school uniforms endseq'],
#  '2076906555_c20dc082db': ['startseq boy wearing jean jacket with his hand on his chest smiling at the camera endseq',
#   'startseq boy with bruised nose and writing on his hands is standing in video rental store endseq',
#   'startseq boy with writing on his hand is standing in store endseq',
#   'startseq young man in jean jacket smiles for the camera inside store endseq',
#   'startseq young man with denim jacket and writing on his hand smiles in front of bookcase full of videos endseq'],
#  '2502007071_82a8c639cf': ['startseq group of people in front of house endseq',
#   'startseq man in stripes woman in sunglasses and child in blue hat in front of brick building endseq',
#   'startseq woman in sunglasses and blue flowered shirt stands while boy and man sit nearby endseq',
#   'startseq woman wearing sunglasses and flowered shirt looks to the left endseq',
#   'startseq three adults and one child are waiting outside of building perhaps school endseq'],
#  '3113769557_9edbb8275c': ['startseq woman stands in front of display case and another woman looks at digital camera endseq',
#   'startseq woman stands tall in front of glass display while another woman takes picture of something endseq',
#   'startseq woman stands with her arms out at her sides while another takes picture endseq',
#   'startseq woman stands with her arms out in store while another woman holds camera endseq',
#   'startseq one woman is taking picture and another woman is standing sideways with her arm out endseq'],
#  '3325974730_3ee192e4ff': ['startseq snowboarder jumps high into the air off of snowy ramp endseq',
#   'startseq snowboarder jumps off ramp endseq',
#   'startseq man on snowboard performing trick high in the air endseq',
#   'startseq person in purple coat making jump on snowboard endseq',
#   'startseq snowboarder jumps off high ramp over icy landscape endseq'],
#  '1655781989_b15ab4cbff': ['startseq group of mountain climbers endseq',
#   'startseq group of people walking in line through the snow toward mountain endseq',
#   'startseq line of people are making their way through snow covered mountains endseq',
#   'startseq people are walking through snow covered field with mountain the background endseq',
#   'startseq people facing mountains in the snow endseq'],
#  '1662261486_db967930de': ['startseq black and white dog is jumping through black and white hoop endseq',
#   'startseq black and white dog jumps through black and white hoop endseq',
#   'startseq brown and white dog jumping through black and white hoop endseq',
#   'startseq dog jumping through black and white hoop endseq',
#   'startseq dog jumping through ring endseq'],
#  '2410562803_56ec09f41c': ['startseq girl using laptop another girl and boy looking at his cellphone endseq',
#   'startseq group of people sit against building and use electronics endseq',
#   'startseq three people sit near street endseq',
#   'startseq three people sitting in front of store on bench endseq',
#   'startseq three young people sit outside and engage with electronic devices endseq'],
#  '2469498117_b4543e1460': ['startseq dog races while wearing number endseq',
#   'startseq greyhound wearing muzzle and the number six on yellow jacket is running on dog track endseq',
#   'startseq muzzle greyhound dog running on track endseq',
#   'startseq tan greyhound wearing gold shirt with number on it runs down track endseq',
#   'startseq muxzzled greyhound leaping in race with yellow jacket endseq'],
#  '69710415_5c2bfb1058': ['startseq group of people stand at the edge of cliff over the ocean endseq',
#   'startseq group of three boy scouts rest on bluff overlooking the ocean endseq',
#   'startseq three men stand on cliff overlooking lake endseq',
#   'startseq three scouts are on top of cliff overlooking the ocean endseq',
#   'startseq two men are sitting on rock near the ocean with another man standing nearby endseq'],
#  '3414734842_beb543f400': ['startseq couple holding hands and another woman are walking down wooded trail endseq',
#   'startseq couple holding hands and woman standing beside them pose on tree lined dirt road endseq',
#   'startseq three friends on stroll in the forest endseq',
#   'startseq three people stand on path through the woods endseq',
#   'startseq two women and man posing on rural path endseq'],
#  '3006217970_90b42e6b27': ['startseq car sponsored by riwal is smoking its tires on wet road endseq',
#   'startseq race car drives along track in the rain endseq',
#   'startseq racing car is driving around wet track with its headlights on endseq',
#   'startseq small race car with advertising is driving on rainy track endseq',
#   'startseq sponsored race car is driving with lights on wet raceway endseq'],
#  '2192411521_9c7e488c5e': ['startseq bearded man wearing bandanna is pointing his finger whilst riding bicycle endseq',
#   'startseq man bicycles down the street and points his finger endseq',
#   'startseq man holds an object with his hand while riding his bike down the street endseq',
#   'startseq man with long hair riding bicycle gives the peace sign endseq',
#   'startseq man in blue shirt and black cap riding bike down street flashing peace sign endseq'],
#  '3535879138_9281dc83d5': ['startseq crowd of people waving red flags are passing under bridge endseq',
#   'startseq group of people walk down the street carrying red flags endseq',
#   'startseq large group of people walking down street some carrying flags or banners endseq',
#   'startseq many people walking together on pavement near brick building with other people looking on endseq',
#   'startseq many people walk in the street endseq'],
#  '2685788323_ceab14534a': ['startseq man in sunglasses gets ready to pull chair out to sit down for his meal endseq',
#   'startseq man wearing sunglasses stands by table at cafe endseq',
#   'startseq man about to pull out chair and sit down at restaurant endseq',
#   'startseq man at eatery getting ready to sit down endseq',
#   'startseq the large man grabs seat at restaurant endseq'],
#  '3465606652_f380a38050': ['startseq boy holding racket is standing in the grass endseq',
#   'startseq boy in purple shirt and blue jeans is standing in the grass holding round toy with handle endseq',
#   'startseq boy playes with stringless racket in his backyard endseq',
#   'startseq boy walks through the lawn endseq',
#   'startseq child in purple clothing is playing with toy inside yard with other toys and fence endseq'],
#  '2599131872_65789d86d5': ['startseq two blond girls are playing together endseq',
#   'startseq two girls enjoy themselves whilst wind blows through their hair endseq',
#   'startseq two girls with long hair jumping on trampoline endseq',
#   'startseq two little blonde girls twirl their hair endseq',
#   'startseq two little girls are playing on trampoline endseq'],
#  '2244613488_4d1f9edb33': ['startseq four bicyclists ride along dirt road between two wire fences endseq',
#   'startseq four cyclists on country trail are passing by an electricity pylon endseq',
#   'startseq the four bicyclists are riding through the desert endseq',
#   'startseq three bikers bike across the dry land endseq',
#   'startseq three cyclists ride near mountain endseq'],
#  '2738077433_10e6264b6f': ['startseq dog climbing steep dirt hill endseq',
#   'startseq dog climbs hill endseq',
#   'startseq great dane climbing steep hill endseq',
#   'startseq light brown dog is running up endseq',
#   'startseq light dog climbing wall of dirt endseq'],
#  '3537201804_ce07aff237': ['startseq child spins on merry go round endseq',
#   'startseq childern are playing on merry go round as adults on bench watch them endseq',
#   'startseq children play on merry go round as adults look on from bench endseq',
#   'startseq fathers watch as their children enjoy the spinning merry go round endseq',
#   'startseq two kids sit in the middle of playground toy that spins around them endseq'],
#  '1597557856_30640e0b43': ['startseq brown dog is jumping up at woman who is wearing brown skirt endseq',
#   'startseq golden retriever is excitedly greeting woman as little dog walks towards the camera endseq',
#   'startseq tan dog jumping up at woman in skirt and black and tan dog walking away endseq',
#   'startseq yellow dog jumps to greet woman endseq',
#   'startseq one dog is jumping at the lady while the other walks away endseq'],
#  '3357194782_c261bb6cbf': ['startseq man in the dooorway of bus looking onward endseq',
#   'startseq man standing at the door of vehicle with another sitting glancing out the window endseq',
#   'startseq people ride bus or trolley endseq',
#   'startseq some people riding an old bus endseq',
#   'startseq three passengers on train car endseq'],
#  '3682038869_585075b5ff': ['startseq little girl is peaking out from behind tree endseq',
#   'startseq little girl peering out from behind tree endseq',
#   'startseq young girl hiding behind tree in forest endseq',
#   'startseq young girl peeking out from behind tree in wooded area endseq',
#   'startseq young girl wearing striped dress peeks out from behind tree endseq'],
#  '236474697_0c73dd5d8b': ['startseq group of people hold drinks and point at the camera endseq',
#   'startseq group of people are holding up drinks and pointing to the camera endseq',
#   'startseq group of young people holding bottles and pointing at the camera endseq',
#   'startseq several young people posing for this photo holding beers endseq',
#   'startseq young adults stand pointing at the person taking the picture endseq'],
#  '2641288004_30ce961211': ['startseq border collie jumps over bed with tennis ball in its mouth endseq',
#   'startseq dog jumping with ball in its mouth endseq',
#   'startseq dog jumps on bed and catches green toy endseq',
#   'startseq border collie jumps in the air and catches tennis ball endseq',
#   'startseq the black and white dog jumps with tennis ball in its mouth endseq'],
#  '267164457_2e8b4d30aa': ['startseq climber walks along snowy peak endseq',
#   'startseq man climbs over snow covered rocks by shore endseq',
#   'startseq man is standing on snowcapped mountain endseq',
#   'startseq person hikes down snowy mountain endseq',
#   'startseq there man on top of an snow covered mountain with lake behind him endseq'],
#  '2453891449_fedb277908': ['startseq white dog chasing black dog across the grass endseq',
#   'startseq white dog is following black dog through the grassy area endseq',
#   'startseq there are two dogs black and white and the black one is jumping endseq',
#   'startseq two dogs running in grassy fenced in area surrounded by trees endseq',
#   'startseq two dogs running through yard with forest in the distance endseq'],
#  '281419391_522557ce27': ['startseq black race car spins its tires while smoke comes out endseq',
#   'startseq black race car starts up in front of crowd of people endseq',
#   'startseq broken down car during race endseq',
#   'startseq race car smoking very badly on the racetrack endseq',
#   'startseq red bull branded race car leaves smoke behind it in front of crowd endseq'],
#  '354999632_915ea81e53': ['startseq person behind some bags inside an igloo endseq',
#   'startseq snowy cave full of luggage endseq',
#   'startseq inside the igloo the young man gets ready for his overnight stay endseq',
#   'startseq some backpacks piled up in an ice cave with person dressed in black in the background endseq',
#   'startseq there is something visible through the hole in the wall endseq'],
#  '3109136206_f7d201b368': ['startseq brown dog drinks from body of water endseq',
#   'startseq brown dog is starting to walk into water endseq',
#   'startseq brown dog steps into murky water endseq',
#   'startseq dog getting into some water endseq',
#   'startseq dog putting his legs into pond endseq'],
#  '2281054343_95d6d3b882': ['startseq man wearing black hat is walking through busy city street endseq',
#   'startseq silhouette of man in hat on busy city street endseq',
#   'startseq person with black hat and black coat near buildings with signs endseq',
#   'startseq three people in crowded city area endseq',
#   'startseq thre is shot of man with his back turned in city endseq'],
#  '3296584432_bef3c965a3': ['startseq brown dog chases something man behind him threw on the beach endseq',
#   'startseq man and dog on the beach endseq',
#   'startseq man is interacting with dog that is running in the opposite direction endseq',
#   'startseq man playing fetch with his dog on beach endseq',
#   'startseq man walking behind running dog on the beach endseq'],
#  '3526431764_056d2c61dc': ['startseq woman taking photo standing next to tall man and in front of another man who is also taking photo endseq',
#   'startseq three people are outdoors taking pictures endseq',
#   'startseq three people holding cameras are standing on dirt trail with grass on the side of it endseq',
#   'startseq three people taking pictures with their cameras endseq',
#   'startseq two people are taking pictures while third is holding camera endseq'],
#  '3549997413_01388dece0': ['startseq man is skiing down mountain with another large mountain behind him and river between the mountains endseq',
#   'startseq man is skiing down snowy hill with large mountain in the background endseq',
#   'startseq man skiing down snow covered mountain endseq',
#   'startseq person skis down snowy mountain endseq',
#   'startseq skier goes down hill with mountain as backdrop endseq'],
#  '143688895_e837c3bc76': ['startseq boy climbing rock face endseq',
#   'startseq climber is standing on the rock face next to the pink rope endseq',
#   'startseq man climbing cliff with rope endseq',
#   'startseq man climbs steep rocks endseq',
#   'startseq man rock climbing in the forest surrounded by light endseq'],
#  '2495394666_2ef6c37519': ['startseq brown dog is standing in lake endseq',
#   'startseq brown dog is swimming in creek endseq',
#   'startseq dog swimming in pond endseq',
#   'startseq dog swimming in body of water endseq',
#   'startseq the brown dog is swimming in the water endseq'],
#  '3384742888_85230c34d5': ['startseq dog plays with toy in the grass endseq',
#   'startseq rotweiler playfully rolls over int he grass with toy endseq',
#   'startseq black and tan dog playing with toy and rolling on the grass endseq',
#   'startseq dog chewing up ball while rolling in grass endseq',
#   'startseq the dog is resting after game of fetch endseq'],
#  '1160034462_16b38174fe': ['startseq elderly man in straw hat is sitting on bench endseq',
#   'startseq elderly man sits alone on park bench endseq',
#   'startseq an old man in straw hat sits on park bench endseq',
#   'startseq the old man in the brown hat is sitting on the bench endseq',
#   'startseq white haired man in gray sweater and straw hat sitting on bench under tree endseq'],
#  '334768700_51c439b9ee': ['startseq dark haired man in red shirt with beard playing the guitar in park endseq',
#   'startseq man in red shirt plays guitar in park endseq',
#   'startseq man is sitting and playing guitar on the grass endseq',
#   'startseq man sitting in the grass playing his guitar wearing red shirt endseq',
#   'startseq man wearing red plays his guitar on the grass endseq'],
#  '412101267_7257e6d8c0': ['startseq two black dogs are jumping and playing with yellow tennis ball in the snow endseq',
#   'startseq two dog play in the snow endseq',
#   'startseq two dogs one with tennis ball in his mouth play together in the snow endseq',
#   'startseq two dogs playing with ball in the snow endseq',
#   'startseq two dogs play with tennis ball in the snow endseq'],
#  '2623939135_0cd02ffa5d': ['startseq an attractive woman holds halo above her head endseq',
#   'startseq woman in dress raises her arm over her head endseq',
#   'startseq woman is looking at the ceiling while taking off her hat endseq',
#   'startseq woman looking up towards wide ring she is holding over her head drink in her other hand endseq',
#   'startseq woman looking upward with her hand above her head endseq'],
#  '3043266735_904dda6ded': ['startseq an elderly person with white hat is reading paperback book endseq',
#   'startseq an elder woman in hat and scarf is looking through book she has in her hands endseq',
#   'startseq an older woman wearing hat reads book endseq',
#   'startseq an old lady consulting paperback book endseq',
#   'startseq woman in white hat reading book endseq'],
#  '3034585889_388d6ffcc0': ['startseq looker on catches motocross bike on its side after spill while another races by endseq',
#   'startseq man on dirt bike zipping away while another one slips to the ground and third man in yellow jacket looks on endseq',
#   'startseq man on motorcycle making tight turn endseq',
#   'startseq person is riding their motorbike and person in bright yellow jacket is watching someone fall off their bike endseq',
#   'startseq bike rider is looking at accident of other sports bike rider endseq'],
#  '2069279767_fb32bfb2de': ['startseq the men are climbing endseq',
#   'startseq two men are lying in red cots on the side of mountain endseq',
#   'startseq two men are sleeping on makeshift beds on the side of cliff endseq',
#   'startseq two men in cots hanging from cliff endseq',
#   'startseq two mountain climbers are smiling on the mountainside endseq'],
#  '2593406865_ab98490c1f': ['startseq skateboarder jumps off his skateboard in midair in hopes of landing back on it endseq',
#   'startseq teenage boy is performing trick with his skateboard endseq',
#   'startseq young man is flipping skateboard during trick endseq',
#   'startseq young skateboarder doing tricks in the air endseq',
#   'startseq the man is performing trick on skateboard near onlookers endseq'],
#  '432167214_c17fcc1a2d': ['startseq dark colored man is holding protest banner in busy city street with people staring from behind endseq',
#   'startseq man in blue and yellow jacket holding religious sign stands in street with people behind him on the sidewalk endseq',
#   'startseq man is holding religious poster endseq',
#   'startseq man wearing hat holding sign with writing on it endseq',
#   'startseq man standing on the street holding sign endseq'],
#  '305749904_54a612fd1a': ['startseq man is wearing blue shirt with the word mambo on it endseq',
#   'startseq man is wearing shirt that reads mambo with an image of baby and teddy bear endseq',
#   'startseq man wears shirt showing baby humping stuffed bear endseq',
#   'startseq person wearing blue mambo shirt has his back to the camera endseq',
#   'startseq the man is wearing blue shirt endseq'],
#  '2780087302_6a77658cbf': ['startseq man in black shirt sits on stool while trying to sell stuffed animals endseq',
#   'startseq man is outside selling various toys endseq',
#   'startseq vendor sells children toys as visitors walk by endseq',
#   'startseq vendor sells inflatable toys and stuffed animals on the sidewalk endseq',
#   'startseq man sits on stool beside toys endseq'],
#  '3051998298_38da5746fa': ['startseq guy in navy blue and yellow shorts jumping into pool endseq',
#   'startseq man catches football in midair while jumping into pool endseq',
#   'startseq man in swim trunks is jumping into pool while in strange pose endseq',
#   'startseq antics in covered pool endseq',
#   'startseq people are diving into swimming pool endseq'],
#  '1574401950_6bedc0d29b': ['startseq boy jumps from the top of blue plastic slide endseq',
#   'startseq child jumps over the slide portion of playground equipment shaded by trees endseq',
#   'startseq little boy in striped shirt jumps from blue slide endseq',
#   'startseq little boy is jumping off the top of slide endseq',
#   'startseq young boy jumps on slide in backyard endseq'],
#  '539493431_744eb1abaa': ['startseq man is playing with fire baton in the day light endseq',
#   'startseq man juggling fire endseq',
#   'startseq man stands near playground endseq',
#   'startseq man throws flames outside endseq',
#   'startseq the guy is holding black stick in front of playground endseq'],
#  '3524436870_7670df68e8': ['startseq brown dog playing with bubbles endseq',
#   'startseq brown dog walking across lawn as bubbles float by endseq',
#   'startseq dark brown dog is looking at bubbles while walking on green grass endseq',
#   'startseq dog catching bubbles on the grass endseq',
#   'startseq the brown dog is chasing and popping bubbles endseq'],
#  '2081446176_f97dc76951': ['startseq guy with scarf and woven toboggan endseq',
#   'startseq man in black and white cap and scarf endseq',
#   'startseq man wearing scarf and knitted hat is smiling endseq',
#   'startseq person wearing hat and scarf looks to the right endseq',
#   'startseq the man has poof on top of his woolen hat endseq'],
#  '2265367960_7928c5642f': ['startseq boy sitting down smiling for the picture endseq',
#   'startseq child holding some shoes endseq',
#   'startseq child in blue and wearing hat smiles endseq',
#   'startseq young boy smiling and holding sandals endseq',
#   'startseq the boy is wearing hat and holding sandals endseq'],
#  '460350019_af60511a3b': ['startseq black dog and woman in red shirt playing tug of war endseq',
#   'startseq dog is pulling on one end of rope and girl is pulling on the other endseq',
#   'startseq woman plays tug of war with her black dog in brown landscape surrounded by trees endseq',
#   'startseq woman plays with her rottweiler dog outside endseq',
#   'startseq woman and dog playing outside endseq'],
#  '2976946039_fb9147908d': ['startseq group of people surf on very large wave endseq',
#   'startseq group of surfers catching wave endseq',
#   'startseq people surfing and attempting to surf in the ocean on big wave endseq',
#   'startseq several people are surfing on wave in the sea endseq',
#   'startseq surfers on huge ocean wave at sunset endseq'],
#  '2308108566_2cba6bca53': ['startseq man rides bike on dirt path endseq',
#   'startseq person biking through the woods endseq',
#   'startseq person dirtbikes along muddy trail endseq',
#   'startseq dirt bike rider riding down the slope endseq',
#   'startseq person rides dirt bike down dirt hill endseq'],
#  '3367758711_a8c09607ac': ['startseq there are two women crossing the street in front of two buses endseq',
#   'startseq two women in headwraps are hurrying past buses endseq',
#   'startseq two women walk in front of bus to cross the road endseq',
#   'startseq two women walk on the street in front of two buses endseq',
#   'startseq two women with their heads covered crossing the road in front of buses endseq'],
#  '3666056567_661e25f54c': ['startseq group of people walk down city street at night endseq',
#   'startseq group of people walking down the street with one on the phone in green hat endseq',
#   'startseq four people are walking along city sidewalk while the one in the green hat talks on cellphone endseq',
#   'startseq four people are walking on sidewalk endseq',
#   'startseq four people walk down sidewalk at night endseq'],
#  '3099264059_21653e2536': ['startseq skateboarder is jumping almost as high as building endseq',
#   'startseq snowboarder jumping off tall brick building endseq',
#   'startseq snowboarder jumps over pile of snow endseq',
#   'startseq snowboarder jumps off rail over snowpile endseq',
#   'startseq the snowboarder is doing stunt high in the air at night endseq'],
#  '2988439935_7cea05bc48': ['startseq man in red soccer uniform getting ready to kick the ball endseq',
#   'startseq man in red uniform plays in soccer game endseq',
#   'startseq man in red uniform runs towards soccer ball on field endseq',
#   'startseq player in red uniform gets ready to kick the ball during soccer match as the crowd watches endseq',
#   'startseq soccer player in red uniform runs after soccer ball endseq'],
#  '241345864_138471c9ea': ['startseq boy cheerleader has girl cheerleader on his knee endseq',
#   'startseq female cheerleader sits on the knee of male cheerleader endseq',
#   'startseq cheerleaders taking break endseq',
#   'startseq the cheerleader in red and white is sitting on the knee of man also wearing red and white endseq',
#   'startseq two cheerleaders are sitting at football game endseq'],
#  '3019199755_a984bc21b1': ['startseq driver is at the wheel of race car endseq',
#   'startseq man inside red race car gives thumbs up sign endseq',
#   'startseq man is in red race car while another man is at the back of it endseq',
#   'startseq man is smiling whilst sitting inside red racing car endseq',
#   'startseq race car driver smiles and gives the thumbs up before race endseq'],
#  '3201594926_cd2009eb13': ['startseq girl wearing white polka dots and black boots walks and woman in blue outfit hurridly walks behind her endseq',
#   'startseq hip young woman down the street with woman in kimono walks behind her endseq',
#   'startseq woman in boots with big purse walks down the street followed by woman in blue endseq',
#   'startseq woman walks with her big purse endseq',
#   'startseq women walk down the street endseq'],
#  '2540751930_d71c7f5622': ['startseq man and woman walk away from the camera as redheaded man walks in the other direction endseq',
#   'startseq pedestrians walk on sidewalk next to grassy wooded field endseq',
#   'startseq people are walking around park area endseq',
#   'startseq people meandering around in grassy area with trees endseq',
#   'startseq young adults dressed casually walk around in field endseq'],
#  '1475046848_831245fc64': ['startseq blonde woman in blue shorts walks on the beach carrying her shoes endseq',
#   'startseq woman in blue shorts is carrying her shoes whilst walking on the beach next to the ocean endseq',
#   'startseq blond woman with blue shorts walks along beach carrying shoes in one hand endseq',
#   'startseq woman carrying her shoes on beach endseq',
#   'startseq woman in blue shorts walking barefoot on the beach endseq'],
#  '2877637572_641cd29901': ['startseq cute puppy fetches yellow ring chew toy in the yard endseq',
#   'startseq puppy is running across the grass with yellow toy in its mouth endseq',
#   'startseq tan dog is running through the grass with yellow toy in its mouth endseq',
#   'startseq tan dog with red collar runs with yellow toy in its mouth endseq',
#   'startseq fluffy golden puppy holding yellow rings in mouth while running through grass endseq'],
#  '1308472581_9961782889': ['startseq boy in blue shirt splashing in water under dock endseq',
#   'startseq laughing girl holding bucket splashes in the ocean endseq',
#   'startseq young girl plays under pier with blue bucket endseq',
#   'startseq girls with blue bucket is playing and splashing in the ocean water endseq',
#   'startseq the girl with the blue bucket splashes beneath the pier endseq'],
#  '2282260240_55387258de': ['startseq little girl dances in room with balloons on the floor endseq',
#   'startseq young girl dancing in her socks on wooden floor strewn with pink balloons endseq',
#   'startseq child with pink strings on head dancing surrounded by confetti balloons endseq',
#   'startseq little girl in brown shirt and bluejean skirt dances on wood floor endseq',
#   'startseq the blond girl is dancing inside house endseq'],
#  '2363419943_717e6b119d': ['startseq lady and her little girl are holding hands and walking up the sidewalk endseq',
#   'startseq mother and child run hand in hand through chinatown in an american city endseq',
#   'startseq woman and child both wearing red outfits walking up street endseq',
#   'startseq child in red holding the hand of person in red coat walking on sidewalk under awnings endseq',
#   'startseq woman and little girl wearing red in asian area endseq'],
#  '392976422_c8d0514bc3': ['startseq boy in blue shirt is walking along tan and blue wall endseq',
#   'startseq boy in stripes walking along ledge endseq',
#   'startseq boy scales the wall endseq',
#   'startseq child in striped shirt is walking along wall endseq',
#   'startseq boy in striped shirt walking along ledge endseq'],
#  '103205630_682ca7285b': ['startseq tent is being set up on the ice endseq',
#   'startseq two men are about to enter an ice fishing tent on snow covered lake endseq',
#   'startseq two men setting up blue ice fishing hut on an iced over lake endseq',
#   'startseq two men standing on an ice looking into something covered with blue tarp endseq',
#   'startseq two people standing outside blue tent structure on snowy surface endseq'],
#  '1347519824_e402241e4f': ['startseq few girls with green foam statue of liberty hats on train endseq',
#   'startseq some young adults are wearing green foam statute of liberty crowns endseq',
#   'startseq some young people take photos of each other while in new york endseq',
#   'startseq three woman with statue of liberty hats and taking picture endseq',
#   'startseq two woman wearing statue of liberty hats get their picture taken in subway endseq'],
#  '584484388_0eeb36d03d': ['startseq two brown dogs are playing with red ball endseq',
#   'startseq two brown dogs fight over red ball while playing in the grass endseq',
#   'startseq two brown dogs run over the grass carrying red toy endseq',
#   'startseq two daschunds play with red ball endseq',
#   'startseq two little wiener dogs are running on the grass carrying red ball between them endseq'],
#  '2460823604_7f6f786b1c': ['startseq boy baseball player in green and yellow jersey leaps for the ball endseq',
#   'startseq boy chasing baseball endseq',
#   'startseq little boy playing baseball goes for the ball on the ground endseq',
#   'startseq young boy dives to catch the ball during baseball game endseq',
#   'startseq the boy in the green and yellow shirt has glove on and is going towards the ball endseq'],
#  '121800200_bef08fae5f': ['startseq group of climbers begin up sheer rock face endseq',
#   'startseq group of rock climbers climb rock wall in forest endseq',
#   'startseq many people are climbing the mountain surrounded by pretty green trees endseq',
#   'startseq people at distance trying to climb cliff endseq',
#   'startseq the flat side of large rocky mountain endseq'],
#  '2422302286_385725e3cf': ['startseq child sits in plastic toy car endseq',
#   'startseq little kid in toy car endseq',
#   'startseq small girl riding in play car endseq',
#   'startseq there is child in red and yellow toy car endseq',
#   'startseq the small child is sitting in red and yellow toy car endseq'],
#  '3183883750_b6acc40397': ['startseq two girls hold up card reading know what this is endseq',
#   'startseq two kids smiling and holding card endseq',
#   'startseq two people pose for picure holding card that says know what this is endseq',
#   'startseq two people smile at the camera while holding sign endseq',
#   'startseq two teenage girls hold card referring to periods as they smile endseq'],
#  '3091912922_0d6ebc8f6a': ['startseq dog runs holding yellow dog toy in fall bench in the background endseq',
#   'startseq dog runs with yellow toy in its mouth endseq',
#   'startseq tan dog running through the grass with toy in his mouth endseq',
#   'startseq the brown dog is running through the grass with yellow toy in its mouth endseq',
#   'startseq the tan colored dog has yellow toy in its mouth endseq'],
#  '2787868417_810985234d': ['startseq blond girl in pink bathing suit running through the sprinklers endseq',
#   'startseq girl in pink runs through sprinkler endseq',
#   'startseq girl runs through sprinklers on lawn endseq',
#   'startseq little girl in pink in running through sprinkler endseq',
#   'startseq little girl wearing pink dress is running across the grass endseq'],
#  '3670075789_92ea9a183a': ['startseq child is sliding into small pool endseq',
#   'startseq girl in child swimming pool endseq',
#   'startseq little girl is sliding down short slide into an inflatable paddling pool endseq',
#   'startseq girl splashing in kiddie pool endseq',
#   'startseq the dark haired girl is sliding into white kiddie pool endseq'],
#  '3329169877_175cb16845': ['startseq lone snowboarder wearing white jacket jumping into the air on the snowy mountains endseq',
#   'startseq snowboarder flies through the air in front of leafless trees endseq',
#   'startseq snowboarder gets some air endseq',
#   'startseq snowboarder in green pants and white jacket is jumping high in the air endseq',
#   'startseq someone in green pants is on white snowboard in the air endseq'],
#  '751074141_feafc7b16c': ['startseq boy being pulled on shovel endseq',
#   'startseq happy child play in the scoop of shovel by chair in grassy backyard endseq',
#   'startseq little boy in red flowered shorts is sitting on shovel endseq',
#   'startseq little boy smiling and riding in shovel endseq',
#   'startseq small boy in red shorts with blue flowers sitting on shovel in the grass near tan chair endseq'],
#  '3445428367_25bafffe75': ['startseq person is standing on brick ledge taking picture of something in the distance endseq',
#   'startseq woman takes photograph endseq',
#   'startseq woman with long hair pointing her camera skyward as she stands on brick wall endseq',
#   'startseq the woman is holding camera and standing on brick wall endseq',
#   'startseq woman standing on brick wall and taking picture endseq'],
#  '3542418447_7c337360d6': ['startseq black dog and brown dog with yellow foam soccer ball toy on grassy field endseq',
#   'startseq brown dog and black dog playing with yellow soccer ball endseq',
#   'startseq two dogs on lawn play with plastic toy in distorted photograph endseq',
#   'startseq two dogs one brown one black with yellow toy black dog has mouth open and brown dog has the toy endseq',
#   'startseq two dogs run to catch yellow soccer ball endseq'],
#  '2730819220_b58af1119a': ['startseq little girl ends up at the bottom of the slide endseq',
#   'startseq little girl is just reaching the bottom of playground slide endseq',
#   'startseq little girl lands at the bottom of slide endseq',
#   'startseq young girl reaches the bottom of slide endseq',
#   'startseq young girl sliding down tan plastic slide endseq'],
#  '3543378438_47e2712486': ['startseq man dressed in green jacket is playing piano while woman sings endseq',
#   'startseq man is sitting in front of harpsichord and woman is preparing to sing endseq',
#   'startseq person playing the piano with singer nearby endseq',
#   'startseq pianist and singer are ready to perform endseq',
#   'startseq the man in the green jacket is playing the piano next to woman who is by music stand endseq'],
#  '2335619125_2e2034f2c3': ['startseq big black dog bares its teeth while running through the snow endseq',
#   'startseq black dog is running through the snow endseq',
#   'startseq black dog is running through the snow endseq',
#   'startseq black dog with his mouth open and tongue out runs across an expanse of snow endseq',
#   'startseq black dog runs through snow endseq'],
#  '3520199925_ca18d0f41e': ['startseq curly haired woman plays the violin endseq',
#   'startseq red haired woman is holding violin and boe endseq',
#   'startseq woman is playing violin while surrounded by transparent walls and pictures endseq',
#   'startseq woman playing the violin with posters in the background endseq',
#   'startseq the woman is holding violin endseq'],
#  '3374722123_6fe6fef449': ['startseq an elderly woman is wearing pink striped shirt endseq',
#   'startseq an older woman in pink striped shirt endseq',
#   'startseq an older woman with striped shirt rubbing her chin endseq',
#   'startseq woman in pink striped shirt with her hand up endseq',
#   'startseq older lady is appears to be getting ready to cover her mouth endseq'],
#  '3280672302_2967177653': ['startseq boy carries teenager on his back endseq',
#   'startseq boy struggles to carry girl on his back endseq',
#   'startseq person wearing black shirt is getting piggy back ride from person wearing black shirt walkng on paved path in the woods endseq',
#   'startseq teenage boy gives another teenage boy piggy back ride in forest endseq',
#   'startseq the boy is carrying the other boy endseq'],
#  '3073579130_7c95d16a7f': ['startseq man wears red bandanna endseq',
#   'startseq man with head covering endseq',
#   'startseq an man wearing an arab scarf with another man in the background endseq',
#   'startseq white man in turban endseq',
#   'startseq man with facial hair wearing red and white palestinian style headscarf endseq'],
#  '99679241_adc853a5c0': ['startseq grey bird stands majestically on beach while waves roll in endseq',
#   'startseq large bird stands in the water on the beach endseq',
#   'startseq tall bird is standing on the sand beside the ocean endseq',
#   'startseq water bird standing at the ocean edge endseq',
#   'startseq white crane stands tall as it looks out upon the ocean endseq'],
#  '3759492488_592cd78ed1': ['startseq boy hanging onto pole endseq',
#   'startseq kid in green shirt playing in the park endseq',
#   'startseq little kid swings on pole at playground endseq',
#   'startseq the boy in the green shirt swings with one arm on the silver pole endseq',
#   'startseq the boy is swinging on pole at the beach endseq'],
#  '2875528143_94d9480fdd': ['startseq girl wearing pink bounces on bed endseq',
#   'startseq little girl in pink leotard is jumping and landing in straddle split on blue bed endseq',
#   'startseq young girl jumping with her mouth open endseq',
#   'startseq little girl in pink hello kitty shirt is jumping endseq',
#   'startseq the girl in pink does midair leg splits endseq'],
#  '1052358063_eae6744153': ['startseq boy takes jump on his skateboard while another boy with skateboard watches endseq',
#   'startseq child is performing skateboard trick while another child with skateboard leans on wall endseq',
#   'startseq little boy skateboarder is doing trick on his board while another young skateboarder watches endseq',
#   'startseq young boy skateboarder jumping on platform on skateboard endseq',
#   'startseq two skateboarders endseq'],
#  '111766423_4522d36e56': ['startseq black and white bird eating seeds out of someone hand endseq',
#   'startseq black and white bird standing on hand endseq',
#   'startseq small bird sits in person hand and eats seeds endseq',
#   'startseq black and white bird standing on hand of someone holding sunflower seeds endseq',
# ...
#  '2546667441_bbe87a6285': ['startseq black dog is walking along the grass sniffing at the ground endseq',
#   'startseq black dog running in the grass endseq',
#   'startseq dog sniffs the grass endseq',
#   'startseq black dog on grass sniffing the ground endseq',
#   'startseq black dog with tan markings wearing blue collar standing on green grass endseq'],
#  '1301140633_046e4e8010': ['startseq boy in blue shirt with dirt on his face endseq',
#   'startseq boy with dirty face smiles endseq',
#   'startseq child with dirty face looks at the camera and smiles endseq',
#   'startseq blond child with dirty face holding yellow bottle with red cap plants in background endseq',
#   'startseq the boy has blonde hair and dirty face endseq'],
#  '458735196_176e7df6b3': ['startseq brown dog indoors with large pink toy endseq',
#   'startseq dog with wrinkled face bites on pink toy endseq',
#   'startseq wrinkled dog playing with pink chew toy endseq',
#   'startseq the dog is carrying pink ball in its mouth endseq',
#   'startseq this is strange sight dog delivering cookie endseq'],
#  '3304712466_18cbdb85fe': ['startseq bicycle racers being cheered on by some people endseq',
#   'startseq bicycle road racers passing group of cheering spectators endseq',
#   'startseq crowds cheer on cyclists as they complete race to the finish endseq',
#   'startseq people on bicycles riding through group of onlookers endseq',
#   'startseq racers on bikes riding past crowd endseq'],
#  '2721656220_5f4cda8bc1': ['startseq lady holds beverage endseq',
#   'startseq an attractive brunette woman smiles and holds beverage in front of her endseq',
#   'startseq woman holding drink and smiling endseq',
#   'startseq woman holds drink and smiles endseq',
#   'startseq this woman is wearing white shirt and holding cup endseq'],
#  '1253275679_e955fb7304': ['startseq boy has his head down and is wearing shirt that says adhd endseq',
#   'startseq young boy wearing clever black and white shirt with his head bowed down endseq',
#   'startseq the boy is wearing black shirt with an ad parody of the ac logo endseq',
#   'startseq young boy wearing an ac shirt looking down endseq',
#   'startseq young boy with black adhd shirt nodding off endseq'],
#  '3668984985_b60ceb2ae9': ['startseq family sits on bench in front of pool endseq',
#   'startseq few couples sitting on beanches next to pool endseq',
#   'startseq girl wearing boots stands next to swimming pool and four people seated on bench endseq',
#   'startseq group of people talking next to pool with trees in the background endseq',
#   'startseq people sit on bench by the pool endseq'],
#  '3241726740_6d256d61ec': ['startseq man smoking cigarette talking to lady who is sitting on steps endseq',
#   'startseq lady in black standing and smoking with another girl sitting on the steps endseq',
#   'startseq the person in black smoked while the woman in brown sat on the steps endseq',
#   'startseq the woman in the black coat is smoking and the woman in the gray coat sits on stone steps endseq',
#   'startseq two women smoking on the steps of white building endseq'],
#  '310213587_778fe8fb5b': ['startseq group of people sitting on benches at city park endseq',
#   'startseq man drinking beverage and holding plastic bag far away from the other people endseq',
#   'startseq man drinking soda is standing in front of bench near group of people sitting endseq',
#   'startseq man in black clothes and blue hat is taking drink and holding shopping bag endseq',
#   'startseq man is standing next to bench drinking soda while other people sit on bench nearby endseq'],
#  '2974501005_346f74e5d8': ['startseq boy does skateboard jump at skateboard park endseq',
#   'startseq kid doing trick on his skateboard endseq',
#   'startseq young boy is performing tricks with skateboard at skate park endseq',
#   'startseq young man rides yellow and black skateboard at the top of ramp endseq',
#   'startseq kid doing skateboard trick with his legs split and board between them endseq'],
#  '3716277216_c04002be81': ['startseq three african american women are dressed in bright orange and brown dresses and head scarves endseq',
#   'startseq three african women in traditional orange costume are gathered in front of yellow curtain endseq',
#   'startseq three women are dressed in african clothes and two of them are putting on make up endseq',
#   'startseq three women wearing traditional apparel make the final touches on their clothing endseq',
#   'startseq women are putting their robes and headdresses on endseq'],
#  '3320209694_db579cb607': ['startseq man in purple had climbs rocky wall with his hands endseq',
#   'startseq man with purple hat is climbing rock endseq',
#   'startseq man with purple hat and bandaged hand climbs wall of rock endseq',
#   'startseq young man in purple snow cap is rock climbing endseq',
#   'startseq this young man is rock climbing endseq'],
#  '3368865171_597d51cdd5': ['startseq child rides unicycle while crowd watches endseq',
#   'startseq little girl rides on bicycle during parade endseq',
#   'startseq small girl riding unicycle endseq',
#   'startseq girl in plaid shirt riding unicycle endseq',
#   'startseq person in checked shirt riding unicycle while crowd watches endseq'],
#  '124881487_36e668145d': ['startseq man on bicycle riding down rocky hill endseq',
#   'startseq man rides his dirt bike down rocky trail endseq',
#   'startseq person rides bike down rocky hill endseq',
#   'startseq blurry picture of mountain biker descending rocky trail endseq',
#   'startseq the mountain biker in blue rides down rocky path endseq'],
#  '2701603045_6cbdc4ce7c': ['startseq boy is wading through water endseq',
#   'startseq boy up to his knees in water endseq',
#   'startseq boy wearing white shorts walks through the water endseq',
#   'startseq young boy with white swim trunks walks out of the water endseq',
#   'startseq the boy is wading through the blue ocean endseq'],
#  '2278766574_f71f1704a8': ['startseq youn woman on man back walking down cement path with another couple behind them holding hands endseq',
#   'startseq people walk on path outside endseq',
#   'startseq several people are walking down trail endseq',
#   'startseq the man is giving woman piggyback ride through park endseq',
#   'startseq two couples walking on path adorned with trees bushes and grass endseq'],
#  '347543966_b2053ae78c': ['startseq group of men stand outside glass and steel building endseq',
#   'startseq three men are looking at wall very intently in city endseq',
#   'startseq three men stand in glass area endseq',
#   'startseq three people in glass structure endseq',
#   'startseq three people stand in an outdoor glass structure endseq'],
#  '1143882946_1898d2eeb9': ['startseq lady wearing helmet holding bike endseq',
#   'startseq woman in blue vest and sky blue helmet stands with her bicycle in traffic endseq',
#   'startseq woman in helmet rides her bike behind car endseq',
#   'startseq woman with helmet and backpack walks next to her bike endseq',
#   'startseq women with bike and helmet wait for traffic endseq'],
#  '2029280005_a19609c81a': ['startseq man in black shirt is rollerblading past bench in the city endseq',
#   'startseq man is inline skating in front of wooden bench endseq',
#   'startseq man is wearing rollerblades standing on paved area near park bench endseq',
#   'startseq man on rollerblades travelling down the sidewalk endseq',
#   'startseq man wearing black shirt and brown pants skates on concrete surface near park bench endseq'],
#  '3231751379_10ebf7150c': ['startseq goalie is crouching in defensive position in front of the goal endseq',
#   'startseq hockey player in blue and red guarding the goal endseq',
#   'startseq an ice hockey goalkeeper in red and blue strip is on his knees in front of the goal endseq',
#   'startseq an ice hockey player is bending down on the ice endseq',
#   'startseq the hockey player knelt on the ice endseq'],
#  '3069216757_c419b3898e': ['startseq girl in pink striped shirt is in front of an armoire endseq',
#   'startseq girl in pink striped shirt poses for the camera endseq',
#   'startseq girl wearing pink striped shirt throws her arms into the air endseq',
#   'startseq young girl wearing pink and orange stripped shirt extends her arms forward and appears to be happy endseq',
#   'startseq the girl wearing the pink striped shirt is standing in the doorway with her arm outstretched endseq'],
#  '3234719720_5bb2fc5ffa': ['startseq dark haired bearded man in white dress shirt and black sweater and woman in black and white dress in small space endseq',
#   'startseq man and women both in black and white are in an elevator endseq',
#   'startseq man with large beard and woman wearing white necklace smile endseq',
#   'startseq nicely dressed woman and bearded man in small room endseq',
#   'startseq smiling man leaning to his right stands behind smiling woman leaning to her left endseq'],
#  '491964988_414b556228': ['startseq little girl runs down path in japanese garden endseq',
#   'startseq little girl skips down path near an idyllic country pond endseq',
#   'startseq young girl hops on the path to avoid the puddles located near lake endseq',
#   'startseq young girl is jumping on gravel road near pond endseq',
#   'startseq the girl runs near pond endseq'],
#  '2474047296_fd9179d438': ['startseq man in white shirt and dress pants sits just underneath stone archway endseq',
#   'startseq man wearing white shirt and black pants sitting on staircase endseq',
#   'startseq an old man sits in an ancient brick archway endseq',
#   'startseq an old man with white shirt and black pants sits on chair in the opening of stone tunnel endseq',
#   'startseq elderly man sitting in doorway endseq'],
#  '3546891929_f31a99cd0d': ['startseq man in bicycle helmet is talking on cellphone with other people behind him endseq',
#   'startseq man in helmet holding cellphone endseq',
#   'startseq man in plaid shirt with red and black bike helmet on his cellphone endseq',
#   'startseq man wearing red bicycle helmet talking on cellphone with other people in the background endseq',
#   'startseq man with bicycle helmet on is using cellphone in the midst of crowd endseq'],
#  '2355763034_9fb61a8165': ['startseq flautist plays the flute in marching band endseq',
#   'startseq girl in band is playing the flute endseq',
#   'startseq girl in red and black uniform is playing the flute as part of marching band endseq',
#   'startseq woman in red uniform is playing the flute endseq',
#   'startseq girl in uniform playing flute with marching band endseq'],
#  '3065560742_f6e266ccd9': ['startseq boy playing hockey lies on the ice injured endseq',
#   'startseq the two hockey players are down on the ice endseq',
#   'startseq two hockey players fall on the ice endseq',
#   'startseq two hockey players fall to the ground in game endseq',
#   'startseq two hockey players slide into each other on the ice endseq'],
#  '265528702_8653eab9fa': ['startseq man in sunglasses and neatly trimmed beard overlooks woody valley endseq',
#   'startseq man posing with large grassy mountains off in the distance endseq',
#   'startseq man wearing sunglasses stands before forested landscape endseq',
#   'startseq man with beard and sunglasses is standing in front of tree covered hills endseq',
#   'startseq bearded man with sunglasses in the mountains endseq'],
#  '2687539673_d54a8dc613': ['startseq girl and young boy are jumping on trampoline in suburban yard endseq',
#   'startseq girl is jumping on trampoline with her arms in the air while boy in blue shirt is bouncing on his stomach endseq',
#   'startseq teenager girl jumps high on trampoline and toddler falls on his stomach endseq',
#   'startseq toddler and teenage girl jumping on trampoline endseq',
#   'startseq two children jump on trampoline endseq'],
#  '3067500667_0fce8f28d4': ['startseq cricket batsman has been bowled out middle stump endseq',
#   'startseq cricket player swings his bat but misses endseq',
#   'startseq man is standing in front of some red sticks trying to hit ball endseq',
#   'startseq man is swinging paddle at unique ball game endseq',
#   'startseq player hits the ball at cricket game endseq'],
#  '2657484970_610e18144f': ['startseq people are boating near mountain endseq',
#   'startseq two people in canoe are rowing past large tree covered mountain endseq',
#   'startseq two people in canoe float past rocky wooded cliff endseq',
#   'startseq two people in canoe on river beside forested mountain endseq',
#   'startseq two people in kayak are paddling past green foliage on river endseq'],
#  '407008823_bdd7fc6ed5': ['startseq climber is making his way up snowy mountainside endseq',
#   'startseq lone person jumping through the air from one snowy mountain to another endseq',
#   'startseq man doing tricks in the snow endseq',
#   'startseq man dressed in snow gear takes leap into snow covered ravine endseq',
#   'startseq people jump over mountain crevasse on rope endseq'],
#  '3675825945_96b2916959': ['startseq man in skateboarding in an empty swimming pool endseq',
#   'startseq man rides skateboard up the side of an empty pool endseq',
#   'startseq skateboarder dressed in white is dropping into blue bowl endseq',
#   'startseq skateboarder hanging off the edge of bowl at skate park endseq',
#   'startseq skateboarder in an empty pool endseq'],
#  '1557838421_a33f2a4911': ['startseq grey and white dog is biting the ear of white and brown dog endseq',
#   'startseq the brown and white dog nips at the yellow dog endseq',
#   'startseq there are two dogs playing with each other endseq',
#   'startseq two dogs wrestle with each other with their teeth bared endseq',
#   'startseq two large dogs attempt to bite each other playfully endseq'],
#  '544301311_5e7d69a517': ['startseq the women sit outside on the steps reading and drinking endseq',
#   'startseq two girls sit by doorway on the steps endseq',
#   'startseq two women in period dress sitting in doorway endseq',
#   'startseq two women in traditional european dress sit on stoop one drinking the other reading endseq',
#   'startseq two women with white head garb and long dresses sitting in front of door on steps reading and drinking beverage endseq'],
#  '3624076529_9793655a21': ['startseq brown dog swimming through lake with stick in his mouth endseq',
#   'startseq brown dog swimming with stick endseq',
#   'startseq dog holding stick swims in the water endseq',
#   'startseq dog swimming with stick in its mouth endseq',
#   'startseq golden dog swims with stick in its mouth endseq'],
#  '537479916_c033897fac': ['startseq black dog finishes running down blue and orange ramp endseq',
#   'startseq black dog has just run down blue and red ramp on an obstacle course endseq',
#   'startseq dog and person doing an agility course endseq',
#   'startseq dog runs dog ramp endseq',
#   'startseq dog runs down ramp past its trainer endseq'],
#  '2737729252_b3fd9c05b1': ['startseq girl is taking picture of another girl in park endseq',
#   'startseq girl is taking picture of another girl in park endseq',
#   'startseq woman takes picture of another in purple in park endseq',
#   'startseq one girl taking picture of her friend endseq',
#   'startseq two little girls playing in the parking lot endseq'],
#  '267162122_c3437414ec': ['startseq black puppy jumping on the back of white puppy endseq',
#   'startseq black dog and white dog wrestle endseq',
#   'startseq black dog and white dog wrestling next to food dish endseq',
#   'startseq black puppy stands over white puppy endseq',
#   'startseq small black dog is standing over small white dog laying on his side endseq'],
#  '2592711202_55f8c64495': ['startseq girl dressed in blue enjoys blue treat while putting her white shoe back on endseq',
#   'startseq girl in blue dress sitting on the ground eating cotton candy endseq',
#   'startseq girl in blue dress takes off her shoes and eats blue cotton candy endseq',
#   'startseq child in blue dress holding sandal in one hand and eating blue cotton candy with other hand endseq',
#   'startseq the girl in blue dress is eating some blue cotton candy with one shoe off and one shoe on endseq'],
#  ...}

# %%
encoding_test
# Out:
# {'3385593926_d3e9c21170.jpg': array([0.33316892, 0.38347754, 0.0725344 , ..., 0.9083217 , 0.35600552,
#         1.0914083 ], dtype=float32),
#  '2677656448_6b7e7702af.jpg': array([0.29442003, 0.09479222, 0.7021817 , ..., 0.01987058, 0.2909237 ,
#         0.10954218], dtype=float32),
#  '311146855_0b65fdb169.jpg': array([0.01134304, 0.08777486, 0.14328411, ..., 0.03006493, 1.1856282 ,
#         0.06956831], dtype=float32),
#  '1258913059_07c613f7ff.jpg': array([0.04770138, 1.435463  , 0.10770524, ..., 0.1334385 , 0.11505935,
#         2.0496504 ], dtype=float32),
#  '241347760_d44c8d3a01.jpg': array([0.06552811, 6.6828294 , 0.3176343 , ..., 0.06200404, 0.0374284 ,
#         0.04522504], dtype=float32),
#  '2654514044_a70a6e2c21.jpg': array([1.956204  , 0.04316799, 0.11143841, ..., 0.02008318, 0.68325484,
#         0.43294135], dtype=float32),
#  '2339106348_2df90aa6a9.jpg': array([0.08876347, 1.192791  , 0.07676525, ..., 0.01899937, 0.13417555,
#         0.13799475], dtype=float32),
#  '256085101_2c2617c5d0.jpg': array([0.619181  , 0.59047747, 0.03345924, ..., 0.34150848, 0.02107635,
#         0.21161863], dtype=float32),
#  '280706862_14c30d734a.jpg': array([0.5567606 , 1.1480238 , 0.38229254, ..., 0.3687687 , 0.06483267,
# %% [markdown]
# # Data Preprocessing - Captions

# %%
"""
word_to_idx is mapping between each unique word in all_vocab to int value 
and idx_to_word is vice-versa
"""


ix = 1
word_to_idx = {}
idx_to_word = {}

for e in all_vocab:
    word_to_idx[e] = ix
    idx_to_word[ix] = e
    ix +=1

# %%
#  need to add these 2 words as well

word_to_idx['startseq'] = 1846
word_to_idx['endseq'] = 1847

idx_to_word[1846] = 'startseq'
idx_to_word[1847] = 'endseq'

# %%
#  vocab_size is total vocabulary len +1 because we will append 0's as well. 

vocab_size = len(idx_to_word)+1
print(vocab_size)
# Out:
# 1848

# %%
all_captions_len = []

for key in train_descriptions.keys():
    for cap in train_descriptions[key]:
        all_captions_len.append(len(cap.split()))

max_len = max(all_captions_len)
print(max_len)
# Out:
# 35

# %% [markdown]
# # Data Preparation using Generator Function¶

# %%
def data_generator(train_descriptions, encoding_train, word_to_idx, max_len, num_photos_per_batch):

    X1, X2, y = [], [], []

    n=0

    while True:
        
        for key, desc_list in train_descriptions.items():
            n +=1

            photo = encoding_train[key+".jpg"]

            for desc in desc_list:
                
                seq = [ word_to_idx[word] for word in desc.split() if word in word_to_idx]  

                for i in range(1,len(seq)):

                    in_seq = seq[0:i]
                    out_seq = seq[i]

                    in_seq = pad_sequences([in_seq], maxlen=max_len, value=0, padding='post')[0]

                    out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]

                    X1.append(photo)
                    X2.append(in_seq)
                    y.append(out_seq)

            if n==num_photos_per_batch:
                yield ([np.array(X1), np.array(X2)], np.array(y))
                X1, X2, y = [], [], []
                n=0

# %% [markdown]
# # Word Embedding

# %%
#f = open("./GloVE/glove.6B.50d.txt", encoding='utf8')
f = open("./saved/glove.6B.50d.txt",encoding='utf8')

# %%
embedding_index = {}

for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype="float")
    
    embedding_index[word] = coefs
    
f.close()

# %% [markdown]
# # Converting words into vectors Directly - (Embedding Layer Output)

# %%
def get_embedding_output():
    
    emb_dim = 50
    embedding_output = np.zeros((vocab_size,emb_dim))
    
    for word, idx in word_to_idx.items():
        embedding_vector = embedding_index.get(word)
        
        if embedding_vector is not None:
            embedding_output[idx] = embedding_vector
            
    return embedding_output


embedding_output = get_embedding_output()

# %%
embedding_output.shape
# Out:
# (1848, 50)

# %% [markdown]
# # Model Architecture

# %%
# image feature extractor model

input_img_fea = Input(shape=(2048,))
inp_img1 = Dropout(0.3)(input_img_fea)
inp_img2 = Dense(256, activation='relu')(inp_img1)

# %%
# partial caption sequence model

input_cap = Input(shape=(max_len,))
inp_cap1 = Embedding(input_dim=vocab_size, output_dim=50, mask_zero=True)(input_cap)
inp_cap2 = Dropout(0.3)(inp_cap1)
inp_cap3 = LSTM(256)(inp_cap2)

# %%
decoder1 = add([inp_img2 , inp_cap3])
decoder2 = Dense(256, activation='relu')(decoder1)
outputs = Dense(vocab_size, activation='softmax')(decoder2)

# Merge 2 networks
model = Model(inputs=[input_img_fea, input_cap], outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 35)]         0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 2048)]       0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 35, 50)       92400       input_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 2048)         0           input_4[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 35, 50)       0           embedding_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          524544      dropout_2[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 256)          314368      dropout_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 256)          0           dense_3[0][0]
#                                                                  lstm_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 256)          65792       add_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1848)         474936      dense_4[0][0]
# ==================================================================================================
# Total params: 1,472,040
# Trainable params: 1,472,040
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.layers[2].set_weights([embedding_output])
model.layers[2].trainable = False

# %%
model.compile(loss="categorical_crossentropy", optimizer="adam")

# %% [markdown]
# # Train Our Model

# %%
    X1, X2, y = [], [], []
    num_photos_per_batch= 3

    n=0

    while True:
        
        for key, desc_list in train_descriptions.items():
            n +=1

            photo = encoding_train[key+".jpg"]

            for desc in desc_list:
                
                seq = [ word_to_idx[word] for word in desc.split() if word in word_to_idx]  

                for i in range(1,len(seq)):

                    in_seq = seq[0:i]
                    out_seq = seq[i]

                    in_seq = pad_sequences([in_seq], maxlen=max_len, value=0, padding='post')[0]

                    out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]

                    X1.append(photo)
                    X2.append(in_seq)
                    y.append(out_seq)

            if n==num_photos_per_batch:
                x_final = [np.array(X1), np.array(X2)]
                y_final = np.array(y)
                X1, X2, y = [], [], []
                n=0

# %%
epochs = 10
steps = len(train_descriptions)//number_pics_per_bath

# %%
for i in range(epochs):
    generator = data_generator(train_descriptions, encoding_train, word_to_idx, max_len, number_pics_per_bath)
    model.fit(x_final,y_final, epochs=1, steps_per_epoch=steps, verbose=1)
    model.save('./model_weights/model_' + str(i) + '.h5')

# %%
epochs = 10
number_pics_per_bath = 3
steps = len(train_descriptions)//number_pics_per_bath

# %%
for i in range(epochs):
    generator = data_generator(train_descriptions, encoding_train, word_to_idx, max_len, number_pics_per_bath)
    model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
    model.save('./model_weights/model_' + str(i) + '.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-76bf09fc713e> in <module>
#       1 for i in range(epochs):
#       2     generator = data_generator(train_descriptions, encoding_train, word_to_idx, max_len, number_pics_per_bath)
# ----> 3     model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
#       4     model.save('./model_weights/model_' + str(i) + '.h5')
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1845                   'will be removed in a future version. '
#    1846                   'Please use `Model.fit`, which supports generators.')
# -> 1847     return self.fit(
#    1848         generator,
#    1849         steps_per_epoch=steps_per_epoch,
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     862       results = self._stateful_fn(*args, **kwds)
#     863       if self._created_variables:
# --> 864         raise ValueError("Creating variables on a non-first call to a function"
#     865                          " decorated with tf.function.")
#     866       return results
#
# ValueError: Creating variables on a non-first call to a function decorated with tf.function.

# %%
encoding_train
# Out:
# {'260012_03d33305cf.jpg': array([0.3470795 , 0.51159084, 0.08728848, ..., 1.1897296 , 0.04043847,
#         0.1527106 ], dtype=float32),
#  '617548_d3e38d7f88.jpg': array([0.        , 0.00303404, 0.09360084, ..., 0.4310791 , 0.37979594,
#         0.9166435 ], dtype=float32),
#  '291921_fe7ae0c8f8.jpg': array([0.7674472 , 0.5342269 , 0.38325197, ..., 0.02098639, 0.18429385,
#         0.04270015], dtype=float32),
#  '16045_1c6d903fe0.jpg': array([6.2481058e-01, 3.2965460e-01, 1.7821058e-04, ..., 1.2753810e+00,
#         4.6392566e-01, 4.9036074e-01], dtype=float32),
#  '326817_8f45080b87.jpg': array([0.1155531 , 0.6596539 , 0.05323281, ..., 0.14397353, 1.0179375 ,
#         0.00556583], dtype=float32),
#  '42358_1755a9cce1.jpg': array([1.7061832 , 0.4051473 , 0.35206553, ..., 0.29408896, 0.04833031,
#         0.04654434], dtype=float32),
#  '968935_02f2cd8079.jpg': array([0.10608297, 1.4420797 , 0.04447002, ..., 0.20587179, 0.6978754 ,
#         1.590432  ], dtype=float32),
#  '342860_5288e203ea.jpg': array([0.46122536, 0.3323877 , 0.10834733, ..., 0.71413195, 0.        ,
#         0.06853592], dtype=float32),
#  '369467_8fc251595b.jpg': array([1.4792114 , 0.00732505, 0.1990863 , ..., 0.911336  , 0.07021052,
#         0.9363788 ], dtype=float32),
#  '786902_815a99a154.jpg': array([1.1178092 , 0.6061055 , 2.0033443 , ..., 1.3630112 , 0.49351892,
#         0.13383187], dtype=float32),
#  '304910_b5721199bc.jpg': array([0.13311353, 0.8839836 , 0.26648125, ..., 0.06137232, 0.30909884,
#         0.        ], dtype=float32),
#  '802527_94bd2b23b0.jpg': array([0.23148237, 0.41955256, 0.07108793, ..., 0.51854736, 0.292536  ,
#         0.8536098 ], dtype=float32),
#  '369156_074750c6cc.jpg': array([0.3818782 , 0.14747812, 0.95705813, ..., 1.2396249 , 0.6067537 ,
#         0.09615622], dtype=float32),
#  '598473_40637b5c04.jpg': array([0.9133097 , 0.17343298, 0.11540992, ..., 1.9545766 , 0.94113034,
#         0.01581051], dtype=float32),
#  '338263_a4fa073154.jpg': array([1.0365963 , 0.12317808, 0.2958485 , ..., 3.3519733 , 1.7793591 ,
#         0.41484973], dtype=float32),
#  '765956_6313d8cae3.jpg': array([0.4852698 , 0.53069174, 0.02347291, ..., 2.2674115 , 0.39438626,
#         0.12719129], dtype=float32),
#  '891333_b1b0fd1702.jpg': array([0.68717724, 0.82325536, 0.04614077, ..., 0.580301  , 0.32277524,
#         0.04854431], dtype=float32),
#  '887967_271a097464.jpg': array([0.9521603 , 0.29378942, 0.        , ..., 0.29402107, 0.11930709,
#         0.00695439], dtype=float32),
#  '28702_8653eab9fa.jpg': array([0.08854447, 0.02346901, 0.16821067, ..., 0.        , 0.        ,
#         0.67439276], dtype=float32),
#  '539673_d54a8dc613.jpg': array([0.06875198, 0.10609296, 0.15365985, ..., 0.46783906, 0.9590761 ,
#         0.05886733], dtype=float32),
#  '500667_0fce8f28d4.jpg': array([0.75720525, 3.1249123 , 0.01961731, ..., 1.5944678 , 0.45336682,
#         0.64769727], dtype=float32),
#  '484970_610e18144f.jpg': array([0.51081073, 0.04414028, 0.00772437, ..., 0.78429836, 0.11223575,
#         0.        ], dtype=float32),
#  '08823_bdd7fc6ed5.jpg': array([0.45115823, 2.6158314 , 0.        , ..., 0.07525696, 0.66879606,
#         0.        ], dtype=float32),
#  '825945_96b2916959.jpg': array([0.40501565, 0.3748037 , 0.15193506, ..., 1.0126328 , 0.1438267 ,
#         1.5070627 ], dtype=float32),
#  '838421_a33f2a4911.jpg': array([0.7515679 , 0.549046  , 0.510202  , ..., 0.16861133, 0.37967035,
#         0.12857203], dtype=float32),
#  '01311_5e7d69a517.jpg': array([0.852905  , 0.15831676, 0.71747124, ..., 0.414882  , 0.6047261 ,
#         0.19936511], dtype=float32),
#  '076529_9793655a21.jpg': array([1.6719826 , 0.45983368, 0.02224702, ..., 1.5215069 , 0.10599517,
#         0.48607403], dtype=float32),
#  '79916_c033897fac.jpg': array([0.29341614, 0.68819934, 0.03396511, ..., 0.86882   , 0.21497968,
#         0.09678081], dtype=float32),
#  '729252_b3fd9c05b1.jpg': array([5.1189816e-01, 3.4504399e-01, 3.6004125e-04, ..., 1.8665691e-01,
#         1.1546625e+00, 1.3712884e-01], dtype=float32),
#  '62122_c3437414ec.jpg': array([0.08635254, 0.23993513, 0.54427713, ..., 0.16394928, 0.15965247,
#         0.2726738 ], dtype=float32),
#  '711202_55f8c64495.jpg': array([0.35245472, 0.18302605, 0.28294978, ..., 0.04511109, 0.62672466,
#         0.071109  ], dtype=float32),
#  ...}

# %%
len(encoding_train)
# Out:
# 6000

# %%
train_descriptions
# Out:
# {'2513260012_03d33305cf': ['startseq black dog is running after white dog in the snow endseq',
#   'startseq black dog chasing brown dog through snow endseq',
#   'startseq two dogs chase each other across the snowy ground endseq',
#   'startseq two dogs play together in the snow endseq',
#   'startseq two dogs running through low lying body of water endseq'],
#  '2903617548_d3e38d7f88': ['startseq little baby plays croquet endseq',
#   'startseq little girl plays croquet next to truck endseq',
#   'startseq the child is playing croquette by the truck endseq',
#   'startseq the kid is in front of car with put and ball endseq',
#   'startseq the little boy is playing with croquet hammer and ball beside the car endseq'],
#  '3338291921_fe7ae0c8f8': ['startseq brown dog in the snow has something hot pink in its mouth endseq',
#   'startseq brown dog in the snow holding pink hat endseq',
#   'startseq brown dog is holding pink shirt in the snow endseq',
#   'startseq dog is carrying something pink in its mouth while walking through the snow endseq',
#   'startseq dog with something pink in its mouth is looking forward endseq'],
#  '488416045_1c6d903fe0': ['startseq brown dog is running along beach endseq',
#   'startseq brown dog wearing black collar running across the beach endseq',
#   'startseq dog walks on the sand near the water endseq',
#   'startseq brown dog running on the beach endseq',
#   'startseq the large brown dog is running on the beach by the ocean endseq'],
#  '2644326817_8f45080b87': ['startseq black and white dog with red frisbee standing on sandy beach endseq',
#   'startseq dog drops red disc on beach endseq',
#   'startseq dog with red frisbee flying in the air endseq',
#   'startseq dog catching red frisbee endseq',
#   'startseq the black dog is dropping red disc on beach endseq'],
#  '218342358_1755a9cce1': ['startseq cyclist wearing red helmet is riding on the pavement endseq',
#   'startseq girl is riding bike on the street while wearing red helmet endseq',
#   'startseq person on bike wearing red helmet riding down street endseq',
#   'startseq woman wears red helmet and blue shirt as she goes for bike ride in the shade endseq',
#   'startseq person in blue shirt and red helmet riding bike down the road endseq'],
#  '2501968935_02f2cd8079': ['startseq man dressed in purple shirt and red bandanna smiles at the people watching him endseq',
#   'startseq man on the street wearing leather chaps and chainmail codpiece endseq',
#   'startseq man wearing purple shirt and black leather chaps poses for the camera endseq',
#   'startseq man dressed in leather chaps and purple shirt stands in front of onlookers endseq',
#   'startseq there is man in purple shirt leather chaps and red bandanna standing near other men endseq'],
#  '2699342860_5288e203ea': ['startseq boy wearing red shirt is running through woodland endseq',
#   'startseq child runs near some trees endseq',
#   'startseq young boy is dancing around endseq',
#   'startseq young boy with red short sleeved shirt and jeans runs by some trees endseq',
#   'startseq the little boy in the red shirt stops to smile for the camera endseq'],
#  '2638369467_8fc251595b': ['startseq girl in white dress endseq',
#   'startseq little girl in white is looking back at the camera while carrying water grenade endseq',
#   'startseq smiling young girl in braids is playing ball endseq',
#   'startseq young girl wearing white looks at the camera as she plays endseq',
#   'startseq the girl is holding green ball endseq'],
#  '2926786902_815a99a154': ['startseq skier in yellow jacket is airborne above the mountains endseq',
#   'startseq skier jumps high in the air with view of the mountains endseq',
#   'startseq skiing man in fluorescent jacket jumps very high and it looks as though he is flying endseq',
#   'startseq somone is high in the air doing ski jump endseq',
#   'startseq the skier in the green jacket and white pants appears to almost fly into the sky endseq'],
#  '2851304910_b5721199bc': ['startseq photographer looks over the hills endseq',
#   'startseq woman in red jacket is videotaping natural landscape endseq',
#   'startseq woman with camera looks out over rolling hills endseq',
#   'startseq woman with camera on tripod is looking at the view endseq',
#   'startseq lady in red shirt has her camera set up in the field to record something endseq'],
#  '3423802527_94bd2b23b0': ['startseq bunch of girls in cheerleader outfits endseq',
#   'startseq large group of cheerleaders walking in parade endseq',
#   'startseq cheerleaders perform endseq',
#   'startseq many cheerleaders wearing black walk down the street endseq',
#   'startseq parade of cheerleaders wearing black pink and white uniforms endseq'],
#  '3356369156_074750c6cc': ['startseq blue boat with yellow canopy is floating on calm waters endseq',
#   'startseq boat in the water endseq',
#   'startseq boat with roof on green water endseq',
#   'startseq the boat is in the middle of the water endseq',
#   'startseq the solitude boat floats on the lake endseq'],
#  '2294598473_40637b5c04': ['startseq dog catches frisbee in midair endseq',
#   'startseq dog catching frisbee endseq',
#   'startseq terrier mix catches frisbee in the air endseq',
#   'startseq white and black dog catching frisbee endseq',
#   'startseq white dog is leaping in the air with green object in its mouth endseq'],
#  '1191338263_a4fa073154': ['startseq little old lady sitting next to an advertisement endseq',
#   'startseq an asian woman waiting at an underground train stop endseq',
#   'startseq an old woman sits in transit station next to backlit advertisement endseq',
#   'startseq woman sits in subway station endseq',
#   'startseq woman with an umbrella is sitting at station with an aquos commercial on the wall endseq'],
#  '2380765956_6313d8cae3': ['startseq blond girl wearing green jacket walks on trail along side metal fence endseq',
#   'startseq girl in green coat walks down rural road playing flute endseq',
#   'startseq young girl in parka playing flute while walking by fenced in field endseq',
#   'startseq girl in green and blue jacket walking past an enclosed field endseq',
#   'startseq girl playing flute as she walks by fence in rural area endseq'],
#  '3197891333_b1b0fd1702': ['startseq family of nine people including four children pose in front of brick fireplace with white mantle endseq',
#   'startseq family poses in front of the fireplace and christmas tree endseq',
#   'startseq family posing by the mantle and christmas tree endseq',
#   'startseq happy family poses by the fireplace endseq',
#   'startseq two couples and four kids pose for family picture endseq'],
#  '3119887967_271a097464': ['startseq man in sweater pointing at the camera endseq',
#   'startseq one man is posing with arms outstretched and finger pointed while another stares from behind him endseq',
#   'startseq the man in the black hat stands behind the man who is pointing his finger endseq',
#   'startseq two men look toward the camera while the one in front points his index finger endseq',
#   'startseq two men one wearing black hat while the one in front points standing in hallway endseq'],
#  '2276499757_b44dc6f8ce': ['startseq dog looks warily at the brown dog investigating his area endseq',
#   'startseq large brown dog is looking at medium sized black dog endseq',
#   'startseq small black dog looks at larger brown dog in grassy field endseq',
#   'startseq the big brown dog looks at the small black dog in tall grass endseq',
#   'startseq there is big dog looking at little dog endseq'],
#  '2506892928_7e79bec613': ['startseq three children in field with white flowers endseq',
#   'startseq three children one with stuffed kitten in field of flowers endseq',
#   'startseq three children play in the garden endseq',
#   'startseq three children pose among wildflowers endseq',
#   'startseq three kids palying with toy cat in garden endseq'],
#  '2187222896_c206d63396': ['startseq boy in red shirt in front of long blue wall raises his eyebrow at the camera endseq',
#   'startseq boy in red shirt with stripes standing near blue brick wall with handicap signs endseq',
#   'startseq an african american boy stands in front of blue building in the handicapped space endseq',
#   'startseq the boy in the orange shirt looks backwards endseq',
#   'startseq the boy in the red shirt is next to blue wall endseq'],
#  '2826769554_85c90864c9': ['startseq brown dog is carrying wet stick on the shore of the ocean endseq',
#   'startseq dog bounds across the sandy beach with stick in his mouth and water splashing off his paws endseq',
#   'startseq wet blond dog carries stick on the shore endseq',
#   'startseq the dog is running along the beach next to the ocean with stick in its mouth endseq',
#   'startseq the wet brown dog has stick in his mouth and is running in the sand next to the water endseq'],
#  '3097196395_ec06075389': ['startseq two dogs are racing on ractrack endseq',
#   'startseq two dogs race across the track endseq',
#   'startseq two greyhounds race endseq',
#   'startseq two greyhounds with muzzles race along the inside curb of railed dirt track endseq',
#   'startseq two racing dogs run around track endseq'],
#  '3603116579_4a28a932e2': ['startseq baseball pitcher with shelton on his shirt throws the ball endseq',
#   'startseq baseball player in black and orange shirt and with glove on pitches the ball endseq',
#   'startseq male dressed in sports outfit tries to catch baseball endseq',
#   'startseq man playing baseball endseq',
#   'startseq the baseball player is running after the ball endseq'],
#  '3339263085_6db9fd0981': ['startseq brown dog wades through water and walks toward rock endseq',
#   'startseq dog has waded through shallow water to reach rock outcropping endseq',
#   'startseq light brown dog is splashing in the water with its paw endseq',
#   'startseq small brown dog is about ready to exit the water after swim endseq',
#   'startseq yellow dog in shallow water endseq'],
#  '2532262109_87429a2cae': ['startseq group of girls in school uniforms are standing together and waiting to cross the street while one girl takes picture endseq',
#   'startseq group of people are standing together outside as one takes photograph endseq',
#   'startseq group of school girls are standing together while one is taking pictures endseq',
#   'startseq group of young women stand together endseq',
#   'startseq girls in school uniforms endseq'],
#  '2076906555_c20dc082db': ['startseq boy wearing jean jacket with his hand on his chest smiling at the camera endseq',
#   'startseq boy with bruised nose and writing on his hands is standing in video rental store endseq',
#   'startseq boy with writing on his hand is standing in store endseq',
#   'startseq young man in jean jacket smiles for the camera inside store endseq',
#   'startseq young man with denim jacket and writing on his hand smiles in front of bookcase full of videos endseq'],
#  '2502007071_82a8c639cf': ['startseq group of people in front of house endseq',
#   'startseq man in stripes woman in sunglasses and child in blue hat in front of brick building endseq',
#   'startseq woman in sunglasses and blue flowered shirt stands while boy and man sit nearby endseq',
#   'startseq woman wearing sunglasses and flowered shirt looks to the left endseq',
#   'startseq three adults and one child are waiting outside of building perhaps school endseq'],
#  '3113769557_9edbb8275c': ['startseq woman stands in front of display case and another woman looks at digital camera endseq',
#   'startseq woman stands tall in front of glass display while another woman takes picture of something endseq',
#   'startseq woman stands with her arms out at her sides while another takes picture endseq',
#   'startseq woman stands with her arms out in store while another woman holds camera endseq',
#   'startseq one woman is taking picture and another woman is standing sideways with her arm out endseq'],
#  '3325974730_3ee192e4ff': ['startseq snowboarder jumps high into the air off of snowy ramp endseq',
#   'startseq snowboarder jumps off ramp endseq',
#   'startseq man on snowboard performing trick high in the air endseq',
#   'startseq person in purple coat making jump on snowboard endseq',
#   'startseq snowboarder jumps off high ramp over icy landscape endseq'],
#  '1655781989_b15ab4cbff': ['startseq group of mountain climbers endseq',
#   'startseq group of people walking in line through the snow toward mountain endseq',
#   'startseq line of people are making their way through snow covered mountains endseq',
#   'startseq people are walking through snow covered field with mountain the background endseq',
#   'startseq people facing mountains in the snow endseq'],
#  '1662261486_db967930de': ['startseq black and white dog is jumping through black and white hoop endseq',
#   'startseq black and white dog jumps through black and white hoop endseq',
#   'startseq brown and white dog jumping through black and white hoop endseq',
#   'startseq dog jumping through black and white hoop endseq',
#   'startseq dog jumping through ring endseq'],
#  '2410562803_56ec09f41c': ['startseq girl using laptop another girl and boy looking at his cellphone endseq',
#   'startseq group of people sit against building and use electronics endseq',
#   'startseq three people sit near street endseq',
#   'startseq three people sitting in front of store on bench endseq',
#   'startseq three young people sit outside and engage with electronic devices endseq'],
#  '2469498117_b4543e1460': ['startseq dog races while wearing number endseq',
#   'startseq greyhound wearing muzzle and the number six on yellow jacket is running on dog track endseq',
#   'startseq muzzle greyhound dog running on track endseq',
#   'startseq tan greyhound wearing gold shirt with number on it runs down track endseq',
#   'startseq muxzzled greyhound leaping in race with yellow jacket endseq'],
#  '69710415_5c2bfb1058': ['startseq group of people stand at the edge of cliff over the ocean endseq',
#   'startseq group of three boy scouts rest on bluff overlooking the ocean endseq',
#   'startseq three men stand on cliff overlooking lake endseq',
#   'startseq three scouts are on top of cliff overlooking the ocean endseq',
#   'startseq two men are sitting on rock near the ocean with another man standing nearby endseq'],
#  '3414734842_beb543f400': ['startseq couple holding hands and another woman are walking down wooded trail endseq',
#   'startseq couple holding hands and woman standing beside them pose on tree lined dirt road endseq',
#   'startseq three friends on stroll in the forest endseq',
#   'startseq three people stand on path through the woods endseq',
#   'startseq two women and man posing on rural path endseq'],
#  '3006217970_90b42e6b27': ['startseq car sponsored by riwal is smoking its tires on wet road endseq',
#   'startseq race car drives along track in the rain endseq',
#   'startseq racing car is driving around wet track with its headlights on endseq',
#   'startseq small race car with advertising is driving on rainy track endseq',
#   'startseq sponsored race car is driving with lights on wet raceway endseq'],
#  '2192411521_9c7e488c5e': ['startseq bearded man wearing bandanna is pointing his finger whilst riding bicycle endseq',
#   'startseq man bicycles down the street and points his finger endseq',
#   'startseq man holds an object with his hand while riding his bike down the street endseq',
#   'startseq man with long hair riding bicycle gives the peace sign endseq',
#   'startseq man in blue shirt and black cap riding bike down street flashing peace sign endseq'],
#  '3535879138_9281dc83d5': ['startseq crowd of people waving red flags are passing under bridge endseq',
#   'startseq group of people walk down the street carrying red flags endseq',
#   'startseq large group of people walking down street some carrying flags or banners endseq',
#   'startseq many people walking together on pavement near brick building with other people looking on endseq',
#   'startseq many people walk in the street endseq'],
#  '2685788323_ceab14534a': ['startseq man in sunglasses gets ready to pull chair out to sit down for his meal endseq',
#   'startseq man wearing sunglasses stands by table at cafe endseq',
#   'startseq man about to pull out chair and sit down at restaurant endseq',
#   'startseq man at eatery getting ready to sit down endseq',
#   'startseq the large man grabs seat at restaurant endseq'],
#  '3465606652_f380a38050': ['startseq boy holding racket is standing in the grass endseq',
#   'startseq boy in purple shirt and blue jeans is standing in the grass holding round toy with handle endseq',
#   'startseq boy playes with stringless racket in his backyard endseq',
#   'startseq boy walks through the lawn endseq',
#   'startseq child in purple clothing is playing with toy inside yard with other toys and fence endseq'],
#  '2599131872_65789d86d5': ['startseq two blond girls are playing together endseq',
#   'startseq two girls enjoy themselves whilst wind blows through their hair endseq',
#   'startseq two girls with long hair jumping on trampoline endseq',
#   'startseq two little blonde girls twirl their hair endseq',
#   'startseq two little girls are playing on trampoline endseq'],
#  '2244613488_4d1f9edb33': ['startseq four bicyclists ride along dirt road between two wire fences endseq',
#   'startseq four cyclists on country trail are passing by an electricity pylon endseq',
#   'startseq the four bicyclists are riding through the desert endseq',
#   'startseq three bikers bike across the dry land endseq',
#   'startseq three cyclists ride near mountain endseq'],
#  '2738077433_10e6264b6f': ['startseq dog climbing steep dirt hill endseq',
#   'startseq dog climbs hill endseq',
#   'startseq great dane climbing steep hill endseq',
#   'startseq light brown dog is running up endseq',
#   'startseq light dog climbing wall of dirt endseq'],
#  '3537201804_ce07aff237': ['startseq child spins on merry go round endseq',
#   'startseq childern are playing on merry go round as adults on bench watch them endseq',
#   'startseq children play on merry go round as adults look on from bench endseq',
#   'startseq fathers watch as their children enjoy the spinning merry go round endseq',
#   'startseq two kids sit in the middle of playground toy that spins around them endseq'],
#  '1597557856_30640e0b43': ['startseq brown dog is jumping up at woman who is wearing brown skirt endseq',
#   'startseq golden retriever is excitedly greeting woman as little dog walks towards the camera endseq',
#   'startseq tan dog jumping up at woman in skirt and black and tan dog walking away endseq',
#   'startseq yellow dog jumps to greet woman endseq',
#   'startseq one dog is jumping at the lady while the other walks away endseq'],
#  '3357194782_c261bb6cbf': ['startseq man in the dooorway of bus looking onward endseq',
#   'startseq man standing at the door of vehicle with another sitting glancing out the window endseq',
#   'startseq people ride bus or trolley endseq',
#   'startseq some people riding an old bus endseq',
#   'startseq three passengers on train car endseq'],
#  '3682038869_585075b5ff': ['startseq little girl is peaking out from behind tree endseq',
#   'startseq little girl peering out from behind tree endseq',
#   'startseq young girl hiding behind tree in forest endseq',
#   'startseq young girl peeking out from behind tree in wooded area endseq',
#   'startseq young girl wearing striped dress peeks out from behind tree endseq'],
#  '236474697_0c73dd5d8b': ['startseq group of people hold drinks and point at the camera endseq',
#   'startseq group of people are holding up drinks and pointing to the camera endseq',
#   'startseq group of young people holding bottles and pointing at the camera endseq',
#   'startseq several young people posing for this photo holding beers endseq',
#   'startseq young adults stand pointing at the person taking the picture endseq'],
#  '2641288004_30ce961211': ['startseq border collie jumps over bed with tennis ball in its mouth endseq',
#   'startseq dog jumping with ball in its mouth endseq',
#   'startseq dog jumps on bed and catches green toy endseq',
#   'startseq border collie jumps in the air and catches tennis ball endseq',
#   'startseq the black and white dog jumps with tennis ball in its mouth endseq'],
#  '267164457_2e8b4d30aa': ['startseq climber walks along snowy peak endseq',
#   'startseq man climbs over snow covered rocks by shore endseq',
#   'startseq man is standing on snowcapped mountain endseq',
#   'startseq person hikes down snowy mountain endseq',
#   'startseq there man on top of an snow covered mountain with lake behind him endseq'],
#  '2453891449_fedb277908': ['startseq white dog chasing black dog across the grass endseq',
#   'startseq white dog is following black dog through the grassy area endseq',
#   'startseq there are two dogs black and white and the black one is jumping endseq',
#   'startseq two dogs running in grassy fenced in area surrounded by trees endseq',
#   'startseq two dogs running through yard with forest in the distance endseq'],
#  '281419391_522557ce27': ['startseq black race car spins its tires while smoke comes out endseq',
#   'startseq black race car starts up in front of crowd of people endseq',
#   'startseq broken down car during race endseq',
#   'startseq race car smoking very badly on the racetrack endseq',
#   'startseq red bull branded race car leaves smoke behind it in front of crowd endseq'],
#  '354999632_915ea81e53': ['startseq person behind some bags inside an igloo endseq',
#   'startseq snowy cave full of luggage endseq',
#   'startseq inside the igloo the young man gets ready for his overnight stay endseq',
#   'startseq some backpacks piled up in an ice cave with person dressed in black in the background endseq',
#   'startseq there is something visible through the hole in the wall endseq'],
#  '3109136206_f7d201b368': ['startseq brown dog drinks from body of water endseq',
#   'startseq brown dog is starting to walk into water endseq',
#   'startseq brown dog steps into murky water endseq',
#   'startseq dog getting into some water endseq',
#   'startseq dog putting his legs into pond endseq'],
#  '2281054343_95d6d3b882': ['startseq man wearing black hat is walking through busy city street endseq',
#   'startseq silhouette of man in hat on busy city street endseq',
#   'startseq person with black hat and black coat near buildings with signs endseq',
#   'startseq three people in crowded city area endseq',
#   'startseq thre is shot of man with his back turned in city endseq'],
#  '3296584432_bef3c965a3': ['startseq brown dog chases something man behind him threw on the beach endseq',
#   'startseq man and dog on the beach endseq',
#   'startseq man is interacting with dog that is running in the opposite direction endseq',
#   'startseq man playing fetch with his dog on beach endseq',
#   'startseq man walking behind running dog on the beach endseq'],
#  '3526431764_056d2c61dc': ['startseq woman taking photo standing next to tall man and in front of another man who is also taking photo endseq',
#   'startseq three people are outdoors taking pictures endseq',
#   'startseq three people holding cameras are standing on dirt trail with grass on the side of it endseq',
#   'startseq three people taking pictures with their cameras endseq',
#   'startseq two people are taking pictures while third is holding camera endseq'],
#  '3549997413_01388dece0': ['startseq man is skiing down mountain with another large mountain behind him and river between the mountains endseq',
#   'startseq man is skiing down snowy hill with large mountain in the background endseq',
#   'startseq man skiing down snow covered mountain endseq',
#   'startseq person skis down snowy mountain endseq',
#   'startseq skier goes down hill with mountain as backdrop endseq'],
#  '143688895_e837c3bc76': ['startseq boy climbing rock face endseq',
#   'startseq climber is standing on the rock face next to the pink rope endseq',
#   'startseq man climbing cliff with rope endseq',
#   'startseq man climbs steep rocks endseq',
#   'startseq man rock climbing in the forest surrounded by light endseq'],
#  '2495394666_2ef6c37519': ['startseq brown dog is standing in lake endseq',
#   'startseq brown dog is swimming in creek endseq',
#   'startseq dog swimming in pond endseq',
#   'startseq dog swimming in body of water endseq',
#   'startseq the brown dog is swimming in the water endseq'],
#  '3384742888_85230c34d5': ['startseq dog plays with toy in the grass endseq',
#   'startseq rotweiler playfully rolls over int he grass with toy endseq',
#   'startseq black and tan dog playing with toy and rolling on the grass endseq',
#   'startseq dog chewing up ball while rolling in grass endseq',
#   'startseq the dog is resting after game of fetch endseq'],
#  '1160034462_16b38174fe': ['startseq elderly man in straw hat is sitting on bench endseq',
#   'startseq elderly man sits alone on park bench endseq',
#   'startseq an old man in straw hat sits on park bench endseq',
#   'startseq the old man in the brown hat is sitting on the bench endseq',
#   'startseq white haired man in gray sweater and straw hat sitting on bench under tree endseq'],
#  '334768700_51c439b9ee': ['startseq dark haired man in red shirt with beard playing the guitar in park endseq',
#   'startseq man in red shirt plays guitar in park endseq',
#   'startseq man is sitting and playing guitar on the grass endseq',
#   'startseq man sitting in the grass playing his guitar wearing red shirt endseq',
#   'startseq man wearing red plays his guitar on the grass endseq'],
#  '412101267_7257e6d8c0': ['startseq two black dogs are jumping and playing with yellow tennis ball in the snow endseq',
#   'startseq two dog play in the snow endseq',
#   'startseq two dogs one with tennis ball in his mouth play together in the snow endseq',
#   'startseq two dogs playing with ball in the snow endseq',
#   'startseq two dogs play with tennis ball in the snow endseq'],
#  '2623939135_0cd02ffa5d': ['startseq an attractive woman holds halo above her head endseq',
#   'startseq woman in dress raises her arm over her head endseq',
#   'startseq woman is looking at the ceiling while taking off her hat endseq',
#   'startseq woman looking up towards wide ring she is holding over her head drink in her other hand endseq',
#   'startseq woman looking upward with her hand above her head endseq'],
#  '3043266735_904dda6ded': ['startseq an elderly person with white hat is reading paperback book endseq',
#   'startseq an elder woman in hat and scarf is looking through book she has in her hands endseq',
#   'startseq an older woman wearing hat reads book endseq',
#   'startseq an old lady consulting paperback book endseq',
#   'startseq woman in white hat reading book endseq'],
#  '3034585889_388d6ffcc0': ['startseq looker on catches motocross bike on its side after spill while another races by endseq',
#   'startseq man on dirt bike zipping away while another one slips to the ground and third man in yellow jacket looks on endseq',
#   'startseq man on motorcycle making tight turn endseq',
#   'startseq person is riding their motorbike and person in bright yellow jacket is watching someone fall off their bike endseq',
#   'startseq bike rider is looking at accident of other sports bike rider endseq'],
#  '2069279767_fb32bfb2de': ['startseq the men are climbing endseq',
#   'startseq two men are lying in red cots on the side of mountain endseq',
#   'startseq two men are sleeping on makeshift beds on the side of cliff endseq',
#   'startseq two men in cots hanging from cliff endseq',
#   'startseq two mountain climbers are smiling on the mountainside endseq'],
#  '2593406865_ab98490c1f': ['startseq skateboarder jumps off his skateboard in midair in hopes of landing back on it endseq',
#   'startseq teenage boy is performing trick with his skateboard endseq',
#   'startseq young man is flipping skateboard during trick endseq',
#   'startseq young skateboarder doing tricks in the air endseq',
#   'startseq the man is performing trick on skateboard near onlookers endseq'],
#  '432167214_c17fcc1a2d': ['startseq dark colored man is holding protest banner in busy city street with people staring from behind endseq',
#   'startseq man in blue and yellow jacket holding religious sign stands in street with people behind him on the sidewalk endseq',
#   'startseq man is holding religious poster endseq',
#   'startseq man wearing hat holding sign with writing on it endseq',
#   'startseq man standing on the street holding sign endseq'],
#  '305749904_54a612fd1a': ['startseq man is wearing blue shirt with the word mambo on it endseq',
#   'startseq man is wearing shirt that reads mambo with an image of baby and teddy bear endseq',
#   'startseq man wears shirt showing baby humping stuffed bear endseq',
#   'startseq person wearing blue mambo shirt has his back to the camera endseq',
#   'startseq the man is wearing blue shirt endseq'],
#  '2780087302_6a77658cbf': ['startseq man in black shirt sits on stool while trying to sell stuffed animals endseq',
#   'startseq man is outside selling various toys endseq',
#   'startseq vendor sells children toys as visitors walk by endseq',
#   'startseq vendor sells inflatable toys and stuffed animals on the sidewalk endseq',
#   'startseq man sits on stool beside toys endseq'],
#  '3051998298_38da5746fa': ['startseq guy in navy blue and yellow shorts jumping into pool endseq',
#   'startseq man catches football in midair while jumping into pool endseq',
#   'startseq man in swim trunks is jumping into pool while in strange pose endseq',
#   'startseq antics in covered pool endseq',
#   'startseq people are diving into swimming pool endseq'],
#  '1574401950_6bedc0d29b': ['startseq boy jumps from the top of blue plastic slide endseq',
#   'startseq child jumps over the slide portion of playground equipment shaded by trees endseq',
#   'startseq little boy in striped shirt jumps from blue slide endseq',
#   'startseq little boy is jumping off the top of slide endseq',
#   'startseq young boy jumps on slide in backyard endseq'],
#  '539493431_744eb1abaa': ['startseq man is playing with fire baton in the day light endseq',
#   'startseq man juggling fire endseq',
#   'startseq man stands near playground endseq',
#   'startseq man throws flames outside endseq',
#   'startseq the guy is holding black stick in front of playground endseq'],
#  '3524436870_7670df68e8': ['startseq brown dog playing with bubbles endseq',
#   'startseq brown dog walking across lawn as bubbles float by endseq',
#   'startseq dark brown dog is looking at bubbles while walking on green grass endseq',
#   'startseq dog catching bubbles on the grass endseq',
#   'startseq the brown dog is chasing and popping bubbles endseq'],
#  '2081446176_f97dc76951': ['startseq guy with scarf and woven toboggan endseq',
#   'startseq man in black and white cap and scarf endseq',
#   'startseq man wearing scarf and knitted hat is smiling endseq',
#   'startseq person wearing hat and scarf looks to the right endseq',
#   'startseq the man has poof on top of his woolen hat endseq'],
#  '2265367960_7928c5642f': ['startseq boy sitting down smiling for the picture endseq',
#   'startseq child holding some shoes endseq',
#   'startseq child in blue and wearing hat smiles endseq',
#   'startseq young boy smiling and holding sandals endseq',
#   'startseq the boy is wearing hat and holding sandals endseq'],
#  '460350019_af60511a3b': ['startseq black dog and woman in red shirt playing tug of war endseq',
#   'startseq dog is pulling on one end of rope and girl is pulling on the other endseq',
#   'startseq woman plays tug of war with her black dog in brown landscape surrounded by trees endseq',
#   'startseq woman plays with her rottweiler dog outside endseq',
#   'startseq woman and dog playing outside endseq'],
#  '2976946039_fb9147908d': ['startseq group of people surf on very large wave endseq',
#   'startseq group of surfers catching wave endseq',
#   'startseq people surfing and attempting to surf in the ocean on big wave endseq',
#   'startseq several people are surfing on wave in the sea endseq',
#   'startseq surfers on huge ocean wave at sunset endseq'],
#  '2308108566_2cba6bca53': ['startseq man rides bike on dirt path endseq',
#   'startseq person biking through the woods endseq',
#   'startseq person dirtbikes along muddy trail endseq',
#   'startseq dirt bike rider riding down the slope endseq',
#   'startseq person rides dirt bike down dirt hill endseq'],
#  '3367758711_a8c09607ac': ['startseq there are two women crossing the street in front of two buses endseq',
#   'startseq two women in headwraps are hurrying past buses endseq',
#   'startseq two women walk in front of bus to cross the road endseq',
#   'startseq two women walk on the street in front of two buses endseq',
#   'startseq two women with their heads covered crossing the road in front of buses endseq'],
#  '3666056567_661e25f54c': ['startseq group of people walk down city street at night endseq',
#   'startseq group of people walking down the street with one on the phone in green hat endseq',
#   'startseq four people are walking along city sidewalk while the one in the green hat talks on cellphone endseq',
#   'startseq four people are walking on sidewalk endseq',
#   'startseq four people walk down sidewalk at night endseq'],
#  '3099264059_21653e2536': ['startseq skateboarder is jumping almost as high as building endseq',
#   'startseq snowboarder jumping off tall brick building endseq',
#   'startseq snowboarder jumps over pile of snow endseq',
#   'startseq snowboarder jumps off rail over snowpile endseq',
#   'startseq the snowboarder is doing stunt high in the air at night endseq'],
#  '2988439935_7cea05bc48': ['startseq man in red soccer uniform getting ready to kick the ball endseq',
#   'startseq man in red uniform plays in soccer game endseq',
#   'startseq man in red uniform runs towards soccer ball on field endseq',
#   'startseq player in red uniform gets ready to kick the ball during soccer match as the crowd watches endseq',
#   'startseq soccer player in red uniform runs after soccer ball endseq'],
#  '241345864_138471c9ea': ['startseq boy cheerleader has girl cheerleader on his knee endseq',
#   'startseq female cheerleader sits on the knee of male cheerleader endseq',
#   'startseq cheerleaders taking break endseq',
#   'startseq the cheerleader in red and white is sitting on the knee of man also wearing red and white endseq',
#   'startseq two cheerleaders are sitting at football game endseq'],
#  '3019199755_a984bc21b1': ['startseq driver is at the wheel of race car endseq',
#   'startseq man inside red race car gives thumbs up sign endseq',
#   'startseq man is in red race car while another man is at the back of it endseq',
#   'startseq man is smiling whilst sitting inside red racing car endseq',
#   'startseq race car driver smiles and gives the thumbs up before race endseq'],
#  '3201594926_cd2009eb13': ['startseq girl wearing white polka dots and black boots walks and woman in blue outfit hurridly walks behind her endseq',
#   'startseq hip young woman down the street with woman in kimono walks behind her endseq',
#   'startseq woman in boots with big purse walks down the street followed by woman in blue endseq',
#   'startseq woman walks with her big purse endseq',
#   'startseq women walk down the street endseq'],
#  '2540751930_d71c7f5622': ['startseq man and woman walk away from the camera as redheaded man walks in the other direction endseq',
#   'startseq pedestrians walk on sidewalk next to grassy wooded field endseq',
#   'startseq people are walking around park area endseq',
#   'startseq people meandering around in grassy area with trees endseq',
#   'startseq young adults dressed casually walk around in field endseq'],
#  '1475046848_831245fc64': ['startseq blonde woman in blue shorts walks on the beach carrying her shoes endseq',
#   'startseq woman in blue shorts is carrying her shoes whilst walking on the beach next to the ocean endseq',
#   'startseq blond woman with blue shorts walks along beach carrying shoes in one hand endseq',
#   'startseq woman carrying her shoes on beach endseq',
#   'startseq woman in blue shorts walking barefoot on the beach endseq'],
#  '2877637572_641cd29901': ['startseq cute puppy fetches yellow ring chew toy in the yard endseq',
#   'startseq puppy is running across the grass with yellow toy in its mouth endseq',
#   'startseq tan dog is running through the grass with yellow toy in its mouth endseq',
#   'startseq tan dog with red collar runs with yellow toy in its mouth endseq',
#   'startseq fluffy golden puppy holding yellow rings in mouth while running through grass endseq'],
#  '1308472581_9961782889': ['startseq boy in blue shirt splashing in water under dock endseq',
#   'startseq laughing girl holding bucket splashes in the ocean endseq',
#   'startseq young girl plays under pier with blue bucket endseq',
#   'startseq girls with blue bucket is playing and splashing in the ocean water endseq',
#   'startseq the girl with the blue bucket splashes beneath the pier endseq'],
#  '2282260240_55387258de': ['startseq little girl dances in room with balloons on the floor endseq',
#   'startseq young girl dancing in her socks on wooden floor strewn with pink balloons endseq',
#   'startseq child with pink strings on head dancing surrounded by confetti balloons endseq',
#   'startseq little girl in brown shirt and bluejean skirt dances on wood floor endseq',
#   'startseq the blond girl is dancing inside house endseq'],
#  '2363419943_717e6b119d': ['startseq lady and her little girl are holding hands and walking up the sidewalk endseq',
#   'startseq mother and child run hand in hand through chinatown in an american city endseq',
#   'startseq woman and child both wearing red outfits walking up street endseq',
#   'startseq child in red holding the hand of person in red coat walking on sidewalk under awnings endseq',
#   'startseq woman and little girl wearing red in asian area endseq'],
#  '392976422_c8d0514bc3': ['startseq boy in blue shirt is walking along tan and blue wall endseq',
#   'startseq boy in stripes walking along ledge endseq',
#   'startseq boy scales the wall endseq',
#   'startseq child in striped shirt is walking along wall endseq',
#   'startseq boy in striped shirt walking along ledge endseq'],
#  '103205630_682ca7285b': ['startseq tent is being set up on the ice endseq',
#   'startseq two men are about to enter an ice fishing tent on snow covered lake endseq',
#   'startseq two men setting up blue ice fishing hut on an iced over lake endseq',
#   'startseq two men standing on an ice looking into something covered with blue tarp endseq',
#   'startseq two people standing outside blue tent structure on snowy surface endseq'],
#  '1347519824_e402241e4f': ['startseq few girls with green foam statue of liberty hats on train endseq',
#   'startseq some young adults are wearing green foam statute of liberty crowns endseq',
#   'startseq some young people take photos of each other while in new york endseq',
#   'startseq three woman with statue of liberty hats and taking picture endseq',
#   'startseq two woman wearing statue of liberty hats get their picture taken in subway endseq'],
#  '584484388_0eeb36d03d': ['startseq two brown dogs are playing with red ball endseq',
#   'startseq two brown dogs fight over red ball while playing in the grass endseq',
#   'startseq two brown dogs run over the grass carrying red toy endseq',
#   'startseq two daschunds play with red ball endseq',
#   'startseq two little wiener dogs are running on the grass carrying red ball between them endseq'],
#  '2460823604_7f6f786b1c': ['startseq boy baseball player in green and yellow jersey leaps for the ball endseq',
#   'startseq boy chasing baseball endseq',
#   'startseq little boy playing baseball goes for the ball on the ground endseq',
#   'startseq young boy dives to catch the ball during baseball game endseq',
#   'startseq the boy in the green and yellow shirt has glove on and is going towards the ball endseq'],
#  '121800200_bef08fae5f': ['startseq group of climbers begin up sheer rock face endseq',
#   'startseq group of rock climbers climb rock wall in forest endseq',
#   'startseq many people are climbing the mountain surrounded by pretty green trees endseq',
#   'startseq people at distance trying to climb cliff endseq',
#   'startseq the flat side of large rocky mountain endseq'],
#  '2422302286_385725e3cf': ['startseq child sits in plastic toy car endseq',
#   'startseq little kid in toy car endseq',
#   'startseq small girl riding in play car endseq',
#   'startseq there is child in red and yellow toy car endseq',
#   'startseq the small child is sitting in red and yellow toy car endseq'],
#  '3183883750_b6acc40397': ['startseq two girls hold up card reading know what this is endseq',
#   'startseq two kids smiling and holding card endseq',
#   'startseq two people pose for picure holding card that says know what this is endseq',
#   'startseq two people smile at the camera while holding sign endseq',
#   'startseq two teenage girls hold card referring to periods as they smile endseq'],
#  '3091912922_0d6ebc8f6a': ['startseq dog runs holding yellow dog toy in fall bench in the background endseq',
#   'startseq dog runs with yellow toy in its mouth endseq',
#   'startseq tan dog running through the grass with toy in his mouth endseq',
#   'startseq the brown dog is running through the grass with yellow toy in its mouth endseq',
#   'startseq the tan colored dog has yellow toy in its mouth endseq'],
#  '2787868417_810985234d': ['startseq blond girl in pink bathing suit running through the sprinklers endseq',
#   'startseq girl in pink runs through sprinkler endseq',
#   'startseq girl runs through sprinklers on lawn endseq',
#   'startseq little girl in pink in running through sprinkler endseq',
#   'startseq little girl wearing pink dress is running across the grass endseq'],
#  '3670075789_92ea9a183a': ['startseq child is sliding into small pool endseq',
#   'startseq girl in child swimming pool endseq',
#   'startseq little girl is sliding down short slide into an inflatable paddling pool endseq',
#   'startseq girl splashing in kiddie pool endseq',
#   'startseq the dark haired girl is sliding into white kiddie pool endseq'],
#  '3329169877_175cb16845': ['startseq lone snowboarder wearing white jacket jumping into the air on the snowy mountains endseq',
#   'startseq snowboarder flies through the air in front of leafless trees endseq',
#   'startseq snowboarder gets some air endseq',
#   'startseq snowboarder in green pants and white jacket is jumping high in the air endseq',
#   'startseq someone in green pants is on white snowboard in the air endseq'],
#  '751074141_feafc7b16c': ['startseq boy being pulled on shovel endseq',
#   'startseq happy child play in the scoop of shovel by chair in grassy backyard endseq',
#   'startseq little boy in red flowered shorts is sitting on shovel endseq',
#   'startseq little boy smiling and riding in shovel endseq',
#   'startseq small boy in red shorts with blue flowers sitting on shovel in the grass near tan chair endseq'],
#  '3445428367_25bafffe75': ['startseq person is standing on brick ledge taking picture of something in the distance endseq',
#   'startseq woman takes photograph endseq',
#   'startseq woman with long hair pointing her camera skyward as she stands on brick wall endseq',
#   'startseq the woman is holding camera and standing on brick wall endseq',
#   'startseq woman standing on brick wall and taking picture endseq'],
#  '3542418447_7c337360d6': ['startseq black dog and brown dog with yellow foam soccer ball toy on grassy field endseq',
#   'startseq brown dog and black dog playing with yellow soccer ball endseq',
#   'startseq two dogs on lawn play with plastic toy in distorted photograph endseq',
#   'startseq two dogs one brown one black with yellow toy black dog has mouth open and brown dog has the toy endseq',
#   'startseq two dogs run to catch yellow soccer ball endseq'],
#  '2730819220_b58af1119a': ['startseq little girl ends up at the bottom of the slide endseq',
#   'startseq little girl is just reaching the bottom of playground slide endseq',
#   'startseq little girl lands at the bottom of slide endseq',
#   'startseq young girl reaches the bottom of slide endseq',
#   'startseq young girl sliding down tan plastic slide endseq'],
#  '3543378438_47e2712486': ['startseq man dressed in green jacket is playing piano while woman sings endseq',
#   'startseq man is sitting in front of harpsichord and woman is preparing to sing endseq',
#   'startseq person playing the piano with singer nearby endseq',
#   'startseq pianist and singer are ready to perform endseq',
#   'startseq the man in the green jacket is playing the piano next to woman who is by music stand endseq'],
#  '2335619125_2e2034f2c3': ['startseq big black dog bares its teeth while running through the snow endseq',
#   'startseq black dog is running through the snow endseq',
#   'startseq black dog is running through the snow endseq',
#   'startseq black dog with his mouth open and tongue out runs across an expanse of snow endseq',
#   'startseq black dog runs through snow endseq'],
#  '3520199925_ca18d0f41e': ['startseq curly haired woman plays the violin endseq',
#   'startseq red haired woman is holding violin and boe endseq',
#   'startseq woman is playing violin while surrounded by transparent walls and pictures endseq',
#   'startseq woman playing the violin with posters in the background endseq',
#   'startseq the woman is holding violin endseq'],
#  '3374722123_6fe6fef449': ['startseq an elderly woman is wearing pink striped shirt endseq',
#   'startseq an older woman in pink striped shirt endseq',
#   'startseq an older woman with striped shirt rubbing her chin endseq',
#   'startseq woman in pink striped shirt with her hand up endseq',
#   'startseq older lady is appears to be getting ready to cover her mouth endseq'],
#  '3280672302_2967177653': ['startseq boy carries teenager on his back endseq',
#   'startseq boy struggles to carry girl on his back endseq',
#   'startseq person wearing black shirt is getting piggy back ride from person wearing black shirt walkng on paved path in the woods endseq',
#   'startseq teenage boy gives another teenage boy piggy back ride in forest endseq',
#   'startseq the boy is carrying the other boy endseq'],
#  '3073579130_7c95d16a7f': ['startseq man wears red bandanna endseq',
#   'startseq man with head covering endseq',
#   'startseq an man wearing an arab scarf with another man in the background endseq',
#   'startseq white man in turban endseq',
#   'startseq man with facial hair wearing red and white palestinian style headscarf endseq'],
#  '99679241_adc853a5c0': ['startseq grey bird stands majestically on beach while waves roll in endseq',
#   'startseq large bird stands in the water on the beach endseq',
#   'startseq tall bird is standing on the sand beside the ocean endseq',
#   'startseq water bird standing at the ocean edge endseq',
#   'startseq white crane stands tall as it looks out upon the ocean endseq'],
#  '3759492488_592cd78ed1': ['startseq boy hanging onto pole endseq',
#   'startseq kid in green shirt playing in the park endseq',
#   'startseq little kid swings on pole at playground endseq',
#   'startseq the boy in the green shirt swings with one arm on the silver pole endseq',
#   'startseq the boy is swinging on pole at the beach endseq'],
#  '2875528143_94d9480fdd': ['startseq girl wearing pink bounces on bed endseq',
#   'startseq little girl in pink leotard is jumping and landing in straddle split on blue bed endseq',
#   'startseq young girl jumping with her mouth open endseq',
#   'startseq little girl in pink hello kitty shirt is jumping endseq',
#   'startseq the girl in pink does midair leg splits endseq'],
#  '1052358063_eae6744153': ['startseq boy takes jump on his skateboard while another boy with skateboard watches endseq',
#   'startseq child is performing skateboard trick while another child with skateboard leans on wall endseq',
#   'startseq little boy skateboarder is doing trick on his board while another young skateboarder watches endseq',
#   'startseq young boy skateboarder jumping on platform on skateboard endseq',
#   'startseq two skateboarders endseq'],
#  '111766423_4522d36e56': ['startseq black and white bird eating seeds out of someone hand endseq',
#   'startseq black and white bird standing on hand endseq',
#   'startseq small bird sits in person hand and eats seeds endseq',
#   'startseq black and white bird standing on hand of someone holding sunflower seeds endseq',
# ...
#  '2546667441_bbe87a6285': ['startseq black dog is walking along the grass sniffing at the ground endseq',
#   'startseq black dog running in the grass endseq',
#   'startseq dog sniffs the grass endseq',
#   'startseq black dog on grass sniffing the ground endseq',
#   'startseq black dog with tan markings wearing blue collar standing on green grass endseq'],
#  '1301140633_046e4e8010': ['startseq boy in blue shirt with dirt on his face endseq',
#   'startseq boy with dirty face smiles endseq',
#   'startseq child with dirty face looks at the camera and smiles endseq',
#   'startseq blond child with dirty face holding yellow bottle with red cap plants in background endseq',
#   'startseq the boy has blonde hair and dirty face endseq'],
#  '458735196_176e7df6b3': ['startseq brown dog indoors with large pink toy endseq',
#   'startseq dog with wrinkled face bites on pink toy endseq',
#   'startseq wrinkled dog playing with pink chew toy endseq',
#   'startseq the dog is carrying pink ball in its mouth endseq',
#   'startseq this is strange sight dog delivering cookie endseq'],
#  '3304712466_18cbdb85fe': ['startseq bicycle racers being cheered on by some people endseq',
#   'startseq bicycle road racers passing group of cheering spectators endseq',
#   'startseq crowds cheer on cyclists as they complete race to the finish endseq',
#   'startseq people on bicycles riding through group of onlookers endseq',
#   'startseq racers on bikes riding past crowd endseq'],
#  '2721656220_5f4cda8bc1': ['startseq lady holds beverage endseq',
#   'startseq an attractive brunette woman smiles and holds beverage in front of her endseq',
#   'startseq woman holding drink and smiling endseq',
#   'startseq woman holds drink and smiles endseq',
#   'startseq this woman is wearing white shirt and holding cup endseq'],
#  '1253275679_e955fb7304': ['startseq boy has his head down and is wearing shirt that says adhd endseq',
#   'startseq young boy wearing clever black and white shirt with his head bowed down endseq',
#   'startseq the boy is wearing black shirt with an ad parody of the ac logo endseq',
#   'startseq young boy wearing an ac shirt looking down endseq',
#   'startseq young boy with black adhd shirt nodding off endseq'],
#  '3668984985_b60ceb2ae9': ['startseq family sits on bench in front of pool endseq',
#   'startseq few couples sitting on beanches next to pool endseq',
#   'startseq girl wearing boots stands next to swimming pool and four people seated on bench endseq',
#   'startseq group of people talking next to pool with trees in the background endseq',
#   'startseq people sit on bench by the pool endseq'],
#  '3241726740_6d256d61ec': ['startseq man smoking cigarette talking to lady who is sitting on steps endseq',
#   'startseq lady in black standing and smoking with another girl sitting on the steps endseq',
#   'startseq the person in black smoked while the woman in brown sat on the steps endseq',
#   'startseq the woman in the black coat is smoking and the woman in the gray coat sits on stone steps endseq',
#   'startseq two women smoking on the steps of white building endseq'],
#  '310213587_778fe8fb5b': ['startseq group of people sitting on benches at city park endseq',
#   'startseq man drinking beverage and holding plastic bag far away from the other people endseq',
#   'startseq man drinking soda is standing in front of bench near group of people sitting endseq',
#   'startseq man in black clothes and blue hat is taking drink and holding shopping bag endseq',
#   'startseq man is standing next to bench drinking soda while other people sit on bench nearby endseq'],
#  '2974501005_346f74e5d8': ['startseq boy does skateboard jump at skateboard park endseq',
#   'startseq kid doing trick on his skateboard endseq',
#   'startseq young boy is performing tricks with skateboard at skate park endseq',
#   'startseq young man rides yellow and black skateboard at the top of ramp endseq',
#   'startseq kid doing skateboard trick with his legs split and board between them endseq'],
#  '3716277216_c04002be81': ['startseq three african american women are dressed in bright orange and brown dresses and head scarves endseq',
#   'startseq three african women in traditional orange costume are gathered in front of yellow curtain endseq',
#   'startseq three women are dressed in african clothes and two of them are putting on make up endseq',
#   'startseq three women wearing traditional apparel make the final touches on their clothing endseq',
#   'startseq women are putting their robes and headdresses on endseq'],
#  '3320209694_db579cb607': ['startseq man in purple had climbs rocky wall with his hands endseq',
#   'startseq man with purple hat is climbing rock endseq',
#   'startseq man with purple hat and bandaged hand climbs wall of rock endseq',
#   'startseq young man in purple snow cap is rock climbing endseq',
#   'startseq this young man is rock climbing endseq'],
#  '3368865171_597d51cdd5': ['startseq child rides unicycle while crowd watches endseq',
#   'startseq little girl rides on bicycle during parade endseq',
#   'startseq small girl riding unicycle endseq',
#   'startseq girl in plaid shirt riding unicycle endseq',
#   'startseq person in checked shirt riding unicycle while crowd watches endseq'],
#  '124881487_36e668145d': ['startseq man on bicycle riding down rocky hill endseq',
#   'startseq man rides his dirt bike down rocky trail endseq',
#   'startseq person rides bike down rocky hill endseq',
#   'startseq blurry picture of mountain biker descending rocky trail endseq',
#   'startseq the mountain biker in blue rides down rocky path endseq'],
#  '2701603045_6cbdc4ce7c': ['startseq boy is wading through water endseq',
#   'startseq boy up to his knees in water endseq',
#   'startseq boy wearing white shorts walks through the water endseq',
#   'startseq young boy with white swim trunks walks out of the water endseq',
#   'startseq the boy is wading through the blue ocean endseq'],
#  '2278766574_f71f1704a8': ['startseq youn woman on man back walking down cement path with another couple behind them holding hands endseq',
#   'startseq people walk on path outside endseq',
#   'startseq several people are walking down trail endseq',
#   'startseq the man is giving woman piggyback ride through park endseq',
#   'startseq two couples walking on path adorned with trees bushes and grass endseq'],
#  '347543966_b2053ae78c': ['startseq group of men stand outside glass and steel building endseq',
#   'startseq three men are looking at wall very intently in city endseq',
#   'startseq three men stand in glass area endseq',
#   'startseq three people in glass structure endseq',
#   'startseq three people stand in an outdoor glass structure endseq'],
#  '1143882946_1898d2eeb9': ['startseq lady wearing helmet holding bike endseq',
#   'startseq woman in blue vest and sky blue helmet stands with her bicycle in traffic endseq',
#   'startseq woman in helmet rides her bike behind car endseq',
#   'startseq woman with helmet and backpack walks next to her bike endseq',
#   'startseq women with bike and helmet wait for traffic endseq'],
#  '2029280005_a19609c81a': ['startseq man in black shirt is rollerblading past bench in the city endseq',
#   'startseq man is inline skating in front of wooden bench endseq',
#   'startseq man is wearing rollerblades standing on paved area near park bench endseq',
#   'startseq man on rollerblades travelling down the sidewalk endseq',
#   'startseq man wearing black shirt and brown pants skates on concrete surface near park bench endseq'],
#  '3231751379_10ebf7150c': ['startseq goalie is crouching in defensive position in front of the goal endseq',
#   'startseq hockey player in blue and red guarding the goal endseq',
#   'startseq an ice hockey goalkeeper in red and blue strip is on his knees in front of the goal endseq',
#   'startseq an ice hockey player is bending down on the ice endseq',
#   'startseq the hockey player knelt on the ice endseq'],
#  '3069216757_c419b3898e': ['startseq girl in pink striped shirt is in front of an armoire endseq',
#   'startseq girl in pink striped shirt poses for the camera endseq',
#   'startseq girl wearing pink striped shirt throws her arms into the air endseq',
#   'startseq young girl wearing pink and orange stripped shirt extends her arms forward and appears to be happy endseq',
#   'startseq the girl wearing the pink striped shirt is standing in the doorway with her arm outstretched endseq'],
#  '3234719720_5bb2fc5ffa': ['startseq dark haired bearded man in white dress shirt and black sweater and woman in black and white dress in small space endseq',
#   'startseq man and women both in black and white are in an elevator endseq',
#   'startseq man with large beard and woman wearing white necklace smile endseq',
#   'startseq nicely dressed woman and bearded man in small room endseq',
#   'startseq smiling man leaning to his right stands behind smiling woman leaning to her left endseq'],
#  '491964988_414b556228': ['startseq little girl runs down path in japanese garden endseq',
#   'startseq little girl skips down path near an idyllic country pond endseq',
#   'startseq young girl hops on the path to avoid the puddles located near lake endseq',
#   'startseq young girl is jumping on gravel road near pond endseq',
#   'startseq the girl runs near pond endseq'],
#  '2474047296_fd9179d438': ['startseq man in white shirt and dress pants sits just underneath stone archway endseq',
#   'startseq man wearing white shirt and black pants sitting on staircase endseq',
#   'startseq an old man sits in an ancient brick archway endseq',
#   'startseq an old man with white shirt and black pants sits on chair in the opening of stone tunnel endseq',
#   'startseq elderly man sitting in doorway endseq'],
#  '3546891929_f31a99cd0d': ['startseq man in bicycle helmet is talking on cellphone with other people behind him endseq',
#   'startseq man in helmet holding cellphone endseq',
#   'startseq man in plaid shirt with red and black bike helmet on his cellphone endseq',
#   'startseq man wearing red bicycle helmet talking on cellphone with other people in the background endseq',
#   'startseq man with bicycle helmet on is using cellphone in the midst of crowd endseq'],
#  '2355763034_9fb61a8165': ['startseq flautist plays the flute in marching band endseq',
#   'startseq girl in band is playing the flute endseq',
#   'startseq girl in red and black uniform is playing the flute as part of marching band endseq',
#   'startseq woman in red uniform is playing the flute endseq',
#   'startseq girl in uniform playing flute with marching band endseq'],
#  '3065560742_f6e266ccd9': ['startseq boy playing hockey lies on the ice injured endseq',
#   'startseq the two hockey players are down on the ice endseq',
#   'startseq two hockey players fall on the ice endseq',
#   'startseq two hockey players fall to the ground in game endseq',
#   'startseq two hockey players slide into each other on the ice endseq'],
#  '265528702_8653eab9fa': ['startseq man in sunglasses and neatly trimmed beard overlooks woody valley endseq',
#   'startseq man posing with large grassy mountains off in the distance endseq',
#   'startseq man wearing sunglasses stands before forested landscape endseq',
#   'startseq man with beard and sunglasses is standing in front of tree covered hills endseq',
#   'startseq bearded man with sunglasses in the mountains endseq'],
#  '2687539673_d54a8dc613': ['startseq girl and young boy are jumping on trampoline in suburban yard endseq',
#   'startseq girl is jumping on trampoline with her arms in the air while boy in blue shirt is bouncing on his stomach endseq',
#   'startseq teenager girl jumps high on trampoline and toddler falls on his stomach endseq',
#   'startseq toddler and teenage girl jumping on trampoline endseq',
#   'startseq two children jump on trampoline endseq'],
#  '3067500667_0fce8f28d4': ['startseq cricket batsman has been bowled out middle stump endseq',
#   'startseq cricket player swings his bat but misses endseq',
#   'startseq man is standing in front of some red sticks trying to hit ball endseq',
#   'startseq man is swinging paddle at unique ball game endseq',
#   'startseq player hits the ball at cricket game endseq'],
#  '2657484970_610e18144f': ['startseq people are boating near mountain endseq',
#   'startseq two people in canoe are rowing past large tree covered mountain endseq',
#   'startseq two people in canoe float past rocky wooded cliff endseq',
#   'startseq two people in canoe on river beside forested mountain endseq',
#   'startseq two people in kayak are paddling past green foliage on river endseq'],
#  '407008823_bdd7fc6ed5': ['startseq climber is making his way up snowy mountainside endseq',
#   'startseq lone person jumping through the air from one snowy mountain to another endseq',
#   'startseq man doing tricks in the snow endseq',
#   'startseq man dressed in snow gear takes leap into snow covered ravine endseq',
#   'startseq people jump over mountain crevasse on rope endseq'],
#  '3675825945_96b2916959': ['startseq man in skateboarding in an empty swimming pool endseq',
#   'startseq man rides skateboard up the side of an empty pool endseq',
#   'startseq skateboarder dressed in white is dropping into blue bowl endseq',
#   'startseq skateboarder hanging off the edge of bowl at skate park endseq',
#   'startseq skateboarder in an empty pool endseq'],
#  '1557838421_a33f2a4911': ['startseq grey and white dog is biting the ear of white and brown dog endseq',
#   'startseq the brown and white dog nips at the yellow dog endseq',
#   'startseq there are two dogs playing with each other endseq',
#   'startseq two dogs wrestle with each other with their teeth bared endseq',
#   'startseq two large dogs attempt to bite each other playfully endseq'],
#  '544301311_5e7d69a517': ['startseq the women sit outside on the steps reading and drinking endseq',
#   'startseq two girls sit by doorway on the steps endseq',
#   'startseq two women in period dress sitting in doorway endseq',
#   'startseq two women in traditional european dress sit on stoop one drinking the other reading endseq',
#   'startseq two women with white head garb and long dresses sitting in front of door on steps reading and drinking beverage endseq'],
#  '3624076529_9793655a21': ['startseq brown dog swimming through lake with stick in his mouth endseq',
#   'startseq brown dog swimming with stick endseq',
#   'startseq dog holding stick swims in the water endseq',
#   'startseq dog swimming with stick in its mouth endseq',
#   'startseq golden dog swims with stick in its mouth endseq'],
#  '537479916_c033897fac': ['startseq black dog finishes running down blue and orange ramp endseq',
#   'startseq black dog has just run down blue and red ramp on an obstacle course endseq',
#   'startseq dog and person doing an agility course endseq',
#   'startseq dog runs dog ramp endseq',
#   'startseq dog runs down ramp past its trainer endseq'],
#  '2737729252_b3fd9c05b1': ['startseq girl is taking picture of another girl in park endseq',
#   'startseq girl is taking picture of another girl in park endseq',
#   'startseq woman takes picture of another in purple in park endseq',
#   'startseq one girl taking picture of her friend endseq',
#   'startseq two little girls playing in the parking lot endseq'],
#  '267162122_c3437414ec': ['startseq black puppy jumping on the back of white puppy endseq',
#   'startseq black dog and white dog wrestle endseq',
#   'startseq black dog and white dog wrestling next to food dish endseq',
#   'startseq black puppy stands over white puppy endseq',
#   'startseq small black dog is standing over small white dog laying on his side endseq'],
#  '2592711202_55f8c64495': ['startseq girl dressed in blue enjoys blue treat while putting her white shoe back on endseq',
#   'startseq girl in blue dress sitting on the ground eating cotton candy endseq',
#   'startseq girl in blue dress takes off her shoes and eats blue cotton candy endseq',
#   'startseq child in blue dress holding sandal in one hand and eating blue cotton candy with other hand endseq',
#   'startseq the girl in blue dress is eating some blue cotton candy with one shoe off and one shoe on endseq'],
#  ...}

# %%
train_descriptions['2513260012_03d33305cf']
# Out:
# ['startseq black dog is running after white dog in the snow endseq',
#  'startseq black dog chasing brown dog through snow endseq',
#  'startseq two dogs chase each other across the snowy ground endseq',
#  'startseq two dogs play together in the snow endseq',
#  'startseq two dogs running through low lying body of water endseq']

# %%
model = load_model("./model_weights/model_9.h5")

# %% [markdown]
# # Predictions

# %%
def predict_caption(photo):
    in_text = "startseq"
    
    for i in range(max_len):
        sequence = [word_to_idx[w] for w in in_text.split() if w in word_to_idx]
        sequence = pad_sequences([sequence], maxlen=max_len, padding='post')

        ypred =  model.predict([photo,sequence])
        ypred = ypred.argmax()
        word = idx_to_word[ypred]
        in_text+= ' ' +word
        
        if word =='endseq':
            break
        
        
    final_caption =  in_text.split()
    final_caption = final_caption[1:-1]
    final_caption = ' '.join(final_caption)
    
    return final_caption

# %%
for i in range(20):
    rn =  np.random.randint(0, 1000)
    img_name = list(encoding_test.keys())[rn]
    photo = encoding_test[img_name].reshape((1,2048))

    i = plt.imread(images+img_name)
    plt.imshow(i)
    plt.axis("off")
    plt.show()

    caption = predict_caption(photo)
    print(caption)
